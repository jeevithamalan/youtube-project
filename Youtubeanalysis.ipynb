# %%
from googleapiclient.discovery import build

# %%
def Api_connect():
    Api_Id='AIzaSyDdLr4sjl8NHnpUrTyIx_0Zg-Q0h5ChpR8'

    api_service_name='youtube'
    api_version='v3'
    youtube=build(api_service_name,api_version,developerKey=Api_Id)
    return youtube 

youtube=Api_connect()

# %%
### get channel info


def get_channel_info (channel_id):
  request=youtube.channels().list(
         part='snippet,ContentDetails, statistics' ,
         id=channel_id)

  response=request.execute()
  for i in response['items']:
       information=(dict(channel_name=i['snippet']['title'],
                     channel_id= i['id'],
                     subscribers=i['statistics']['subscriberCount'],
                     views=i['statistics']['viewCount'],
                     total_videos=i['statistics']['videoCount'],
                     channel_description=i['snippet']['description'],
                     playlist_id=i['contentDetails']['relatedPlaylists']['uploads']))
          
  return information

# %%
channelinfo=get_channel_info('UCVSsI1FWqaEgQQKPZO2Kt4g')
channelinfo
# Out:
# {'channel_name': 'SajithSP',
#  'channel_id': 'UCVSsI1FWqaEgQQKPZO2Kt4g',
#  'subscribers': '1210',
#  'views': '73453',
#  'total_videos': '203',
#  'channel_description': 'Accounting & Economics G.C.E A/L - 0771585054',
#  'playlist_id': 'UUVSsI1FWqaEgQQKPZO2Kt4g'}

# %%
##get video id
 
def get_videos_ids(channel_id):

   video_ids=[]
   response=youtube.channels().list(
         id=channel_id,
         part='ContentDetails').execute()
   Paylist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']


   next_page_token=None
   while True:
            response1=youtube.playlistItems().list(
                              part='snippet',
                              playlistId=Paylist_Id,
                              maxResults=50,
                              pageToken=next_page_token).execute()

            for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
            next_page_token=response1.get('nextpageToken')
            
            if next_page_token is None:
                  break
            
   return video_ids

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 Paylist_Id
#
# NameError: name 'Paylist_Id' is not defined

# %%
videosid=get_videos_ids('UCuI5XcJYynHa5k_lqDzAgwQ')

videosid
# Out:
# ['tadK65KehvA',
#  'HoX7T7BsqAs',
#  'bbbi0RAMrZo',
#  'D0pWDo0x5ao',
#  'hdOny_O8Qxg',
#  'gdNrhpiaMqk',
#  'wLrzbanUVKs',
#  'VOxOJMlpbw0',
#  'ZaWHSsqo2Fw',
#  'VKySXPjmUzo',
#  'F11BVRciggQ',
#  'OqYYuu96zyQ',
#  'B7JUo06WX4I',
#  'AYyg2rQOVIc',
#  'k3n2FXSbhd4',
#  'eyHCv3KLFrA',
#  'nR9eaYYtdQ4',
#  'ht_nS8TjQmY',
#  'FLDy71gP29A',
#  'FVQSly4AGh0',
#  'WV5z24-4Z04',
#  '1DCdv1sKdeQ',
#  'LT0rmxunQHI',
#  'YPEPOkGJPv4',
#  'V29V4bATwPE',
#  'XVRh_Gs3kT0',
#  'h_Ph2tt9SwU',
#  'wX--Clg_aiA',
#  'Bqgjq6NGL4c',
#  'BzU_VaoE7OI',
#  'LuJq26q6iWw',
#  'DIrc-tFOSrk',
#  'iytmvBg26Vk',
#  'Lut7ISPuUew',
#  'OW6S10NFfWU',
#  'ipSL33FOS30',
#  'QGzhSqyoUbA',
#  'vrUniQisKTE',
#  'VfakvmAlwhU',
#  'G4YlF8bBtLs',
#  '5TEauiYxpZk',
#  '2IU9RpMzgAo',
#  'FGnZ3pUliCU',
#  'EXn3-jKNVFU',
#  'on-a5-77Y94',
#  'OM7Bsb9ZCTY',
#  '2cyfmA-R-Uw',
#  'r2sn478BKg4',
#  'xBCx4PEZpfo']

# %%
##get video info
def get_video_info(video_ids):
  video_data=[]
  for video_id in video_ids:
 
    request=youtube.videos().list(
              part='snippet,contentDetails,statistics',
              id=video_id
    )
    response=request.execute()


    for item in response['items']:
        data=dict(Channel_Name=item['snippet']['channelTitle'],
                  channel_Id=item['snippet']['channelId'],
                  Video_Id=item['id'],
                  Title=item['snippet']['title'],
                  Tags=item['snippet'].get('tags'),
                  Thumbnail=item['snippet']['thumbnails']['default']['url'],
                  Description=item['snippet'].get('description'),
                  Published_Date=item['snippet']['publishedAt'],
                  Duration=item['contentDetails']['duration'],
                  Views=item['statistics'].get('viewCount'),
                  Likes=item['statistics'].get('likeCount'),
                  Comments=item['statistics'].get('commentCount'),
                  Favorite_Count=item['statistics']['favoriteCount'],
                  Definition=item['contentDetails']['definition'],
                  Caption_Status=item['contentDetails']['caption']
                  )
        video_data.append(data)
    return video_data

# %%
videoinfo=get_video_info(videosid)
videoinfo
# Out:
# [{'Channel_Name': 'Data Science Tamil',
#   'channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Video_Id': 'tadK65KehvA',
#   'Title': 'PhonePe Pulse Data Visualization and Exploration|Data Analysis (17)|part 4.6|Streamlit and Plot',
#   'Tags': ['PhonePe',
#    'DataVisualization in tamil',
#    'DataExploration in tamil',
#    'Streamlit in tamil',
#    'Plotly in tamil',
#    'PythonProgramming in tamil',
#    'DataScienceProject',
#    'data science tamil',
#    'phonepe pulse data visualization and exploration project tamil',
#    'phonepe pulse data visualization github in tamil',
#    'GUVI capstone project',
#    'capstone project tamil',
#    'guvi',
#    'guvi capstone project full explanation in tamil',
#    'data analysis 17',
#    'top transaction 1',
#    'part 4.6',
#    'data science full course in tamil',
#    'phonepe data'],
#   'Thumbnail': 'https://i.ytimg.com/vi/tadK65KehvA/default.jpg',
#   'Description': "PhonePe has emerged as a leader among digital payment platforms, catering to millions of users for their daily transactions. Renowned for its user-friendly interface, rapid and secure payment processing, and innovative features, PhonePe has garnered accolades and recognition within the industry.\n\nIn the PhonePe Pulse Data Visualization and Exploration project, we embark on a mission to extract valuable insights from PhonePe's GitHub repository. Our goal is to meticulously process this data and present it through an interactive dashboard that captivates with its visual appeal. This endeavor is made possible by leveraging the power of Python, Streamlit, and Plotly.\n\nPhonepe Pulse Data Visualization and Exploration:\nA User-Friendly Tool Using Streamlit and Plotly\n\nIndia_Map_Link: https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson\n\nInstall Postgres: https://youtu.be/WxBfnGH3FsU?si=eWZx_DRCoGfSRxw8\n\nStay Connected:\n- LinkedIn: https://www.linkedin.com/in/vignesh15502/\n- GitHub: https://github.com/Vignesh15502\n\n#streamlit #datavisualization #python\n🔗 Join us on this exciting data-driven journey as we explore the world of YouTube data and unlock the potential of data science!\n\nSubscribe to our channel for more insightful projects, tutorials, and data science content. Let's uncover the power of data together!",
#   'Published_Date': '2024-03-01T15:50:31Z',
#   'Duration': 'PT10M59S',
#   'Views': '0',
#   'Likes': '0',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %%
##get comment information
def get_comment_info(video_ids):
    Comment_Data=[]

    try:
      for video_id in video_ids:
          request=youtube.commentThreads().list(
              part='snippet',
              videoId=video_id,
              maxResults=50

           )
          response=request.execute()

          for item in response['items']:
              data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                      Video_Id=item['snippet']['topLevelComment']['snippet']['videoId'],
                      Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                      Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                      Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
              Comment_Data.append(data)
    except:
      pass
    return Comment_Data

# %%
commentinfo=get_comment_info(videosid)
commentinfo
# Out:
# [{'Comment_Id': 'UgxisUnOesMU7kvvcF54AaABAg',
#   'Video_Id': 'D0pWDo0x5ao',
#   'Comment_Text': 'Bro how to download <a href="http://st.video/">st.video</a> file',
#   'Comment_Author': '@phoorneshmurali6441',
#   'Comment_Published': '2024-03-01T13:38:33Z'},
#  {'Comment_Id': 'UgwGwU_DoVCJBSm5-i54AaABAg',
#   'Video_Id': 'D0pWDo0x5ao',
#   'Comment_Text': 'Help me to do final project',
#   'Comment_Author': '@sharonmanuel8220',
#   'Comment_Published': '2024-02-29T20:22:23Z'},
#  {'Comment_Id': 'Ugy_qTQBRz7mu25DSn14AaABAg',
#   'Video_Id': 'wLrzbanUVKs',
#   'Comment_Text': 'bro numpy,pandas and matplotlib seaborn vachi oru end to end video podunga bro',
#   'Comment_Author': '@pubgclutch7719',
#   'Comment_Published': '2024-02-28T14:01:45Z'},
#  {'Comment_Id': 'UgyLQzd5vA5La9KeFMV4AaABAg',
#   'Video_Id': 'VOxOJMlpbw0',
#   'Comment_Text': 'Bro please unga mail id kedaikuma bcoz I am also in guvi that&#39;s why',
#   'Comment_Author': '@stark2794',
#   'Comment_Published': '2024-02-27T19:23:09Z'},
#  {'Comment_Id': 'Ugyd44dGf5MZPKdf0dV4AaABAg',
#   'Video_Id': 'VOxOJMlpbw0',
#   'Comment_Text': 'Hi Vignesh I still have doubt in YouTube data harvesting in that after installing googleapiclient . From googleapiclient.discovery is not working showing error like no module name googleapiclient ! Am confused ! Can you help me in this . Can you drop you’re email so I could contact you for this doubts',
#   'Comment_Author': '@rishiraja1630',
#   'Comment_Published': '2024-02-27T10:14:21Z'},
#  {'Comment_Id': 'Ugwuz5SVl05sdH8SO2t4AaABAg',
#   'Video_Id': 'ZaWHSsqo2Fw',
#   'Comment_Text': 'Please upload ML projects',
#   'Comment_Author': '@sharonmanuel8220',
#   'Comment_Published': '2024-02-27T04:46:07Z'},
#  {'Comment_Id': 'UgzkvwEMOS33dU2p9-Z4AaABAg',
#   'Video_Id': 'B7JUo06WX4I',
#   'Comment_Text': 'next video eppo bro',
#   'Comment_Author': '@saravananmohan4213',
#   'Comment_Published': '2024-02-26T10:12:07Z'},
#  {'Comment_Id': 'UgzDBKxq_6ct-EV_FlR4AaABAg',
#   'Video_Id': 'B7JUo06WX4I',
#   'Comment_Text': 'Next video bro',
#   'Comment_Author': '@baraneetharanr5916',
#   'Comment_Published': '2024-02-26T09:20:42Z'},
#  {'Comment_Id': 'UgwKcsSakxD-OZHjcaN4AaABAg',
#   'Video_Id': 'B7JUo06WX4I',
#   'Comment_Text': 'Unga github link kidaikkuma bro',
#   'Comment_Author': '@Ram-py6em',
#   'Comment_Published': '2024-02-26T04:45:13Z'},
#  {'Comment_Id': 'Ugx49_ODReAMRp22wiF4AaABAg',
#   'Video_Id': 'AYyg2rQOVIc',
#   'Comment_Text': 'Bro i am facing error i have mailed you the screenshot check and tell me bro.',
#   'Comment_Author': '@nethraswami9457',
#   'Comment_Published': '2024-02-27T08:00:21Z'},
#  {'Comment_Id': 'UgzoRjYNY2cdh_MOPIp4AaABAg',
#   'Video_Id': 'AYyg2rQOVIc',
#   'Comment_Text': 'hi vignesh i  went through your linkedin profile seems like you did DS course in guvi . even me took that course can you drop your email id so it will so helpful for me to contact you regarding doubts',
#   'Comment_Author': '@rishiraja1630',
#   'Comment_Published': '2024-02-26T14:28:22Z'},
#  {'Comment_Id': 'UgzAP-LngMi59M9EviR4AaABAg',
#   'Video_Id': 'AYyg2rQOVIc',
#   'Comment_Text': 'Bro aggre transaction vs code la output varuthu bro.. but ( py )la  mathi streamlit la output varala but transaction analysis matum select aagiruku output adhula varala bro empty ah iruku ?',
#   'Comment_Author': '@devadhanush2119',
#   'Comment_Published': '2024-02-26T13:16:21Z'},
#  {'Comment_Id': 'UgyxveS0FFCy-RHtGF54AaABAg',
#   'Video_Id': 'AYyg2rQOVIc',
#   'Comment_Text': 'Thank you',
#   'Comment_Author': '@mperumal726',
#   'Comment_Published': '2024-02-25T16:56:58Z'},
#  {'Comment_Id': 'UgzeoULA2i8dmk9hyeN4AaABAg',
#   'Video_Id': 'AYyg2rQOVIc',
#   'Comment_Text': 'Next video bro',
#   'Comment_Author': '@baraneetharanr5916',
#   'Comment_Published': '2024-02-25T16:01:12Z'},
#  {'Comment_Id': 'UgwIEewbiD6b4aJ37Bp4AaABAg',
#   'Video_Id': 'k3n2FXSbhd4',
#   'Comment_Text': 'hi bro run panna india map visible varala.why bro?',
#   'Comment_Author': '@murugalakshmiram5582',
#   'Comment_Published': '2024-02-26T06:13:41Z'},
#  {'Comment_Id': 'UgySIFiGJp38IXKiphR4AaABAg',
#   'Video_Id': 'k3n2FXSbhd4',
#   'Comment_Text': 'Bro upload next video bro.tommorow is the deadline to submit the project',
#   'Comment_Author': '@chethanb7833',
#   'Comment_Published': '2024-02-23T02:58:36Z'},
#  {'Comment_Id': 'UgyuAuKT1upHn4WXkA14AaABAg',
#   'Video_Id': 'k3n2FXSbhd4',
#   'Comment_Text': 'Next video bro',
#   'Comment_Author': '@baraneetharanr5916',
#   'Comment_Published': '2024-02-21T12:22:21Z'},
#  {'Comment_Id': 'UgyUuoH6msqTiFBWBcV4AaABAg',
#   'Video_Id': 'k3n2FXSbhd4',
#   'Comment_Text': 'next video upload pannu bro',
#   'Comment_Author': '@sriramsudhakar316',
#   'Comment_Published': '2024-02-19T04:50:54Z'},
#  {'Comment_Id': 'UgzS2-m1imSLbBoIXvp4AaABAg',
#   'Video_Id': 'k3n2FXSbhd4',
#   'Comment_Text': 'Brother unga keta coaching join pannikalam , training kudipingala intha mari tamil la easy kathutharingala',
#   'Comment_Author': '@jayasuriya305',
#   'Comment_Published': '2024-02-18T16:51:19Z'},
#  {'Comment_Id': 'UgybMQJMycgAH4aQ9T54AaABAg',
#   'Video_Id': 'k3n2FXSbhd4',
#   'Comment_Text': 'Thank you bro ❤',
#   'Comment_Author': '@mperumal726',
#   'Comment_Published': '2024-02-18T11:03:24Z'},
#  {'Comment_Id': 'UgzH3GZTBYwE4mnQt6h4AaABAg',
#   'Video_Id': 'k3n2FXSbhd4',
#   'Comment_Text': 'Bro next video epo poduviga',
#   'Comment_Author': '@amsathsherif659',
#   'Comment_Published': '2024-02-18T04:50:59Z'},
#  {'Comment_Id': 'UgxHDxImD3rN0OTjCjd4AaABAg',
#   'Video_Id': 'k3n2FXSbhd4',
#   'Comment_Text': 'Bro please provide subtitles in every video',
#   'Comment_Author': '@pratapvesapogu3258',
#   'Comment_Published': '2024-02-17T17:11:28Z'},
#  {'Comment_Id': 'UgxaC2CyiwKicrGLjl94AaABAg',
#   'Video_Id': 'k3n2FXSbhd4',
#   'Comment_Text': 'Super bro🤜 thank you',
#   'Comment_Author': '@amsathsherif659',
#   'Comment_Published': '2024-02-17T14:01:27Z'},
#  {'Comment_Id': 'UgzekU-mgmL7m0NmTGd4AaABAg',
#   'Video_Id': 'eyHCv3KLFrA',
#   'Comment_Text': 'aggregated insurance dataframe la transaction column ey illaye epdi atha base ah vechu transaction amount fetch panninga, aggregated insurance la  insurance count , insurance amiunt mattum thana irukku',
#   'Comment_Author': '@manip2416',
#   'Comment_Published': '2024-02-27T13:25:52Z'},
#  {'Comment_Id': 'UgyjUnQZFhdxebuaUs94AaABAg',
#   'Video_Id': 'eyHCv3KLFrA',
#   'Comment_Text': 'Bro ino evlo videos iruku to complete this project.',
#   'Comment_Author': '@nethraswami9457',
#   'Comment_Published': '2024-02-21T07:34:49Z'},
#  {'Comment_Id': 'Ugw3zQ_p_6IFxpfBLbV4AaABAg',
#   'Video_Id': 'eyHCv3KLFrA',
#   'Comment_Text': 'Bro last ah px.choropleth kita tacyg variable kitta error varuthu bro.',
#   'Comment_Author': '@nethraswami9457',
#   'Comment_Published': '2024-02-19T07:03:03Z'},
#  {'Comment_Id': 'UgxAkK2hz8i-gfDtNIF4AaABAg',
#   'Video_Id': 'eyHCv3KLFrA',
#   'Comment_Text': 'Remaining video upload pannu bro',
#   'Comment_Author': '@sriramsudhakar316',
#   'Comment_Published': '2024-02-17T10:32:40Z'},
#  {'Comment_Id': 'UgytH-Y-lZ2LxIsbtkN4AaABAg',
#   'Video_Id': 'eyHCv3KLFrA',
#   'Comment_Text': 'Hi bro cource last stage la iruku ,complete pana job vagai thatuvagala bro,Unga contact details kuduga bro ungala contact pana',
#   'Comment_Author': '@tamilviyan',
#   'Comment_Published': '2024-02-17T05:36:07Z'},
#  {'Comment_Id': 'UgxjFyn_z_cYTxH2cIV4AaABAg',
#   'Video_Id': 'eyHCv3KLFrA',
#   'Comment_Text': 'Bro next video',
#   'Comment_Author': '@baraneetharanr5916',
#   'Comment_Published': '2024-02-17T04:28:33Z'},
#  {'Comment_Id': 'Ugw3iLuBl5rqegSQRi94AaABAg',
#   'Video_Id': 'nR9eaYYtdQ4',
#   'Comment_Text': 'Bro please upload previous 4 videos..',
#   'Comment_Author': '@chethanb7833',
#   'Comment_Published': '2024-02-21T07:48:13Z'},
#  {'Comment_Id': 'UgzpB0lOozSgtbNqafJ4AaABAg',
#   'Video_Id': 'nR9eaYYtdQ4',
#   'Comment_Text': 'Bro next project eppo start pannuveenga',
#   'Comment_Author': '@phoorneshmurali6441',
#   'Comment_Published': '2024-02-16T10:42:38Z'},
#  {'Comment_Id': 'Ugy3eyYkUOOUKUlkDyt4AaABAg',
#   'Video_Id': 'nR9eaYYtdQ4',
#   'Comment_Text': 'can you tell where can i get airbnb.csv file',
#   'Comment_Author': '@srinayan666',
#   'Comment_Published': '2024-02-16T08:36:15Z'},
#  {'Comment_Id': 'UgwWQj10oaQ7yrMRiD54AaABAg',
#   'Video_Id': 'nR9eaYYtdQ4',
#   'Comment_Text': 'Bro next video epa upload pannuvinga',
#   'Comment_Author': '@nethraswami9457',
#   'Comment_Published': '2024-02-15T07:23:52Z'},
#  {'Comment_Id': 'UgxfxrcgMI22mZqIG2x4AaABAg',
#   'Video_Id': 'ht_nS8TjQmY',
#   'Comment_Text': 'I can&#39;t run streamlit app with .py file..It says invalid file',
#   'Comment_Author': '@fathimaraziha5692',
#   'Comment_Published': '2024-03-01T14:05:23Z'},
#  {'Comment_Id': 'Ugz_4rjtz_k9Rmwb4aR4AaABAg',
#   'Video_Id': 'ht_nS8TjQmY',
#   'Comment_Text': 'Bro pls put industrial coppering',
#   'Comment_Author': '@lalithkishorep2618',
#   'Comment_Published': '2024-02-29T13:35:04Z'},
#  {'Comment_Id': 'UgzX1cgM6hfw-sjgxTV4AaABAg',
#   'Video_Id': 'ht_nS8TjQmY',
#   'Comment_Text': 'ImportError: cannot import name &#39;streamlit_option_menu&#39; from &#39;streamlit_option_menu&#39; (C:\\Users\\Rajgowtham\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\streamlit_option_menu\\__init__.py)',
#   'Comment_Author': '@rajgowthamk2973',
#   'Comment_Published': '2024-02-25T12:15:06Z'},
#  {'Comment_Id': 'UgyQO2CgGioipoZ43fd4AaABAg',
#   'Video_Id': 'ht_nS8TjQmY',
#   'Comment_Text': 'Bro please upload 2.6 ,2.7 ,2.8, 2.9 videos',
#   'Comment_Author': '@chethanb7833',
#   'Comment_Published': '2024-02-21T07:12:33Z'},
#  {'Comment_Id': 'UgxB7MRHJcqwCf4atdl4AaABAg',
#   'Video_Id': 'ht_nS8TjQmY',
#   'Comment_Text': 'Bro streamlit_option_menu ennaku install aagave illa. Enna bro panradhu?',
#   'Comment_Author': '@user-py4ib4eq4y',
#   'Comment_Published': '2024-02-20T16:17:23Z'},
#  {'Comment_Id': 'UgwqlyZEOu-YssdnNP14AaABAg',
#   'Video_Id': 'ht_nS8TjQmY',
#   'Comment_Text': 'my streamlit page shows only blank white page .what can i do sir.pls reply <a href="http://quickly.today/">quickly.today</a> is my last day to submit the project',
#   'Comment_Author': '@gunaseelanponnuvel3180',
#   'Comment_Published': '2024-02-14T11:44:30Z'},
#  {'Comment_Id': 'UgyhRs8K4MX-YJ9xPyJ4AaABAg',
#   'Video_Id': 'ht_nS8TjQmY',
#   'Comment_Text': 'Bro konjam seekarama intha project muduchutu . bizcard project start pannunga bro pls',
#   'Comment_Author': '@nethraswami9457',
#   'Comment_Published': '2024-02-14T11:35:05Z'},
#  {'Comment_Id': 'UgxZWAi9veV48GTGf0x4AaABAg',
#   'Video_Id': 'ht_nS8TjQmY',
#   'Comment_Text': 'Bro next video epa upload pannuvinga bro konjam seekarama upload pannunga bro',
#   'Comment_Author': '@nethraswami9457',
#   'Comment_Published': '2024-02-14T07:22:59Z'},
#  {'Comment_Id': 'UgzJ4ytY2K2q1kdptRh4AaABAg',
#   'Video_Id': 'ht_nS8TjQmY',
#   'Comment_Text': 'Thank you bro',
#   'Comment_Author': '@mperumal726',
#   'Comment_Published': '2024-02-13T15:07:10Z'},
#  {'Comment_Id': 'UgxgRR7u3ITXkUkAOcp4AaABAg',
#   'Video_Id': 'ht_nS8TjQmY',
#   'Comment_Text': 'Bro industry copper project la oru part matum more than 25min + running.<br>I have mailed you about it kindly check and reply bro',
#   'Comment_Author': '@nitish08',
#   'Comment_Published': '2024-02-13T08:13:10Z'},
#  {'Comment_Id': 'UgwHvGeB1sVTcs9l36d4AaABAg',
#   'Video_Id': 'FLDy71gP29A',
#   'Comment_Text': 'bro we already have dataframes in python , then why we again fetching it from sql ?',
#   'Comment_Author': '@balakrishnan5493',
#   'Comment_Published': '2024-02-28T12:24:31Z'},
#  {'Comment_Id': 'UgwOmHkFO48RCnoUZL94AaABAg',
#   'Video_Id': 'FLDy71gP29A',
#   'Comment_Text': 'Im also studying data science in guvi,Bro ungaloda contact number please',
#   'Comment_Author': '@SK98_vlogs',
#   'Comment_Published': '2024-02-09T03:08:57Z'},
#  {'Comment_Id': 'UgzjOSJ9pyRkLpvROBN4AaABAg',
#   'Video_Id': 'FVQSly4AGh0',
#   'Comment_Text': 'Bro 1 unavailable video is hidden nu katuthu bro 14/15 videos dha iruku..',
#   'Comment_Author': '@devadhanush2119',
#   'Comment_Published': '2024-02-07T19:16:44Z'},
#  {'Comment_Id': 'UgxjNjDX9sGfTrnPO7V4AaABAg',
#   'Video_Id': 'FVQSly4AGh0',
#   'Comment_Text': 'Bro sekarama videos yella upload pannunga pls',
#   'Comment_Author': '@nethraswami9457',
#   'Comment_Published': '2024-02-06T05:51:12Z'},
#  {'Comment_Id': 'UgwM8d6O7ST8tgurdap4AaABAg',
#   'Video_Id': 'FVQSly4AGh0',
#   'Comment_Text': 'Bro i had a doubt i  getting a pulse in the folder transcation there is a three files are ptesent i just want to write a code for insurance.',
#   'Comment_Author': '@prithiviraj6598',
#   'Comment_Published': '2024-02-05T15:57:38Z'},
#  {'Comment_Id': 'UgxBCP1RtFoyth-ycFV4AaABAg',
#   'Video_Id': 'FVQSly4AGh0',
#   'Comment_Text': 'Bro when will you post next video ?',
#   'Comment_Author': '@MSTCharumathi',
#   'Comment_Published': '2024-02-05T15:39:07Z'},
#  {'Comment_Id': 'UgyS601DOLrRmTzWVrV4AaABAg',
#   'Video_Id': 'WV5z24-4Z04',
#   'Comment_Text': 'Bro enaku SQL la data load pana kula data values change aagudhu bro.',
#   'Comment_Author': '@rajgowthamk2973',
#   'Comment_Published': '2024-02-20T12:50:53Z'},
#  {'Comment_Id': 'Ugy4kkuGTf-OXtJmjfh4AaABAg',
#   'Video_Id': 'WV5z24-4Z04',
#   'Comment_Text': 'bro nxt video epa update pannuvinga',
#   'Comment_Author': '@nethraswami9457',
#   'Comment_Published': '2024-02-05T08:10:38Z'},
#  {'Comment_Id': 'Ugz86Y2pY4ClJKg15OB4AaABAg',
#   'Video_Id': '1DCdv1sKdeQ',
#   'Comment_Text': 'Bro unga mentor yaru bro.',
#   'Comment_Author': '@prithiviraj6598',
#   'Comment_Published': '2024-02-05T04:09:04Z'},
#  {'Comment_Id': 'Ugw8uAX8Rj_tNdQ8O9t4AaABAg',
#   'Video_Id': 'LT0rmxunQHI',
#   'Comment_Text': 'Yes please upload next video',
#   'Comment_Author': '@anumohanvadivel81',
#   'Comment_Published': '2024-02-04T16:38:18Z'},
#  {'Comment_Id': 'UgzXTS4WAHiHv8OOsYp4AaABAg',
#   'Video_Id': 'LT0rmxunQHI',
#   'Comment_Text': 'Bro kindly upload Next videos.....',
#   'Comment_Author': '@nethraswami9457',
#   'Comment_Published': '2024-02-03T06:59:16Z'},
#  {'Comment_Id': 'UgxETUTcji4g4YgwGSh4AaABAg',
#   'Video_Id': 'LT0rmxunQHI',
#   'Comment_Text': 'Bro kindly upload next video...',
#   'Comment_Author': '@jainthik3623',
#   'Comment_Published': '2024-02-03T03:14:02Z'},
#  {'Comment_Id': 'UgyhR4W5gmRpzcfLlxR4AaABAg',
#   'Video_Id': 'LT0rmxunQHI',
#   'Comment_Text': 'Anna inda project mudinja apro next project video poduvingla?',
#   'Comment_Author': '@manjushree2898',
#   'Comment_Published': '2024-02-01T13:25:29Z'},
#  {'Comment_Id': 'Ugw73j1OjUPTsiDKtIJ4AaABAg',
#   'Video_Id': 'LT0rmxunQHI',
#   'Comment_Text': 'Bro Next video epo poduvinga',
#   'Comment_Author': '@nethraswami9457',
#   'Comment_Published': '2024-02-01T13:15:28Z'},
#  {'Comment_Id': 'UgwT8DjJiSApR8W4uPd4AaABAg',
#   'Video_Id': 'LT0rmxunQHI',
#   'Comment_Text': 'Hi bro, na ungaloda GitHub profile parthen adhula final project retail sales forecast data set send panringala bro',
#   'Comment_Author': '@premav6892',
#   'Comment_Published': '2024-01-31T08:33:14Z'},
#  {'Comment_Id': 'UgwZ238AZ0LklIXtBjh4AaABAg',
#   'Video_Id': 'LT0rmxunQHI',
#   'Comment_Text': 'Bro itha project romba length ah iruka pola iruku.but Unga coding easy ah understand panra pola iruku ,epo bro complete agum',
#   'Comment_Author': '@tamilviyan',
#   'Comment_Published': '2024-01-31T02:06:41Z'},
#  {'Comment_Id': 'Ugyn-yDQbv3IZwRSBzN4AaABAg',
#   'Video_Id': 'YPEPOkGJPv4',
#   'Comment_Text': 'Thank you bro🎉',
#   'Comment_Author': '@renugadevichakkarai6111',
#   'Comment_Published': '2024-01-31T07:23:50Z'},
#  {'Comment_Id': 'UgziO3x5VYzHdpLMech4AaABAg',
#   'Video_Id': 'V29V4bATwPE',
#   'Comment_Text': 'why we are taking pincode can we take district instead of that',
#   'Comment_Author': '@gopikas7416',
#   'Comment_Published': '2024-02-16T09:27:54Z'},
#  {'Comment_Id': 'UgxvBp0BN5fD23VWXuF4AaABAg',
#   'Video_Id': 'V29V4bATwPE',
#   'Comment_Text': 'anna guvi pathi soluunga na our video la plsssss',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-01-30T15:30:13Z'},
#  {'Comment_Id': 'UgzjUiTV42hC0uM1dPt4AaABAg',
#   'Video_Id': 'V29V4bATwPE',
#   'Comment_Text': 'Thank you soo much bro🎉',
#   'Comment_Author': '@renugadevichakkarai6111',
#   'Comment_Published': '2024-01-30T14:13:12Z'},
#  {'Comment_Id': 'UgzzyaYM80bre3YqpDJ4AaABAg',
#   'Video_Id': 'XVRh_Gs3kT0',
#   'Comment_Text': 'Bro will u upload all the videos? Today',
#   'Comment_Author': '@fdfs5782',
#   'Comment_Published': '2024-01-30T05:34:20Z'},
#  {'Comment_Id': 'Ugy3gIgS-RbPSclKi7d4AaABAg',
#   'Video_Id': 'h_Ph2tt9SwU',
#   'Comment_Text': 'Please do in English also. 😢',
#   'Comment_Author': '@user-mm3mv3kc3h',
#   'Comment_Published': '2024-02-16T05:06:33Z'},
#  {'Comment_Id': 'UgzlQiyDWD2FoagDMGB4AaABAg',
#   'Video_Id': 'h_Ph2tt9SwU',
#   'Comment_Text': 'Thanks bro',
#   'Comment_Author': '@renugadevichakkarai6111',
#   'Comment_Published': '2024-01-30T07:13:28Z'},
#  {'Comment_Id': 'UgxYJs3NiHlRkomNaGh4AaABAg',
#   'Video_Id': 'h_Ph2tt9SwU',
#   'Comment_Text': 'Thanks a lot bro we have been waiting for this',
#   'Comment_Author': '@user-cz9oe6ib2z',
#   'Comment_Published': '2024-01-30T04:43:25Z'},
#  {'Comment_Id': 'UgxRduTlL5v80lC2tZN4AaABAg',
#   'Video_Id': 'wX--Clg_aiA',
#   'Comment_Text': 'Hai How are you?  Thanks for your video uploading thank you',
#   'Comment_Author': '@renugadevichakkarai6111',
#   'Comment_Published': '2024-01-28T12:33:58Z'},
#  {'Comment_Id': 'UgwCG48tui4ph_B0g794AaABAg',
#   'Video_Id': 'wX--Clg_aiA',
#   'Comment_Text': 'Thanks bro ❤',
#   'Comment_Author': '@mperumal726',
#   'Comment_Published': '2024-01-28T05:27:03Z'},
#  {'Comment_Id': 'Ugwwk1k0N64-Oavlckp4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Bro final output pic share panna mudiyuma?',
#   'Comment_Author': '@mohanapriya2116',
#   'Comment_Published': '2024-01-30T12:46:54Z'},
#  {'Comment_Id': 'Ugzw93PHhceGoxDT0ZZ4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Bro epo next video poduviga',
#   'Comment_Author': '@amsathsherif659',
#   'Comment_Published': '2024-01-26T10:21:43Z'},
#  {'Comment_Id': 'UgwPYwPvSONcHMjEaEJ4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Hi bro, By referring your github repo i have done the coding but how to execute it? What is execute command?? Can u pls share that??',
#   'Comment_Author': '@user-vo9hy3go9d',
#   'Comment_Published': '2024-01-21T16:00:04Z'},
#  {'Comment_Id': 'Ugyn-8og4SZjAVSQe8J4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'hello sir ,please upload other parts also.',
#   'Comment_Author': '@srinayan666',
#   'Comment_Published': '2024-01-21T06:21:52Z'},
#  {'Comment_Id': 'UgygBuhLey_h6t9bEfV4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'bro when will you post the the next video',
#   'Comment_Author': '@vigneshwaran1928',
#   'Comment_Published': '2024-01-14T08:33:43Z'},
#  {'Comment_Id': 'Ugzmv-9fk6IBl8Pv_zB4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Which value i get into insurance folders sir',
#   'Comment_Author': '@gamingworld5179',
#   'Comment_Published': '2024-01-08T18:23:15Z'},
#  {'Comment_Id': 'Ugzlf7ygr24hVN9f19N4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'C:\\\\Users\\\\vignesh\\\\Desktop\\\\CAPSTONE Projects\\\\phone pe\\\\Phone Pe Ad(720P_HD).mp4<br>C:\\\\Users\\\\vignesh\\\\Desktop\\\\CAPSTONE Projects\\\\phone pe\\\\PhonePe Motion Graphics(720P_HD).mp4&quot;<br>C:\\\\Users\\\\vignesh\\\\Desktop\\\\CAPSTONE Projects\\\\phone pe\\\\PhonePe Motion Graphics(720P_HD)_2.mp4<br><br>anna intha 3 links la enna mp4 vaechirukeenga nu sonna romba helpfull aaa irrukum pls anna',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-01-08T12:05:29Z'},
#  {'Comment_Id': 'Ugx_qN72WsDhaXHXv614AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Anna pls upload the rest ,and also I assume u r a student of guvi.unga experience guvi la eppadi nu oru video podunga',
#   'Comment_Author': '@pretisherine6025',
#   'Comment_Published': '2024-01-07T09:35:03Z'},
#  {'Comment_Id': 'UgzAau6M11QGWeLA_pt4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Bro next step for project videos upload panuga please',
#   'Comment_Author': '@nitish08',
#   'Comment_Published': '2024-01-05T13:32:47Z'},
#  {'Comment_Id': 'UgzgBzrRkX-nifY6Va54AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Bro pls upload the next step process to complete the project',
#   'Comment_Author': '@user-kc4ec9pu1t',
#   'Comment_Published': '2024-01-02T11:16:01Z'},
#  {'Comment_Id': 'Ugyg1CyzMkfBUGHA1jt4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Bro what&#39;s your GitHub name',
#   'Comment_Author': '@gamingworld5179',
#   'Comment_Published': '2023-12-27T09:57:12Z'},
#  {'Comment_Id': 'Ugz9knIFKg1HpA3HgFZ4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'live eveluaton session tamil la explain pannalama illa english matum thana',
#   'Comment_Author': '@abinashs8852',
#   'Comment_Published': '2023-12-21T07:29:56Z'},
#  {'Comment_Id': 'Ugwf24z-S_Fpzjfklal4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'When will you add the next video',
#   'Comment_Author': '@user-tp7li5ig5s',
#   'Comment_Published': '2023-12-18T05:50:51Z'},
#  {'Comment_Id': 'UgzbVubHjw3Hj_VGIJV4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Pls post all videos in this project kindly post soon all videos bro😢',
#   'Comment_Author': '@akakash1372',
#   'Comment_Published': '2023-12-17T11:20:28Z'},
#  {'Comment_Id': 'Ugzbt6kJrOLEcIg6Wdx4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Bro next video epo bro varum',
#   'Comment_Author': '@user-cq4hq8wr3z',
#   'Comment_Published': '2023-12-16T09:13:25Z'},
#  {'Comment_Id': 'Ugy0rOj6DtNgWMgrxLZ4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Bro next video upload panunga',
#   'Comment_Author': '@Mr_MrsAjiSanju',
#   'Comment_Published': '2023-12-16T04:02:14Z'},
#  {'Comment_Id': 'Ugy4eIYFc_3tjZc1WPF4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Bro full play list upload',
#   'Comment_Author': '@sk_shady',
#   'Comment_Published': '2023-12-16T03:05:49Z'},
#  {'Comment_Id': 'UgwYhmtdtE1rzeEVyMh4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'bro one doubt plotly is not open in vs code how you get that plotly pls share me link how to get that i am struck in last part so....',
#   'Comment_Author': '@HUGGIVIKRAM',
#   'Comment_Published': '2023-12-12T17:06:59Z'},
#  {'Comment_Id': 'UgwA5jJCdRALJ18F0_J4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Need next video',
#   'Comment_Author': '@anumohanvadivel81',
#   'Comment_Published': '2023-12-11T17:54:59Z'},
#  {'Comment_Id': 'Ugx2NQj2Cz_1gV6PSVl4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'bro 1 doubt  all 6 dataframe we have done, then after we go to sql and geo map part or somthing we may do before entering sql and geo map part',
#   'Comment_Author': '@HUGGIVIKRAM',
#   'Comment_Published': '2023-12-09T14:52:25Z'},
#  {'Comment_Id': 'Ugy_qmlGHvbyLfK0zwN4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'When you will upload… SQL part and GEO MAP visualisation part.please upload as soon as possible bro',
#   'Comment_Author': '@sriramsudhakar316',
#   'Comment_Published': '2023-12-06T02:55:42Z'},
#  {'Comment_Id': 'UgxYV7SyFWBWAnQ3m294AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'How to open in github in your profile bro',
#   'Comment_Author': '@mohanapriya1882',
#   'Comment_Published': '2023-12-05T04:39:38Z'},
#  {'Comment_Id': 'UgwyJvfzD2L3MxnLKOt4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'How to get you github bro?',
#   'Comment_Author': '@EdhuvumKedaikala',
#   'Comment_Published': '2023-12-03T18:09:21Z'},
#  {'Comment_Id': 'Ugykd0Y6oD3wiJXG5dx4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Waiting for upcoming video sir',
#   'Comment_Author': '@mperumal726',
#   'Comment_Published': '2023-11-27T05:14:26Z'},
#  {'Comment_Id': 'Ugy0uAUpYBZsOp5QcV94AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Bro bar chart and map are not visible in streamlit bro while using your GitHub link Phone pe pulse data code',
#   'Comment_Author': '@arunbala7127',
#   'Comment_Published': '2023-11-26T08:44:26Z'},
#  {'Comment_Id': 'UgwlmWJWfA6EsiF0Wsh4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'in path 5 and path 6 i am getting keyerror with pincode if i use try except the in dataframe i am getting only the header names not the data...could you please help me out with this',
#   'Comment_Author': '@sakthiviji2023',
#   'Comment_Published': '2023-11-25T12:14:05Z'},
#  {'Comment_Id': 'UgwP-D6UKKoPrJn6Gv54AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'bro, how many videos are more able to complete in 4/5 days?',
#   'Comment_Author': '@naveenkumar-rb8rm',
#   'Comment_Published': '2023-11-23T13:44:29Z'},
#  {'Comment_Id': 'UgwSp7JRWZuE2R2vS_Z4AaABAg',
#   'Video_Id': 'Bqgjq6NGL4c',
#   'Comment_Text': 'Thank you so much',
#   'Comment_Author': '@renugadevichakkarai6111',
#   'Comment_Published': '2023-11-23T11:37:47Z'},
#  {'Comment_Id': 'UgxYnrgxLkWdoaqZCoJ4AaABAg',
#   'Video_Id': 'BzU_VaoE7OI',
#   'Comment_Text': 'Bro enaku aggregated la insurance also iruku',
#   'Comment_Author': '@rajgowthamk2973',
#   'Comment_Published': '2024-02-17T13:43:00Z'},
#  {'Comment_Id': 'Ugwqh021BgplKfiH6Jx4AaABAg',
#   'Video_Id': 'BzU_VaoE7OI',
#   'Comment_Text': 'Bro map kulla state folder miss aagudhu bro',
#   'Comment_Author': '@phoorneshmurali6441',
#   'Comment_Published': '2023-12-18T08:31:52Z'},
#  {'Comment_Id': 'Ugw_yOJntYmpq7wH5c94AaABAg',
#   'Video_Id': 'BzU_VaoE7OI',
#   'Comment_Text': 'Thank you so much for your knowledge sharing',
#   'Comment_Author': '@renugadevichakkarai6111',
#   'Comment_Published': '2023-11-22T18:28:26Z'},
#  {'Comment_Id': 'UgzpynbN4Cqa4PcTVLd4AaABAg',
#   'Video_Id': 'LuJq26q6iWw',
#   'Comment_Text': 'super than teachers',
#   'Comment_Author': '@swamyjs',
#   'Comment_Published': '2024-01-09T09:14:39Z'},
#  {'Comment_Id': 'Ugzk9UigZdKGN_7-uGJ4AaABAg',
#   'Video_Id': 'LuJq26q6iWw',
#   'Comment_Text': 'you gave this directory / variable while creating path1 <br>agg_tran_list = os.listdir(path1) <br>do we need to create for agg_user_list i.e.for path 2 ???  can you pls clarify',
#   'Comment_Author': '@nithukatkar5893',
#   'Comment_Published': '2023-11-22T17:58:58Z'},
#  {'Comment_Id': 'UgzimPeaoeR3sAhGcaB4AaABAg',
#   'Video_Id': 'LuJq26q6iWw',
#   'Comment_Text': 'Thanks lot for your video',
#   'Comment_Author': '@renugadevichakkarai6111',
#   'Comment_Published': '2023-11-22T16:39:24Z'},
#  {'Comment_Id': 'UgwNsJaG6UZJ7Kc2A7J4AaABAg',
#   'Video_Id': 'LuJq26q6iWw',
#   'Comment_Text': 'hi bro. i need a help bro . same project tha panitu eruka eppa na map_user data etuthutu eruka ana athula slicing use aga matanguthu D[&quot;data&quot;][&quot;hoverData&quot;] ethuku mela ovoru line laium different data eruku athu epti slicing pandrathu bro<br>konjam solringala',
#   'Comment_Author': '@user-et5ii3fj1b',
#   'Comment_Published': '2023-11-21T13:55:05Z'},
#  {'Comment_Id': 'UgyqLPMM6WI1dMZApBZ4AaABAg',
#   'Video_Id': 'LuJq26q6iWw',
#   'Comment_Text': 'Bro as a data science engineer aaga ,python data structures and algorithms requirements iruka?',
#   'Comment_Author': '@mperumal726',
#   'Comment_Published': '2023-11-21T13:52:06Z'},
#  {'Comment_Id': 'Ugz-TYdlCZlzVy9_zZZ4AaABAg',
#   'Video_Id': 'DIrc-tFOSrk',
#   'Comment_Text': 'super explanation better than teachers',
#   'Comment_Author': '@swamyjs',
#   'Comment_Published': '2024-01-09T08:34:55Z'},
#  {'Comment_Id': 'Ugw2fQQgLsoBVppK35p4AaABAg',
#   'Video_Id': 'DIrc-tFOSrk',
#   'Comment_Text': 'Bro import pandas as pd run panna no module error varuthu',
#   'Comment_Author': '@Kuttalam1602',
#   'Comment_Published': '2024-01-06T06:39:57Z'},
#  {'Comment_Id': 'UgzdRxJrSce4Abz2xCx4AaABAg',
#   'Video_Id': 'DIrc-tFOSrk',
#   'Comment_Text': 'Bro why there are 2 files in your GitHub repository?? Can you please explain how to get the required result using those 2 code files',
#   'Comment_Author': '@sk_shady',
#   'Comment_Published': '2023-12-19T06:17:38Z'},
#  {'Comment_Id': 'UgwE7VGFDXAsE9ZlHTN4AaABAg',
#   'Video_Id': 'DIrc-tFOSrk',
#   'Comment_Text': 'hi bro when will u upload the remaining videos?',
#   'Comment_Author': '@user-ls2fu8tq6z',
#   'Comment_Published': '2023-11-21T06:01:37Z'},
#  {'Comment_Id': 'UgxyKbICVzEtQUBRPX54AaABAg',
#   'Video_Id': 'DIrc-tFOSrk',
#   'Comment_Text': 'is this project completed or more videos to come',
#   'Comment_Author': '@naveenkumar-rb8rm',
#   'Comment_Published': '2023-11-20T12:46:51Z'},
#  {'Comment_Id': 'UgwHWjbcAfOtGGP2zYB4AaABAg',
#   'Video_Id': 'DIrc-tFOSrk',
#   'Comment_Text': 'How many videos will be there to complete this project',
#   'Comment_Author': '@aravindhanraj2583',
#   'Comment_Published': '2023-11-20T05:41:20Z'},
#  {'Comment_Id': 'UgxuDpWe_P3r4TdD0pp4AaABAg',
#   'Video_Id': 'DIrc-tFOSrk',
#   'Comment_Text': 'Thank you so much',
#   'Comment_Author': '@renugadevichakkarai6111',
#   'Comment_Published': '2023-11-18T12:30:53Z'},
#  {'Comment_Id': 'UgzHZBoyUwaBW0W1Ve54AaABAg',
#   'Video_Id': 'DIrc-tFOSrk',
#   'Comment_Text': 'bro, i have same project. can you make the video of complete project.',
#   'Comment_Author': '@user-bv2fy5hm6e',
#   'Comment_Published': '2023-11-18T06:09:07Z'},
#  {'Comment_Id': 'UgxJV9couL2bsZLSrJZ4AaABAg',
#   'Video_Id': 'iytmvBg26Vk',
#   'Comment_Text': 'shall i mail you  first line itself error fatal not in a git directory',
#   'Comment_Author': '@Manikutty',
#   'Comment_Published': '2024-02-15T12:22:08Z'},
#  {'Comment_Id': 'Ugy8FkIcF3E2k1pxQ_d4AaABAg',
#   'Video_Id': 'iytmvBg26Vk',
#   'Comment_Text': 'hi bro... y u didnt update the videos for this project?',
#   'Comment_Author': '@user-ls2fu8tq6z',
#   'Comment_Published': '2024-01-05T02:53:14Z'},
#  {'Comment_Id': 'UgzNkk-ltA0S6EvFAsJ4AaABAg',
#   'Video_Id': 'iytmvBg26Vk',
#   'Comment_Text': 'Bro please upload all videos bro',
#   'Comment_Author': '@sk_shady',
#   'Comment_Published': '2023-12-11T05:48:57Z'},
#  {'Comment_Id': 'Ugw7pldDXnwQRnnhjC14AaABAg',
#   'Video_Id': 'iytmvBg26Vk',
#   'Comment_Text': 'hi bro.. biz card extraction project panniyacha??',
#   'Comment_Author': '@user-ls2fu8tq6z',
#   'Comment_Published': '2023-12-02T11:10:40Z'},
#  {'Comment_Id': 'Ugy_tXUuK1JFbTaEUDl4AaABAg',
#   'Video_Id': 'iytmvBg26Vk',
#   'Comment_Text': 'Super bro❤',
#   'Comment_Author': '@prakash3614',
#   'Comment_Published': '2023-11-19T05:03:17Z'},
#  {'Comment_Id': 'UgxgIxuir7ItDD-sv014AaABAg',
#   'Video_Id': 'iytmvBg26Vk',
#   'Comment_Text': 'Very nice explanation bro ❤we are waiting you will upload many  projects in data science',
#   'Comment_Author': '@mperumal726',
#   'Comment_Published': '2023-11-19T02:32:41Z'},
#  {'Comment_Id': 'Ugz8DLn7f4_kltEiNhd4AaABAg',
#   'Video_Id': 'iytmvBg26Vk',
#   'Comment_Text': 'Error varuthu bro konjam solliringala broo',
#   'Comment_Author': '@amalas1932',
#   'Comment_Published': '2023-11-17T09:51:31Z'},
#  {'Comment_Id': 'UgzKIbG7GQqa_NqZQRt4AaABAg',
#   'Video_Id': 'iytmvBg26Vk',
#   'Comment_Text': 'Hi bro',
#   'Comment_Author': '@amalas1932',
#   'Comment_Published': '2023-11-17T09:50:01Z'},
#  {'Comment_Id': 'UgwCXAQd6UkY9z_F_wV4AaABAg',
#   'Video_Id': 'iytmvBg26Vk',
#   'Comment_Text': 'Hai bro Thank you so much for your next concept.',
#   'Comment_Author': '@renugadevichakkarai6111',
#   'Comment_Published': '2023-11-16T14:50:43Z'},
#  {'Comment_Id': 'UgwnVTYAGL0YqsSuf3p4AaABAg',
#   'Video_Id': 'iytmvBg26Vk',
#   'Comment_Text': 'Superb bro. You explain everything in simplest form thank you.',
#   'Comment_Author': '@user-hl4uh4ux3u',
#   'Comment_Published': '2023-11-16T04:54:38Z'},
#  {'Comment_Id': 'UgxtCpyVWjThqjr2IdJ4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Sooper bro. Thank you.. Because of your videos i have completed my project..<br>While project evaluations what kind of questions they will ask???',
#   'Comment_Author': '@user-jr8ch6sq1o',
#   'Comment_Published': '2024-02-17T19:24:47Z'},
#  {'Comment_Id': 'UgxsR6zoovy7m34YVNl4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'hi bro please upload videos for how to prepare for the placement preparation what important topics have to cover in machine learning. As im new to this field i can&#39;t able to prepare entire topics.',
#   'Comment_Author': '@user-bo3dj4tq2r',
#   'Comment_Published': '2024-02-04T01:19:00Z'},
#  {'Comment_Id': 'UgwETwkx9iPEVNWddpF4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Do u have in english?',
#   'Comment_Author': '@user-mm3mv3kc3h',
#   'Comment_Published': '2024-01-29T07:50:36Z'},
#  {'Comment_Id': 'Ugxufj34vLYDVFeLtlB4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'bro im not getting answer for 4th question in streamlit how to solve that',
#   'Comment_Author': '@user-zs3tl8ol9z',
#   'Comment_Published': '2024-01-05T15:08:58Z'},
#  {'Comment_Id': 'UgzWPVgs_UnhmvIPZlF4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Bro postgresql ku alternative ha sql light use panalama',
#   'Comment_Author': '@poovarasansanthi4979',
#   'Comment_Published': '2023-12-24T06:26:52Z'},
#  {'Comment_Id': 'UgwLx8rfeE-jV_IhRXh4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Anna guvila indha project accept pannika matangala thaniya channel ah filter pandraku stream lit la onnume illa anna.',
#   'Comment_Author': '@user-cq4hq8wr3z',
#   'Comment_Published': '2023-12-20T14:27:26Z'},
#  {'Comment_Id': 'Ugzi47UqsMO4i_p-hDF4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Bro this is the error i am facing while opening the streamlit function <br>ServerSelectionTimeoutError: SSL handshake failed: <a href="http://ac-5n2v9ir-shard-00-01.feia3xt.mongodb.net:27017/">ac-5n2v9ir-shard-00-01.feia3xt.mongodb.net:27017</a>: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:997) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS:',
#   'Comment_Author': '@jeeviths971',
#   'Comment_Published': '2023-12-20T11:28:04Z'},
#  {'Comment_Id': 'UgxwofhtDXoZQcxA2mh4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Anna thaniya channel ID kutha andha channel ID la ulla details ku 10 queries run aagadha anna channels ah epdi anna filter pandradhu stream lit la live evaluation la revaluation potutanganna oru channel kudutha adhoda details mattum thaniya venun solli',
#   'Comment_Author': '@user-cq4hq8wr3z',
#   'Comment_Published': '2023-12-19T07:35:53Z'},
#  {'Comment_Id': 'UgwmBG_rSSIW7OMMEMl4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'thank you bro..able to complete the project with your help',
#   'Comment_Author': '@rajalakshmidhanraj7644',
#   'Comment_Published': '2023-12-13T12:09:22Z'},
#  {'Comment_Id': 'Ugxrqx8zPY2nE3Vzy8h4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Thanks anna purinju project panniruken all the credit goes to you only anna... thankyou so much anna..',
#   'Comment_Author': '@user-cq4hq8wr3z',
#   'Comment_Published': '2023-12-13T09:38:25Z'},
#  {'Comment_Id': 'Ugw8jSSCE3nXEvJp5rN4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'bro thank you for your support brother, god bless you always',
#   'Comment_Author': '@HUGGIVIKRAM',
#   'Comment_Published': '2023-12-08T11:25:55Z'},
#  {'Comment_Id': 'UgxQYcohisJw1XGBHBx4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Bro video title and channel name is empty want to do',
#   'Comment_Author': '@user-je6vr5ue8u',
#   'Comment_Published': '2023-12-08T06:15:55Z'},
#  {'Comment_Id': 'UgwM9qraCc8hChoNoqN4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'bro total_videos whare we mentioned in query 2 that showing total_videos not exist',
#   'Comment_Author': '@HUGGIVIKRAM',
#   'Comment_Published': '2023-12-07T17:36:27Z'},
#  {'Comment_Id': 'UgxZ2RzQLOgK5fseJ3J4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'bro while we updating question and answers in dataframe in vs code  i am getting error df is not defined error  bro what is the mistake i have done',
#   'Comment_Author': '@HUGGIVIKRAM',
#   'Comment_Published': '2023-12-06T18:14:15Z'},
#  {'Comment_Id': 'UgyWEkM49h4TeCHia6l4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'bro can  how to clear playlists duplicate in sql (i can&#39;t get streamlit web duplicate key error bro) in doubt clarification session they are also get confused and not solved my querry so.. help get out of this bro',
#   'Comment_Author': '@HUGGIVIKRAM',
#   'Comment_Published': '2023-12-05T18:01:34Z'},
#  {'Comment_Id': 'UgxD0R9_dkrlSRPoW054AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'bro in capstone we have to submit the code or github url we have to paste?',
#   'Comment_Author': '@user-ls2fu8tq6z',
#   'Comment_Published': '2023-11-19T14:25:46Z'},
#  {'Comment_Id': 'UgzSzJ4Bd5-oEwGMEel4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Bro How can I contact you? I can&#39;t able to msg in linked profile. Please give any other solution.',
#   'Comment_Author': '@kaviyavarshikaviyavarshi5121',
#   'Comment_Published': '2023-11-18T04:05:47Z'},
#  {'Comment_Id': 'UgxAdj3rkEHjnpfnFgB4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Sql questions query ya run panna Internal Error (Unread result found) nu varuthu bro',
#   'Comment_Author': '@kaviyavarshikaviyavarshi5121',
#   'Comment_Published': '2023-11-16T15:44:55Z'},
#  {'Comment_Id': 'UgzR6jqoERY6YTzW1394AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Bro mysql la video table create paniten, but athula values Insert aaga matithu Insert aagumbothu Error varuthu',
#   'Comment_Author': '@kaviyavarshikaviyavarshi5121',
#   'Comment_Published': '2023-11-14T04:20:07Z'},
#  {'Comment_Id': 'UgzhZRUZ2QesfvyiJTF4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Bro please explain phonepe project give another playlist 😂 ur video are easily understandable',
#   'Comment_Author': '@nishanthvijay2148',
#   'Comment_Published': '2023-11-11T16:25:11Z'},
#  {'Comment_Id': 'UgzFJCYXq53WxOzsgah4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Bro how to contact you',
#   'Comment_Author': '@arjunmech9834',
#   'Comment_Published': '2023-11-11T13:00:54Z'},
#  {'Comment_Id': 'UgyhXP8pfPzwJJlg0Bx4AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Bro im data science student in guvi how can i contact you',
#   'Comment_Author': '@vijayapriyadarshini5472',
#   'Comment_Published': '2023-11-11T12:35:03Z'},
#  {'Comment_Id': 'UgyNVZvvtGhXMw10bV94AaABAg',
#   'Video_Id': 'Lut7ISPuUew',
#   'Comment_Text': 'Thanks bor',
#   'Comment_Author': '@renugadevichakkarai6111',
#   'Comment_Published': '2023-11-11T02:51:54Z'},
#  {'Comment_Id': 'UgzedzsOEgmLSbFuTxt4AaABAg',
#   'Video_Id': 'OW6S10NFfWU',
#   'Comment_Text': 'If I done the code from your channel they will reject the projects...even my project also they rejected they told one of our student done this in YouTube channel... people doing the code by seeing that so we don&#39;t accept it nu soldranga',
#   'Comment_Author': '@saranyasweety9480',
#   'Comment_Published': '2024-02-22T11:52:13Z'},
#  {'Comment_Id': 'UgyTH_sAYeJkhWF1mLF4AaABAg',
#   'Video_Id': 'OW6S10NFfWU',
#   'Comment_Text': 'I gave if channel_id in ch_ids even also the data stored to mongodb why',
#   'Comment_Author': '@sunilkumara8689',
#   'Comment_Published': '2024-02-07T14:51:45Z'},
#  {'Comment_Id': 'UgwJ9vPe8Dabk4ZtbER4AaABAg',
#   'Video_Id': 'OW6S10NFfWU',
#   'Comment_Text': 'streamlit run agitu but brower la view agala ?',
#   'Comment_Author': '@abinashs8852',
#   'Comment_Published': '2023-12-12T07:45:01Z'},
#  {'Comment_Id': 'UgzEXlDEuD8BrHFczL14AaABAg',
#   'Video_Id': 'OW6S10NFfWU',
#   'Comment_Text': 'Bro streamlit run kudutha welcome to streamlit nu varudhu localhost varala bro mail id kekkudhu bro if you&#39;d like to receive helpful onboarding emails, otherwise, leave this field blank nu vandhu email kekudhu bro idhu enna pandradhu',
#   'Comment_Author': '@user-cq4hq8wr3z',
#   'Comment_Published': '2023-12-12T06:08:12Z'},
#  {'Comment_Id': 'Ugy7F44_AVW1KxojQYl4AaABAg',
#   'Video_Id': 'OW6S10NFfWU',
#   'Comment_Text': 'Its Mandatory to  create. py file Bro or we can see in .ipynb',
#   'Comment_Author': '@user-je6vr5ue8u',
#   'Comment_Published': '2023-12-06T05:05:21Z'},
#  {'Comment_Id': 'UgwHrZ5BK550rzoX8Gl4AaABAg',
#   'Video_Id': 'OW6S10NFfWU',
#   'Comment_Text': 'Channel id error brother for stramlit app',
#   'Comment_Author': '@sk_shady',
#   'Comment_Published': '2023-11-23T04:04:50Z'},
#  {'Comment_Id': 'UgwNZfkY_N3YdSzdlrZ4AaABAg',
#   'Video_Id': 'OW6S10NFfWU',
#   'Comment_Text': 'bro final part eppo?',
#   'Comment_Author': '@itshari6901',
#   'Comment_Published': '2023-11-10T07:20:28Z'},
#  {'Comment_Id': 'Ugy4d00oCsjMtPRLbkx4AaABAg',
#   'Video_Id': 'OW6S10NFfWU',
#   'Comment_Text': 'Thank you bro. I have seen all your videos. Very useful and even absolute beginning can understand it. Thank you bro',
#   'Comment_Author': '@user-hl4uh4ux3u',
#   'Comment_Published': '2023-11-10T04:54:34Z'},
#  {'Comment_Id': 'Ugy74U8PA_2cWXaNOuB4AaABAg',
#   'Video_Id': 'OW6S10NFfWU',
#   'Comment_Text': 'That&#39;s bro',
#   'Comment_Author': '@renugadevichakkarai6111',
#   'Comment_Published': '2023-11-10T03:00:44Z'},
#  {'Comment_Id': 'Ugyxi_3KfA4YSvdNsud4AaABAg',
#   'Video_Id': 'ipSL33FOS30',
#   'Comment_Text': 'bro enakku upload pannum bodhu more than 16mb nu vardhu so mongo db la upload panna mudila.',
#   'Comment_Author': '@danvathdarshan1426',
#   'Comment_Published': '2024-02-17T09:57:57Z'},
#  {'Comment_Id': 'UgymZrQd7pN6H9EP9xN4AaABAg',
#   'Video_Id': 'ipSL33FOS30',
#   'Comment_Text': 'bro what about -- ServerSelectionTimeoutError               Traceback (most recent call last)',
#   'Comment_Author': '@jeeviths971',
#   'Comment_Published': '2023-12-20T10:46:32Z'},
#  {'Comment_Id': 'Ugz-mOxlMfrBsf4TYLV4AaABAg',
#   'Video_Id': 'ipSL33FOS30',
#   'Comment_Text': 'bro 1 channel videos and comments added in to all channels details and its showing error(UniqueViolation: duplicate key value violates unique constraint &quot;comments_pkey&quot;\r<br>DETAIL:  Key (comment_id)=(UgxM2puLugwhWO9QhhN4AaABAg) already exists) what is solution bro',
#   'Comment_Author': '@HUGGIVIKRAM',
#   'Comment_Published': '2023-12-03T16:20:27Z'},
#  {'Comment_Id': 'UgyL_n7NnGSRo5AHpCN4AaABAg',
#   'Video_Id': 'ipSL33FOS30',
#   'Comment_Text': 'Bro error coming while fetching table in postgresql. Error relation comments foes not exists',
#   'Comment_Author': '@sk_shady',
#   'Comment_Published': '2023-11-22T17:54:54Z'},
#  {'Comment_Id': 'UgxE51CC-Dh9HS8KcDp4AaABAg',
#   'Video_Id': 'ipSL33FOS30',
#   'Comment_Text': 'bro key error:title nu varuthu when i try to run the tables function.. pls help me out',
#   'Comment_Author': '@user-ls2fu8tq6z',
#   'Comment_Published': '2023-11-19T07:40:15Z'},
#  {'Comment_Id': 'Ugw8hdv3fEsIz2SyZpN4AaABAg',
#   'Video_Id': 'ipSL33FOS30',
#   'Comment_Text': 'bro playlist details &quot;None&quot; nu varuthu how to rectify this? pls help mme',
#   'Comment_Author': '@user-ls2fu8tq6z',
#   'Comment_Published': '2023-11-19T04:32:30Z'},
#  {'Comment_Id': 'Ugy1j_45w6J5lGfrlwR4AaABAg',
#   'Video_Id': 'ipSL33FOS30',
#   'Comment_Text': 'Hi bro. error is coming. Request quota exceeded nu.. epdi overcome panradhu..?',
#   'Comment_Author': '@hudsonsylvestor',
#   'Comment_Published': '2023-11-09T16:27:46Z'},
#  {'Comment_Id': 'UgwdllSLgyhDlYSWQVJ4AaABAg',
#   'Video_Id': 'ipSL33FOS30',
#   'Comment_Text': 'bro steamlit part eppo varum bro',
#   'Comment_Author': '@HARIHaran-ug8cz',
#   'Comment_Published': '2023-11-09T11:19:33Z'},
#  {'Comment_Id': 'UgzH1UuZ7LkvrHfr1U14AaABAg',
#   'Video_Id': 'ipSL33FOS30',
#   'Comment_Text': 'Thank you so much bro your channel videos are most useful for me, I learned lots of information  from your videos. Thanks lot',
#   'Comment_Author': '@renugadevichakkarai6111',
#   'Comment_Published': '2023-11-09T05:13:06Z'},
#  {'Comment_Id': 'Ugym6de7VI10_0Ct_QN4AaABAg',
#   'Video_Id': 'ipSL33FOS30',
#   'Comment_Text': 'bro next video upload pannunga',
#   'Comment_Author': '@itshari6901',
#   'Comment_Published': '2023-11-09T04:08:51Z'},
#  {'Comment_Id': 'UgwAHLW6XZLfFvv3hdB4AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'insert agala bro',
#   'Comment_Author': '@sakthisaravanan6370',
#   'Comment_Published': '2024-02-29T11:31:55Z'},
#  {'Comment_Id': 'UgwLzJyCc9uzWEh0b1d4AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'OperationalError: (1241, &#39;Operand should contain 1 column(s)&#39;) facing this error while creating table for videos in MySQL',
#   'Comment_Author': '@pdeva3693',
#   'Comment_Published': '2024-02-28T21:26:36Z'},
#  {'Comment_Id': 'UgwbBdgYu-O33NWubS54AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': '(1292,&quot;Incorrect date time value: &#39;2019-10-01T<a href="https://www.youtube.com/watch?v=QGzhSqyoUbA&amp;t=72788">20:13:08</a>Z&#39; for column &#39;Published_Date&#39; at row1&quot;)',
#   'Comment_Author': '@balajip5653',
#   'Comment_Published': '2024-02-20T17:24:25Z'},
#  {'Comment_Id': 'Ugz_xvLYXaOkOphmaG14AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'Note: People trying with mysql as your rdbms. Change duration datatype( interval) into integers.',
#   'Comment_Author': '@Kevin-nt4eb',
#   'Comment_Published': '2024-02-08T21:40:40Z'},
#  {'Comment_Id': 'Ugw_5ZyKg3dPQoiHukl4AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'keyerror : &quot;Comment_Id&quot; nu vardhu',
#   'Comment_Author': '@danvathdarshan1426',
#   'Comment_Published': '2024-02-07T19:51:51Z'},
#  {'Comment_Id': 'UgzX8hbWeR24IMDuWB54AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'Hello sir mysql la oru thata va drop panna table athey name la again create panna mutiyatha eg:channels ku ra table',
#   'Comment_Author': '@Kuttalam1602',
#   'Comment_Published': '2024-02-06T00:41:03Z'},
#  {'Comment_Id': 'Ugw6U1iFP_u_Ij8-1xF4AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'naa mysql workbench use panra bro<br>videos data insert agaa matangathu bro<br>OperationalError: (1241, &#39;Operand should contain 1 column(s)&#39;<br>naa nalla check pannita',
#   'Comment_Author': '@ponishav2647',
#   'Comment_Published': '2024-01-17T11:50:19Z'},
#  {'Comment_Id': 'UgxuyQRIL0QO1R8jPyJ4AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'Hi when i run in vs code for video table its running but in postgres only table is created video details is not showing please help me already date is exceeded.',
#   'Comment_Author': '@harifakhan2213',
#   'Comment_Published': '2024-01-09T09:31:12Z'},
#  {'Comment_Id': 'UgwrKjtKs0q8bkRcMe14AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'Bro im getting cant adapt type dict in the cursor.execute(insert_query , values) in creating the table for videos how to resolve it',
#   'Comment_Author': '@sharans4468',
#   'Comment_Published': '2024-01-04T11:49:01Z'},
#  {'Comment_Id': 'Ugyny64ir1TKNCtf6BJ4AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'error varudhu bro',
#   'Comment_Author': '@infantandrew1425',
#   'Comment_Published': '2023-12-28T18:08:49Z'},
#  {'Comment_Id': 'Ugz3gjgrn_ev7qDcpDF4AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'Bro am getting keyError for &#39;video information &#39; as well as for &#39;comment information&#39; when fledging details from mongodb. Kindly assist me please 🙏',
#   'Comment_Author': '@parthibanban2162',
#   'Comment_Published': '2023-12-21T06:00:02Z'},
#  {'Comment_Id': 'Ugw_uUvmj9p0_78JclR4AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'Bro  unique violation error showing',
#   'Comment_Author': '@pradeepanbaskar9663',
#   'Comment_Published': '2023-12-14T16:17:25Z'},
#  {'Comment_Id': 'Ugw7J2IbN5qhdtPG6op4AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'Sir oru playlist id oda details mattumdhan table ku vandhuruku.edhunal sir',
#   'Comment_Author': '@user-cq4hq8wr3z',
#   'Comment_Published': '2023-12-06T19:37:58Z'},
#  {'Comment_Id': 'UgxTq3denZnpNwWQFE94AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'Getting error for mentioning interval, instead of interval &quot;TIME&quot; is correct',
#   'Comment_Author': '@sumapradhi1',
#   'Comment_Published': '2023-12-05T08:51:28Z'},
#  {'Comment_Id': 'UgzEusghguBBeRDYEHR4AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'bro also, we need to add one more function for date and time.  For some channels the date time format is different. so we need to write to covert it: df1[&#39;PublishedAt&#39;] = pd.to_datetime(df1[&#39;PublishedAt&#39;]).dt.strftime(&#39;%Y-%m-%d %H:%M:%S&#39;)',
#   'Comment_Author': '@sumapradhi1',
#   'Comment_Published': '2023-12-05T08:27:21Z'},
#  {'Comment_Id': 'UgypeTjCvxoW9qotUw94AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'for index function - pylance error is coming',
#   'Comment_Author': '@sumapradhi1',
#   'Comment_Published': '2023-12-05T08:24:41Z'},
#  {'Comment_Id': 'UgzjXZM5I_4fsRISqq54AaABAg',
#   'Video_Id': 'QGzhSqyoUbA',
#   'Comment_Text': 'bro i am getting programme error &#39;cant adpt type dict&#39;(bcoz i have updated all information without &quot;like&quot; coulmn its ok or not bro',
#   'Comment_Author': '@HUGGIVIKRAM',
#   'Comment_Published': '2023-12-02T14:27:32Z'},
# ...
#   'Comment_Author': '@rajeshwarir2255',
#   'Comment_Published': '2024-01-12T15:06:38Z'},
#  {'Comment_Id': 'Ugx0BnfqOhRpyPfveml4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Type error: got an unexpected kayword argument playlist Id',
#   'Comment_Author': '@balajip5653',
#   'Comment_Published': '2023-12-20T16:52:20Z'},
#  {'Comment_Id': 'Ugz24RNQ1WMibuju9Yp4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Bro',
#   'Comment_Author': '@balajip5653',
#   'Comment_Published': '2023-12-20T16:51:20Z'},
#  {'Comment_Id': 'UgxgOnoi2pxn-StmauB4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Bro eanaku eantha please la error varuthu',
#   'Comment_Author': '@poovarasansanthi4979',
#   'Comment_Published': '2023-12-03T07:25:57Z'},
#  {'Comment_Id': 'UgxwZEHN1CLZpQovKq94AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Hi bro,<br>Playlist = Playlist_Id <br>If I set this I am getting &quot;TypeError: Got an unexpected keyword argument Playlist&quot; <br>please help me on this',
#   'Comment_Author': '@shafathali6345',
#   'Comment_Published': '2023-11-29T18:57:45Z'},
#  {'Comment_Id': 'Ugzujr1IQtYuUEVfT2t4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Hi bro oru program ah save pannitu next codings ah continue panna error varudhunga',
#   'Comment_Author': '@mohanapriya1882',
#   'Comment_Published': '2023-11-28T14:20:10Z'},
#  {'Comment_Id': 'Ugx3V5F4pCLDoQMLxEB4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Helo bro enaku output varuthu but only 50 output tha varuthu',
#   'Comment_Author': '@user-fs9ew4rr2m',
#   'Comment_Published': '2023-11-27T12:15:20Z'},
#  {'Comment_Id': 'UgzBUxJ1mOuzZz875yx4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Hello bro, na channel id la kuduthu excute panniten excute aguthu but channel id output agala',
#   'Comment_Author': '@user-fs9ew4rr2m',
#   'Comment_Published': '2023-11-27T11:58:05Z'},
#  {'Comment_Id': 'UgzardM65D9ZNgVJ8b94AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Hi, final output is excute but not show id',
#   'Comment_Author': '@user-fs9ew4rr2m',
#   'Comment_Published': '2023-11-27T11:51:55Z'},
#  {'Comment_Id': 'UgzdRQ74DbI6capRnXh4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Bro gai error nu varudhu bro',
#   'Comment_Author': '@phoorneshmurali6441',
#   'Comment_Published': '2023-11-23T11:37:37Z'},
#  {'Comment_Id': 'Ugwg2p6SRRQp3svEgYJ4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Bro keyError:’items’ nu varudhu bro',
#   'Comment_Author': '@phoorneshmurali6441',
#   'Comment_Published': '2023-11-23T11:29:25Z'},
#  {'Comment_Id': 'Ugwdj8EM2kYxn7Er8BR4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'bro even I&#39;m using max 50 results, I didn&#39;t get the results more than 5, also after using next page token, pls help me assist with this issue',
#   'Comment_Author': '@PriyankaRangaswamy-no2iv',
#   'Comment_Published': '2023-11-18T18:13:56Z'},
#  {'Comment_Id': 'UgySFLUCqdOW6uO_IR14AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Finally, for checking when I enter &quot;len(video_ids)&quot; I am getting only 50 counts instead of 468 bro. What should I do?I did exactly as you told.',
#   'Comment_Author': '@sneham7959',
#   'Comment_Published': '2023-11-14T18:05:12Z'},
#  {'Comment_Id': 'UgzaLQqPmY-En9yXAo14AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'unga videos simply super...coding theriyamalea coding panren...need ur support..',
#   'Comment_Author': '@vasuntharajr79',
#   'Comment_Published': '2023-11-09T16:22:45Z'},
#  {'Comment_Id': 'UgzNvk9kxQTh6hE3KuB4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'hi@datasciencetamil enaku type error nu varuthu bro...couldnt get it...ena panrathu',
#   'Comment_Author': '@vasuntharajr79',
#   'Comment_Published': '2023-11-09T16:19:57Z'},
#  {'Comment_Id': 'Ugxzz8_vi-BwgUUiIld4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'How to extract information about different channels in one project?',
#   'Comment_Author': '@pranavbhawane7591',
#   'Comment_Published': '2023-11-05T14:58:45Z'},
#  {'Comment_Id': 'UgwM3WBFHHAUHglqllB4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'bro next_page_token=none potu erukurom? none ah erukapothu epdi funcation ahkuthu bro. kjm explain pana mudiuma?',
#   'Comment_Author': '@naren.j2177',
#   'Comment_Published': '2023-11-01T09:35:39Z'},
#  {'Comment_Id': 'UgxYRzFl6wj0JnZNXop4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Put the continuous videos',
#   'Comment_Author': '@thanusharamesh9004',
#   'Comment_Published': '2023-10-25T03:25:03Z'},
#  {'Comment_Id': 'UgwCbrpozYqVNqJrAet4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Mongodb la epdi upload panrathunu video podunga bro',
#   'Comment_Author': '@suvalakshmiv2057',
#   'Comment_Published': '2023-10-22T06:39:47Z'},
#  {'Comment_Id': 'UgxLnXytWeDGcSctXKR4AaABAg',
#   'Video_Id': '2cyfmA-R-Uw',
#   'Comment_Text': 'Bro streamlit epdi pandrathu video poduga bro',
#   'Comment_Author': '@adadhi4094',
#   'Comment_Published': '2023-10-21T07:17:54Z'},
#  {'Comment_Id': 'UgyH41gIotkzgb5__2p4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'Hi bro if i give &quot;from googleapiclient.discovery import build &quot; it is showing as reportmissingimports i cannot proceed further',
#   'Comment_Author': '@user-rs1ph1up2k',
#   'Comment_Published': '2024-02-21T19:43:31Z'},
#  {'Comment_Id': 'Ugzbr5j46P6P7udMCcF4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'Bro output epdi next next vanthathu.. enaku varala.. na Jupiter notebook use pantren.. knjm sollunga bro',
#   'Comment_Author': '@rajinandagopal1986',
#   'Comment_Published': '2024-02-20T14:48:25Z'},
#  {'Comment_Id': 'UgxvgHDK3tDPpVOg31x4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'I got error no module found. I tried many times but I could not find problem. Could you please help me on this',
#   'Comment_Author': '@wajeedwajeed9459',
#   'Comment_Published': '2024-02-19T11:38:33Z'},
#  {'Comment_Id': 'UgyRfYgAxN_jo5qE8514AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'bro unga mail id sollunga please',
#   'Comment_Author': '@Nishnath-uk5kt',
#   'Comment_Published': '2024-02-09T09:09:52Z'},
#  {'Comment_Id': 'UgxrZa2kNaja6HN9SXt4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'bro data science project podunga',
#   'Comment_Author': '@aravindr7422',
#   'Comment_Published': '2024-01-26T00:12:42Z'},
#  {'Comment_Id': 'UgydywGiI18qutrr7094AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'Can I do this in jupyter notebook ?',
#   'Comment_Author': '@johnbosco9287',
#   'Comment_Published': '2024-01-12T04:33:57Z'},
#  {'Comment_Id': 'UgxBSoPvGlcA2kwP6KR4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'I am getting an error while using the from googleapiclient.discovery import build, could you help me brother',
#   'Comment_Author': '@preethisomu2006',
#   'Comment_Published': '2024-01-06T18:33:07Z'},
#  {'Comment_Id': 'UgzhpLDEUN7kNE6WkKt4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'Bro, Actually I couldn&#39;t get the response bro. romba nerama process agitey erukku.. api response ey varala run aagitey erukku bro. ena pandrathu',
#   'Comment_Author': '@sathanj4965',
#   'Comment_Published': '2023-12-30T06:53:53Z'},
#  {'Comment_Id': 'UgzGnFuN79tFk_YsrgR4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'Sir, i am getting module not found error and it is 1st cell',
#   'Comment_Author': '@sandhyareddy5762',
#   'Comment_Published': '2023-12-04T11:15:52Z'},
#  {'Comment_Id': 'Ugx4XsZPLNqeNoobGmF4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'I got a error bro ..Type of error:indices must integers or slices,or not str<br><br>How to pics this ...bro',
#   'Comment_Author': '@sabarir6904',
#   'Comment_Published': '2023-11-30T09:32:46Z'},
#  {'Comment_Id': 'UgzzbEaDoBU2qbErdMh4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=r2sn478BKg4&amp;t=1162">19:22</a> bro eanaku eantha please la error varuthu eana panurathu neinga panna Mathire tha panna but easnku chanals Details varama error inu varuthu bro help panuinga 30 November project tharainum pls',
#   'Comment_Author': '@poovarasansanthi4979',
#   'Comment_Published': '2023-11-28T14:19:39Z'},
#  {'Comment_Id': 'UgxePW8F5tXw_bhk6Cd4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'Neenga pannna intha poroject ah apdi panlama crt ah',
#   'Comment_Author': '@mohanapriya1882',
#   'Comment_Published': '2023-11-27T14:47:47Z'},
#  {'Comment_Id': 'UgxiXdXMOe8U2LoTCwh4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'Hi bro<br><a href="http://www.youtube.com/results?search_query=%23get">#get</a>  channel information  <br>Run error varuthu bro',
#   'Comment_Author': '@VinothKumar-cu7ph',
#   'Comment_Published': '2023-11-25T11:37:32Z'},
#  {'Comment_Id': 'UgwOymMf_98rStzaOxN4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'bro,  I&#39;m getting error when I use def function and I&#39;m getting an error like KeyError: &#39;items&#39;. Please help me on this and I&#39;m using jupyter notebook',
#   'Comment_Author': '@rubasri4957',
#   'Comment_Published': '2023-11-24T05:43:22Z'},
#  {'Comment_Id': 'UgwTsbCC6reeeels43B4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'Thank you so much bro😊which is really really helpful🙏🏻',
#   'Comment_Author': '@kmscjs8364',
#   'Comment_Published': '2023-11-22T20:00:13Z'},
#  {'Comment_Id': 'UgwsVCdhBf7hM3b7q894AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'KeyError: &#39;items&#39; - How to resolve this',
#   'Comment_Author': '@lakshmipraba276',
#   'Comment_Published': '2023-11-22T09:57:03Z'},
#  {'Comment_Id': 'UgxGaf26g2DzYyCjlU94AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'Sir am Getting error in api key connection',
#   'Comment_Author': '@324jasminechristyleo6',
#   'Comment_Published': '2023-11-21T13:44:58Z'},
#  {'Comment_Id': 'UgzQl4VBo_fa9DzUvQp4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'bro couldnt add googleapiclient - it shows No module named &#39;googleapiclient&#39;',
#   'Comment_Author': '@PriyankaRangaswamy-no2iv',
#   'Comment_Published': '2023-11-14T15:18:01Z'},
#  {'Comment_Id': 'UgzvY3Iuq20BpIfiIiF4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'userbis in another person name but my api is in my name if i do in vs code to add python app data its in another name which not able get use api error wat to do in tat is there any video for tat kindly konjam solunga na',
#   'Comment_Author': '@pooja9923',
#   'Comment_Published': '2023-11-13T06:20:57Z'},
#  {'Comment_Id': 'UgwMQnS31S9KeyzydqN4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'api key connection if i put it shows unknown apiname or version it means',
#   'Comment_Author': '@pooja9923',
#   'Comment_Published': '2023-11-12T14:15:44Z'},
#  {'Comment_Id': 'Ugyb4F9U0YqxLGDkuvF4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'sir i get module not found error',
#   'Comment_Author': '@senthamilselvan3045',
#   'Comment_Published': '2023-11-10T06:40:38Z'},
#  {'Comment_Id': 'UgyMprkwuIyVKnIvtLB4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'super bro thank u so much',
#   'Comment_Author': '@Media-dv8nm',
#   'Comment_Published': '2023-11-09T05:07:21Z'},
#  {'Comment_Id': 'Ugwi7KkjVtN37lDy3x54AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'File tokenize plz tell i mailed the photo',
#   'Comment_Author': '@baraneetharanr5916',
#   'Comment_Published': '2023-11-04T19:03:10Z'},
#  {'Comment_Id': 'UgzbFR4LBxewHKypwNR4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'sir...i got a error in return data.... syntax error : invalid syntax',
#   'Comment_Author': '@sanjai_a7179',
#   'Comment_Published': '2023-11-04T17:15:22Z'},
#  {'Comment_Id': 'UgzwW4L5NUdoGVBlK8l4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'bro how to get api key bezo the link you provide is not working',
#   'Comment_Author': '@naren.j2177',
#   'Comment_Published': '2023-10-30T07:45:38Z'},
#  {'Comment_Id': 'UgwZcuV3AxE8gMx2K-t4AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'Bro can we do the same in Google collab?',
#   'Comment_Author': '@dhanushraj2291',
#   'Comment_Published': '2023-10-27T05:53:05Z'},
#  {'Comment_Id': 'UgzdNjFASKaa2x19_714AaABAg',
#   'Video_Id': 'r2sn478BKg4',
#   'Comment_Text': 'i got a error in channel information code',
#   'Comment_Author': '@user-kl2cw8gp9u',
#   'Comment_Published': '2023-10-24T08:49:58Z'},
#  {'Comment_Id': 'UgzrbyLiE1pLByl3XWh4AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'Hi, I am not getting the error message in the terminal bro, Is that mandatory to get the error message',
#   'Comment_Author': '@pamilaarul6125',
#   'Comment_Published': '2024-02-20T18:52:40Z'},
#  {'Comment_Id': 'UgzmedJDAlMtsRNI3gx4AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'Bro intha project final ah streamlit la run aagum pothu new channel id enter panna athoda details collect aagi output tharuma?',
#   'Comment_Author': '@nethraswami9457',
#   'Comment_Published': '2024-02-20T13:32:51Z'},
#  {'Comment_Id': 'UgxpskQF3R5Gi7gswCN4AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'bro. indha project la virtual environment yedhukaga panrom?',
#   'Comment_Author': '@nirmalarajendran396',
#   'Comment_Published': '2024-02-18T13:25:51Z'},
#  {'Comment_Id': 'UgxY9g2xAnXHA-eMCK14AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'Bro please provide subtitles to every video&#39;s',
#   'Comment_Author': '@pratapvesapogu3258',
#   'Comment_Published': '2024-02-17T17:09:29Z'},
#  {'Comment_Id': 'UgxdIinq6n5VS8_uXFB4AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'How to install stream lit in jupyter can you please guide step by step in English?',
#   'Comment_Author': '@user-mm3mv3kc3h',
#   'Comment_Published': '2024-02-11T12:26:49Z'},
#  {'Comment_Id': 'UgwizG09DG8Yr8M9eqt4AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'azhaga explain panirukeenga thambi....vazthukkal',
#   'Comment_Author': '@manojkumaar8221',
#   'Comment_Published': '2024-02-05T17:36:52Z'},
#  {'Comment_Id': 'UgxDlLIu1xnWWKP2atV4AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'Bro entha document link kedaikkuma',
#   'Comment_Author': '@naveenabalamurugan9725',
#   'Comment_Published': '2023-12-27T05:31:13Z'},
#  {'Comment_Id': 'UgwjfCMiEW49fo3MwAt4AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'Bro please assist me on this project i have deadline of 10 days',
#   'Comment_Author': '@parthibanban2162',
#   'Comment_Published': '2023-12-12T03:29:40Z'},
#  {'Comment_Id': 'UgyRHpAaoWPbxGqogWd4AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'How to use SQL in that project',
#   'Comment_Author': '@muthu700',
#   'Comment_Published': '2023-11-26T16:15:06Z'},
#  {'Comment_Id': 'UgxTxbDykEyqQQsAsad4AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'while tying in vs code @this symbol how to change &quot;',
#   'Comment_Author': '@pooja9923',
#   'Comment_Published': '2023-11-22T13:27:58Z'},
#  {'Comment_Id': 'UgxR4MTiscRFc-1qIad4AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'couldnt create environment bro pls assist',
#   'Comment_Author': '@PriyankaRangaswamy-no2iv',
#   'Comment_Published': '2023-11-14T13:48:46Z'},
#  {'Comment_Id': 'UgyOU6rMsn1BtZmYbjN4AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'bro jupyter laium streamlit install pananuma',
#   'Comment_Author': '@user-et5ii3fj1b',
#   'Comment_Published': '2023-11-06T10:43:12Z'},
#  {'Comment_Id': 'UgzKpTwOasD2wXZsLQh4AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'Hi bro please share the instgram or LinkedIn links',
#   'Comment_Author': '@UDSARAVINDAGOKULP',
#   'Comment_Published': '2023-11-04T14:44:33Z'},
#  {'Comment_Id': 'Ugz-b9_-vpME9qwKkj14AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'Are u currently at DS course?',
#   'Comment_Author': '@revanthragult4803',
#   'Comment_Published': '2023-11-03T01:12:58Z'},
#  {'Comment_Id': 'UgxSDS-R4spWqEX_GCt4AaABAg',
#   'Video_Id': 'xBCx4PEZpfo',
#   'Comment_Text': 'can u upload in hindi??',
#   'Comment_Author': '@anjalishinde6460',
#   'Comment_Published': '2023-10-30T08:58:21Z'}]

# %%
###get playlist details

def get_playlist_details(channel_id):
 next_page_token=None
 All_data=[]
 while True:
  request = youtube.playlists().list(
    part='snippet,contentDetails',
    channelId=channel_id,
    maxResults=50,
    pageToken=next_page_token

  )

  response=request.execute()

  for item in response['items']:
    data=dict(Playlist_Id=item['id'],
              Title=item['snippet']['title'],
              Channel_Id=item['snippet']['channelId'],
              Channel_Name=item['snippet']['channelTitle'],
              PublishedAt=item['snippet']['publishedAt'],
              Video_Count=item['contentDetails']['itemCount'])
    All_data.append(data)

  next_page_token=response.get('nextPageToken')
  if next_page_token is None:
   break
 return All_data

# %%
abc=get_playlist_details('UCuI5XcJYynHa5k_lqDzAgwQ')
abc
# Out:
# [{'Playlist_Id': 'PLuo9105K6NLRozcPvyXG4fx3z2-cvXG3G',
#   'Title': 'PhonePe Pulse Data Visualization and Exploration',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Channel_Name': 'Data Science Tamil',
#   'PublishedAt': '2023-11-16T02:20:12Z',
#   'Video_Count': 37},
#  {'Playlist_Id': 'PLuo9105K6NLRe85dP13b0i57AkgyLWOFj',
#   'Title': 'YouTube Data Harvesting and Warehousing',
#   'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ',
#   'Channel_Name': 'Data Science Tamil',
#   'PublishedAt': '2023-10-17T20:13:20Z',
#   'Video_Count': 16}]

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\prajee\appdata\local\programs\python\python311\lib\site-packages (3.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\prajee\appdata\local\programs\python\python311\lib\site-packages (2.9.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
import pandas as pd
import streamlit as st

# %%
client=pymongo.MongoClient("mongodb://jeevitha:Prajee123@ac-a1fmbij-shard-00-00.fl2ujl6.mongodb.net:27017,ac-a1fmbij-shard-00-01.fl2ujl6.mongodb.net:27017,ac-a1fmbij-shard-00-02.fl2ujl6.mongodb.net:27017/?ssl=true&replicaSet=atlas-xacfq8-shard-0&authSource=admin&retryWrites=true&w=majority&appName=Cluster0")

# %%
db=client["youtube_data"]

# %%
def channel_details(channel_id):
    ch_details=get_channel_info(channel_id)
    pl_details= get_playlist_details(channel_id)
    vi_ids=get_videos_ids(channel_id)
    vi_info=get_video_info(vi_ids)
    com_info=get_comment_info(vi_ids)

    collection1=db['youtube_data']
    collection1.insert_one({"channel_information":ch_details,"playlist_information":pl_details,"video_information":vi_info,"comment_information":com_info})


    return "upload completed successfully"

# %%
def channels_table():
    mydb=psycopg2.connect(host="localhost",user="postgres",password="root",
                        database="youtube_details",port="5432")
    cursor=mydb.cursor()

    

    try:
        create_query="""create table channels(channel_name varchar(100) ,
                                                            channel_id varchar(80) primary key,
                                                            subscribers bigint,
                                                            views bigint,
                                                            total_videos int,
                                                            channel_description text,
                                                            playlist_id varchar(80)
                                                            )"""
        cursor.execute(create_query)
        mydb.commit()
    except:
        print('channels table already created') 
        



    ch_list=[]
    db=client["youtube_data"]
    collection1=db["youtube_data"]
    for ch_data in collection1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    
    df=pd.DataFrame(ch_list)



    for index,row in df.iterrows():
        insert_query=''' insert into channels(Channel_Name,
                                            Channel_Id,
                                            Subscribers,
                                            Views,
                                            Total_Videos,
                                            Channel_Description,
                                            Playlist_Id)
                                            
                                            
                                            values(%s,%s,%s,%s,%s,%s,%s)'''

        values=(row['channel_name'],
                row['channel_id'],
                row['subscribers'],
                row['views'],
                row['total_videos'],
                row['channel_description'],
                row['playlist_id'])

        try:
            cursor.execute(insert_query,values)
            mydb.commit()
        except:
            print('channels values are already inserted')

# %%
channels_table()

# %%
ch_list=[]
db=client["youtube_data"]
collection1=db["youtube_data"]
for ch_data in collection1.find({},{"_id":0,"channel_information":1}):
    ch_list.append(ch_data["channel_information"])

df=pd.DataFrame(ch_list)

# %%
df
# Out:
#             channel_name                channel_id subscribers      views  \
# 0  2k Healthy lifestyle   UCEziudKWmyBhkW8nYleaW8A        1450      70880
# 1    Shabarinath Premlal  UCQqmjKQBKQkRbWbSntYJX0Q         199       2070
# 2         Cutest Channel  UCfIVF3nUnQJvR9Xcmg4wEDQ         204      72456
# 3      power of mindset   UCZcyXrwn0Zri6eAhG215AMw         158       4699
# 4         Life of Shmoji  UCvcAi3crny6675g266JxCDQ          20        527
# 5           Life's View💞  UCjAG-F1RXu7nIBzjYmOZMDQ         133      22165
# 6         Inspire Me Now  UC4lQpMReJiQH1DGCJEcmreg           1        146
# 7    Interactive Fitness  UCottV9-6Q4ze0kg0AiCS_gA        1000     239689
# 8     Data Science Tamil  UCuI5XcJYynHa5k_lqDzAgwQ         685      78342
# 9     Priyanka Deshpande  UCNrlHfYLo7s2eoeKEJiJi3Q     1520000  145360551
#
#   total_videos                                channel_description  \
# 0           93  Hai hello guys...🖐️🫰\nThis is sandhiya \nIn th...
# 1            7
# 2            4
# 3           16  keep trying😌think more 🤔work hard💪get the life...
# 4           31  I make videos on whatever I want. Typically st...
# 5           72  Some philosophy with some entertainment with s...
# 6          104  "Welcome to 'InspireMeNow,' your destination f...
# 7          137  Interactive Fitness is your buddy in your fitn...
# 8           43  Dear Brothers and Sisters,\n\n         (Please...
# 9           96
#
#                 playlist_id
# 0  UUEziudKWmyBhkW8nYleaW8A
# 1  UUQqmjKQBKQkRbWbSntYJX0Q
# 2  UUfIVF3nUnQJvR9Xcmg4wEDQ
# 3  UUZcyXrwn0Zri6eAhG215AMw
# 4  UUvcAi3crny6675g266JxCDQ
# 5  UUjAG-F1RXu7nIBzjYmOZMDQ
# 6  UU4lQpMReJiQH1DGCJEcmreg
# 7  UUottV9-6Q4ze0kg0AiCS_gA
# 8  UUuI5XcJYynHa5k_lqDzAgwQ
# 9  UUNrlHfYLo7s2eoeKEJiJi3Q

# %%
def show_channels_table():
    ch_list=[]
    db=client["youtube_data"]
    collection1=db["youtube_data"]
    for ch_data in collection1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    
    df=st.dataframe(ch_list)
    return df

# %%
def playlist_table():
    mydb=psycopg2.connect(host="localhost",user="postgres",password="root",
                        database="youtube_details",port="5432")
    cursor=mydb.cursor()


    create_query="""create table if not exists playlists(Playlist_Id varchar(100)primary key ,
                                                            Title varchar(80) ,
                                                            Channel_Id varchar(100),
                                                            Channel_Name varchar(100),
                                                            PublishedAt timestamp,
                                                            Video_Count int
                                                            )"""
    cursor.execute(create_query)
    mydb.commit()   

    pl_list=[]
    db=client["youtube_data"]
    collection1=db["youtube_data"]
    for pl_data in collection1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
           pl_list.append(pl_data["playlist_information"][i])
            
    df1=pd.DataFrame(pl_list)
    print(pl_list)
    df1

    for index,row in df1.iterrows():
            insert_query=''' insert into playlists(Playlist_Id ,
                                        Title,
                                        Channel_Id,
                                        Channel_Name,
                                        PublishedAt,
                                        Video_Count
                                        )
                                        values(%s,%s,%s,%s,%s,%s)'''


            values=(row['Playlist_Id'],
                    row['Title'],
                    row['Channel_Id'],
                    row['Channel_Name'],
                    row['PublishedAt'],
                    row['Video_Count'])


            try:
                cursor.execute(insert_query,values)
                mydb.commit()
            except:
                print('channels values are already inserted')

# %%
playlist_table()
# Out:
# [{'Playlist_Id': 'PLErROxUrBdIS0c1sN9tJCm5PpiICiGIG-', 'Title': '#minivlogs  #daliyvlog #diteplan #cooking #shortsfeed  #viral #daliyvlog', 'Channel_Id': 'UCEziudKWmyBhkW8nYleaW8A', 'Channel_Name': '2k Healthy lifestyle ', 'PublishedAt': '2023-11-09T16:59:26Z', 'Video_Count': 1}, {'Playlist_Id': 'PLErROxUrBdIQW4flJ2ShFMbyA-c0vIfP2', 'Title': 'My weight lose 7 days challenge', 'Channel_Id': 'UCEziudKWmyBhkW8nYleaW8A', 'Channel_Name': '2k Healthy lifestyle ', 'PublishedAt': '2023-11-07T04:32:40Z', 'Video_Count': 6}, {'Playlist_Id': 'PLa-q1hozZo6qe3dnQ50IdV9DmPrLnA31p', 'Title': 'Basic Ideas about Machine Learning', 'Channel_Id': 'UCQqmjKQBKQkRbWbSntYJX0Q', 'Channel_Name': 'Shabarinath Premlal', 'PublishedAt': '2021-04-30T15:13:04Z', 'Video_Count': 11}, {'Playlist_Id': 'PLYRKF-MmRFI7_AIVJ2UZle6ZdMVj4zoSh', 'Title': 'Fitness Videos', 'Channel_Id': 'UCottV9-6Q4ze0kg0AiCS_gA', 'Channel_Name': 'Interactive Fitness', 'PublishedAt': '2024-02-20T13:07:50Z', 'Video_Count': 7}, {'Playlist_Id': 'PLYRKF-MmRFI5oSBv1EsZ9j9Kqfxd2iSHl', 'Title': 'Your Ultimate Fitness Journey Handbook', 'Channel_Id': 'UCottV9-6Q4ze0kg0AiCS_gA', 'Channel_Name': 'Interactive Fitness', 'PublishedAt': '2024-02-04T16:28:43Z', 'Video_Count': 1}, {'Playlist_Id': 'PLYRKF-MmRFI6vc6F5XDepbCSXDCJjxyFm', 'Title': 'Best Foods to Eat In Your Fitness Journey', 'Channel_Id': 'UCottV9-6Q4ze0kg0AiCS_gA', 'Channel_Name': 'Interactive Fitness', 'PublishedAt': '2024-02-02T06:22:13Z', 'Video_Count': 3}, {'Playlist_Id': 'PLYRKF-MmRFI6RWg1YYcgcsmIPCOjvC5Kk', 'Title': 'Follow Along Workouts', 'Channel_Id': 'UCottV9-6Q4ze0kg0AiCS_gA', 'Channel_Name': 'Interactive Fitness', 'PublishedAt': '2024-01-29T14:53:26Z', 'Video_Count': 12}, {'Playlist_Id': 'PLuo9105K6NLRozcPvyXG4fx3z2-cvXG3G', 'Title': 'PhonePe Pulse Data Visualization and Exploration', 'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ', 'Channel_Name': 'Data Science Tamil', 'PublishedAt': '2023-11-16T02:20:12Z', 'Video_Count': 29}, {'Playlist_Id': 'PLuo9105K6NLRe85dP13b0i57AkgyLWOFj', 'Title': 'YouTube Data Harvesting and Warehousing', 'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ', 'Channel_Name': 'Data Science Tamil', 'PublishedAt': '2023-10-17T20:13:20Z', 'Video_Count': 16}, {'Playlist_Id': 'PLsPanwi_PYe2JEX2pAov_I-WaPQFF7lY9', 'Title': '2020', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2021-01-18T14:14:26Z', 'Video_Count': 1}, {'Playlist_Id': 'PLsPanwi_PYe1GcATCMl1z-66vLbD2zNIb', 'Title': 'Diwali 2020', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-11-15T12:35:55Z', 'Video_Count': 3}, {'Playlist_Id': 'PLsPanwi_PYe2LsMbfO9F9remvPUviGaMY', 'Title': 'Handbag', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-09-29T12:21:23Z', 'Video_Count': 2}, {'Playlist_Id': 'PLsPanwi_PYe0HAOt0wPnr1QIJ91wAoox4', 'Title': 'Beauty', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-09-03T13:31:08Z', 'Video_Count': 3}, {'Playlist_Id': 'PLsPanwi_PYe1HBSS-ovi2hDOyrehR7Ea0', 'Title': 'Namakku Soru Dhaan Mukkiyam', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-09-03T13:30:29Z', 'Video_Count': 6}, {'Playlist_Id': 'PLsPanwi_PYe1XcZku7eEKp9yDlebyNyaj', 'Title': 'Vlog', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-07-27T02:34:23Z', 'Video_Count': 64}, {'Playlist_Id': 'PLsPanwi_PYe1xOzpOTzfSOcpQeY_wab29', 'Title': 'Kelunga Kelunga', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-06-06T17:32:46Z', 'Video_Count': 5}, {'Playlist_Id': 'PLsPanwi_PYe0TRv0U7oRv-9zsVrc8MC3i', 'Title': 'Lockdown Series', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-06-05T20:27:00Z', 'Video_Count': 1}]
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted

# %%
def show_playlist_table():
    pl_list=[]
    db=client["youtube_data"]
    collection1=db["youtube_data"]
    for pl_data in collection1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
           pl_list.append(pl_data["playlist_information"][i])
            
    df=st.dataframe(pl_list)
    return df

# %%
def videos_table():
        mydb=psycopg2.connect(host="localhost",user="postgres",password="root",
                        database="youtube_details",port="5432")
        cursor=mydb.cursor()
    
        create_query="""create table if not exists videos(Channel_Name varchar(100),
                                                        Channel_Id varchar(100),
                                                        Video_Id varchar(30),
                                                        Title varchar(150),
                                                        Tags text,
                                                        Thumbnail varchar(150),
                                                        Description text,
                                                        Published_Date timestamp,
                                                        Duration interval,
                                                        Views bigint,
                                                        Likes bigint,
                                                        Comments int,
                                                        Favorite_Count int,
                                                        Definition varchar(30),
                                                        Caption_Status varchar(50)
                                                        )"""
        cursor.execute(create_query)
        mydb.commit()
      

        vi_list=[]
        db=client["youtube_data"]
        collection1=db["youtube_data"]
        for vi_data in collection1.find({},{"_id":0,"video_information":1}):
                for i in range (len(vi_data["video_information"])):
                   vi_list.append(vi_data["video_information"][i])
        df=pd.DataFrame(vi_list)
        print(vi_list)
        
        print("step 1")
        for index,row in df.iterrows():
                insert_query=''' insert into videos(Channel_Name,
                                                Channel_Id,
                                                Video_Id,
                                                Title,
                                                Tags,
                                                Thumbnail,
                                                Description,
                                                Published_Date,
                                                Duration,
                                                Views,
                                                Likes,
                                                Comments,
                                                Favorite_Count,
                                                Definition,
                                                Caption_Status
                                                )
                                                values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''

                values=(row['Channel_Name'],
                        row['channel_Id'],
                        row['Video_Id'],
                        row['Title'],
                        row['Tags'],
                        row['Thumbnail'],
                        row['Description'],
                        row['Published_Date'],
                        row['Duration'],
                        row['Views'],
                        row['Likes'],
                        row['Comments'],
                        row['Favorite_Count'],
                        row['Definition'],
                        row['Caption_Status'])
                try:
                        cursor.execute(insert_query,values)
                        mydb.commit()
                except:
                    print('channels values are already inserted')

# %%
videos_table()
# Out:
# [{'Channel_Name': '2k Healthy lifestyle ', 'channel_Id': 'UCEziudKWmyBhkW8nYleaW8A', 'Video_Id': 'H7mCOzC2wGo', 'Title': '😋ladiesfinger dryfry  #villagestylefood#ytshortsfeed#shorts#villagecooking#villagestylefood #shorts', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/H7mCOzC2wGo/default.jpg', 'Description': '#cookingchannel #cooking #food #foodnetwork #foodie #foodporn #cookingathome #youtube #cookingvideo #chef #cookingwithlove #cook #cookingtips #youtuber #foodblogger #cookingtime #yummy #cookingclass #cookingshow #instafood #goodeats #recipes #instachef #foodphotography #cookingvideos #personalchef #yummyfood #celebritychef #cheflife #cookingram#homecooking #goodfood #foodstagram #youtubechannel #cookinglife #instagood #love #cookingisfun #cookinglight #delicious #foodlover #kitchenlife #indianfood #cookingwithkids #cookinglove #cookingmama #cookingschool #like #dinner #downhome #catering #cookingclasses #homemade #cookingismypassion #recipe #eater #foodies #cookingdemo #cookingfromscratch #kitchenchronicles#cookingchannel #delicious #foodstagram #youtube #foodphotography #foodblogger #cooking #chef #youtuber #goodfood #cheflife #homecooking #cook #catering #nomnomnom #yummyfood #recipes #goodeats #igfood #culinary #youtubechannel#villagefood #food #foodie #foodphotography #villagelife #indianfood #kerala #foodblogger #village #foodporn #m #mallutraveller #tech #karthiksurya #arjyou #mallu #foodlover #foodstagram #malayalam #malayali #kochi #instafood #comedy #meme #trolls #karikkfresh #karikku #thiruvananthapuram #lulu #funnymalayalam#malayalamtrolls #crazymalayalam #jokes #tc #troll #mention #techtraveleat #trollcompanyofficial #streetfood #foodiesofinstagram #healthyfood #desifood #trollcompany #homemade #february #yummy #fish #valantinesday #nature #traditionalfood #villagefoodfactory #foodlovers #india #chicken #tastyfood #chennaifoodie #photography #delicious #foodpics #southindianfood#villagefood #meme #india #delicious #homemade #healthyfood #foodstagram #foodphotography #comedy #foodgasm #foodblogger #foodlover #kerala #foodpics #fish #foodies #youtuber #jokes #mallu #malayalam #kochi#villagefood #indianfood #february #troll #tastyfood #trolls #assam #lulu #villagelife #desifood #traditionalfood #southindianfood ##villagefood #chennaifoodie #mention #thiruvananthapuram #mallutraveller #malayalamtrolls #karikku #valantinesday #crazymalayalam #villagefood #trollcompany #techtraveleat #karthiksurya #funnymalayalam #villagefoodfactory #', 'Published_Date': '2024-02-20T12:45:01Z', 'Duration': 'PT1M', 'Views': '265', 'Likes': '19', 'Comments': '3', 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}, {'Channel_Name': 'Shabarinath Premlal', 'channel_Id': 'UCQqmjKQBKQkRbWbSntYJX0Q', 'Video_Id': 'aYuCM7hHPAQ', 'Title': 'Turn every setback into a comeback video', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/aYuCM7hHPAQ/default.jpg', 'Description': 'we ll have regular technical updates\n#comeback  #setback', 'Published_Date': '2023-08-28T16:37:46Z', 'Duration': 'PT55S', 'Views': '285', 'Likes': '32', 'Comments': '13', 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}, {'Channel_Name': 'Cutest Channel', 'channel_Id': 'UCfIVF3nUnQJvR9Xcmg4wEDQ', 'Video_Id': 'cBPj0nEjL24', 'Title': '#ninjahattori#ninjahattoriintamil#ninja#hattori#hattoriintamil', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/cBPj0nEjL24/default.jpg', 'Description': '#ninjahattori\n#ninjahattoriintamil\n#ninja\n#hattori\n#hattoriintamil', 'Published_Date': '2022-10-04T05:39:32Z', 'Duration': 'PT12M', 'Views': '451', 'Likes': '8', 'Comments': '0', 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}, {'Channel_Name': 'power of mindset ', 'channel_Id': 'UCZcyXrwn0Zri6eAhG215AMw', 'Video_Id': 'x5vI-U0OunY', 'Title': '#viral #increaseyourvalue#timemanagement #motivational #youtubeshortsvideo  #motivationalspeaker', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/x5vI-U0OunY/default.jpg', 'Des ...
# step 1

# %%
def show_videos_table():
    vi_list=[]
    db=client["youtube_data"]
    collection1=db["youtube_data"]
    for vi_data in collection1.find({},{"_id":0,"video_information":1}):
            for i in range (len(vi_data["video_information"])):
                vi_list.append(vi_data["video_information"][i])
    df=st.dataframe(vi_list)
   
    return df

# %%
def comments_details():
        mydb=psycopg2.connect(host="localhost",user="postgres",password="root",
                            database="youtube_details",port="5432")

        cursor=mydb.cursor()
        
   
        create_query="""create table if not exists comments(Comment_Id varchar(100) primary key,
                                                                Video_Id varchar(50),
                                                                Comment_Text text,
                                                                Comment_Author varchar(150),
                                                                Comment_Published timestamp
                                                                )"""
                                                          
        cursor.execute(create_query)
        mydb.commit()
   

        com_list=[]
        db=client["youtube_data"]
        collection1=db["youtube_data"]
        for com_data in collection1.find({},{"_id":0,"comment_information":1}):
            for i in range (len(com_data["comment_information"])):
                com_list.append(com_data["comment_information"][i])
        df3=pd.DataFrame(com_list)
        
        print("Step 1")
        for index,row in df3.iterrows():
                print(index)
                print(row)
                insert_query=''' insert into comments(Comment_Id ,
                                                        Video_Id ,
                                                        Comment_Text ,
                                                        Comment_Author,
                                                        Comment_Published
                                                    )                                                                                            
                                                    values(%s,%s,%s,%s,%s)'''


                values=(row['Comment_Id'],
                        row['Video_Id'],
                        row['Comment_Text'],
                        row['Comment_Author'],
                        row['Comment_Published']
                    )
                try:
                        cursor.execute(insert_query,values)
                        mydb.commit()
                except:
                    print('comments are already inserted')

# %%
def comments_details():
      mydb=psycopg2.connect(host="localhost",user="postgres",password="root",
                          database="youtube_details",port="5432")

      cursor=mydb.cursor()
      drop_query='''drop table if exists comments'''
      cursor.execute(drop_query)
      mydb.commit()

      create_query="""create table if not exists comments(Comment_Id varchar(100) primary key,
                                                          Video_Id varchar(50),
                                                          Comment_Text text,
                                                          Comment_Author varchar(150),
                                                          Comment_Published timestamp
                                                          )"""
      cursor.execute(create_query)
      mydb.commit()
      com_list=[]
      db=client["youtube_data"]
      collection1=db["youtube_data"]
      for com_data in collection1.find({},{"_id":0,"comment_information":1}):
        for i in range (len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])
      df3=pd.DataFrame(com_list)
     
      print(com_list)
      df3

    #   for index,row in df3.iterrows():
    #       insert_query=''' insert into comments(Comment_Id ,
    #                                               Video_Id ,
    #                                               Comment_Text ,
    #                                               Comment_Author,
    #                                               Comment_Published
    #                                             )
                                                
                                                
    #                                             values(%s,%s,%s,%s,%s)'''


    #       values=(row['Comment_Id'],
    #               row['Video_Id'],
    #               row['Comment_Text'],
    #               row['Comment_Author'],
    #               row['Comment_Published']
    #               )


    #   try:
    #       cursor.execute(insert_query,values)
    #       mydb.commit()
    #   except:
    #       print('channels values are already inserted')

# %%
comments_details()
# Out:
# Step 1
# 0
# Comment_Id                                  UgxiNYj8ZU9-Flsqf2t4AaABAg
# Video_Id                                                   H7mCOzC2wGo
# Comment_Text         Endha vendakai poriyal different ah iruku nanu...
# Comment_Author                                            @saipavi8883
# Comment_Published                                 2024-02-21T02:57:24Z
# Name: 0, dtype: object
# comments are already inserted
# 1
# Comment_Id                                  UgwwIFyDkvmiN7Q2TLh4AaABAg
# Video_Id                                                   H7mCOzC2wGo
# Comment_Text         Panni puri panrapo oru vlog podunge with my br...
# Comment_Author                                  @srinivasansandhya8672
# Comment_Published                                 2024-02-20T14:11:31Z
# Name: 1, dtype: object
# comments are already inserted
# 2
# Comment_Id           UgxipngjG1tHXsPLGUZ4AaABAg
# Video_Id                            bwJnb5ds8Ec
# Comment_Text              Donne biriyani super😇
# Comment_Author                     @saipavi8883
# Comment_Published          2024-02-21T02:58:26Z
# Name: 2, dtype: object
# comments are already inserted
# 3
# Comment_Id                                  UgwbtqvdTCPgZC2LGzd4AaABAg
# Video_Id                                                   bwJnb5ds8Ec
# Comment_Text         Paakum bodhea theariyudhu edhu nalla irukum nu...
# Comment_Author                                            @saipavi8883
# Comment_Published                                 2024-02-21T02:58:07Z
# Name: 3, dtype: object
# comments are already inserted
# 4
# Comment_Id               UgwtsKYSE_M6k4ESOCx4AaABAg
# Video_Id                                bwJnb5ds8Ec
# Comment_Text         Akka donne biriyani super 😁❤️🎉
# Comment_Author                    @sathissathis9942
# Comment_Published              2024-02-21T02:52:35Z
# Name: 4, dtype: object
# comments are already inserted
# 5
# Comment_Id                    UgwUI1eH6UPvLIcw1y14AaABAg
# Video_Id                                     bwJnb5ds8Ec
# Comment_Text         Akka different ahh tea try pannunga
# Comment_Author                             @Ammukutty031
# Comment_Published                   2024-02-19T00:10:49Z
# Name: 5, dtype: object
# comments are already inserted
# 6
# Comment_Id               UgyXrEg4vz47vQEb50l4AaABAg
# Video_Id                                NUPJS1ei3FE
# Comment_Text         Akka easy cake recipes podunga
# Comment_Author                        @IndhuMathi00
# Comment_Published              2024-02-19T00:06:50Z
# Name: 6, dtype: object
# comments are already inserted
# 7
# Comment_Id                                  UgyKaiVEPAy5kyJmyyx4AaABAg
# Video_Id                                                   K6S0sWwwH04
# Comment_Text         Valakai bajji valakai dhan romba chinna chinna...
# Comment_Author                                            @saipavi8883
# Comment_Published                                 2024-02-21T02:59:51Z
# Name: 7, dtype: object
# comments are already inserted
# 8
# Comment_Id                                  Ugxa36TSJSE_Tu_1b7N4AaABAg
# Video_Id                                                   K6S0sWwwH04
# Comment_Text         Sister ladies finger vechi edhachi different r...
# Comment_Author                                           @Ammukutty031
# Comment_Published                                 2024-02-20T08:09:59Z
# Name: 8, dtype: object
# comments are already inserted
# 9
# Comment_Id           UgzJtqyHYusj_-d2Kct4AaABAg
# Video_Id                            K6S0sWwwH04
# Comment_Text          Sandhya akka super banana
# Comment_Author                 @user-ev6rx4eb7m
# Comment_Published          2024-02-15T16:32:20Z
# Name: 9, dtype: object
# comments are already inserted
# 10
# Comment_Id             UgzuPBemVIku72KcGuR4AaABAg
# Video_Id                              K6S0sWwwH04
# Comment_Text         Sweet recipes podunga akka 🤤
# Comment_Author                      @Priya_pretty
# Comment_Published            2024-02-13T18:02:11Z
# Name: 10, dtype: object
# comments are already inserted
# 11
# Comment_Id           Ugxw1NXFO4GA9buq1T54AaABAg
# Video_Id                            K6S0sWwwH04
# Comment_Text                       Akka super 🤤
# Comment_Author                    @Priya_pretty
# Comment_Published          2024-02-13T17:59:33Z
# Name: 11, dtype: object
# comments are already inserted
# 12
# Comment_Id           UgxiE4HzpWlUXnk7kHx4AaABAg
# Video_Id                            f--VmIHj23A
# Comment_Text                         Nalla illa
# Comment_Author            @SanthiyaSankar-lx4tt
# Comment_Published          2024-02-08T12:16:59Z
# Name: 12, dtype: object
# comments are already inserted
# 13
# Comment_Id                                 Ugz4SVW_tvzqzniCvUl4AaABAg
# Video_Id                                                  3wWjFt44pE0
# Comment_Text         Iyoooo correct ah nadikiraney😆😆😆😆😆😆😆😆😆😆😆😆😆😆😆😆😆😆😃
# Comment_Author                                 @srinivasansandhya8672
# Comment_Published                                2024-02-08T05:02:49Z
# Name: 13, dtype: object
# comments are already inserted
# 14
# Comment_Id                                  Ugx74dMxLbdKG2X_I8t4AaABAg
# Video_Id                                                   3wWjFt44pE0
# Comment_Text         Edha recipe nanum v2la try pandrean sis nalla ...
# Comment_Author                                       @sathissathis9942
# Comment_Published                                 2024-02-07T17:44:40Z
# Name: 14, dtype: object
# comments are already inserted
# 15
# Comment_Id                                  Ugxnd9-lVmf1-NprlJd4AaABAg
# Video_Id                                                   3wWjFt44pE0
# Comment_Text         Sunday special super and Tamila Tamila episode...
# Comment_Author                                       @sathissathis9942
# Comment_Published                                 2024-02-07T17:31:00Z
# Name: 15, dtype: object
# comments are already inserted
# 16
# Comment_Id           UgzXjzeGb-V64VW-9_h4AaABAg
# Video_Id                            XTAUZ2ZVr4A
# Comment_Text                                 In
# Comment_Author             @prasannaeswar-kk9iq
# Comment_Published          2024-02-07T14:18:45Z
# Name: 16, dtype: object
# comments are already inserted
# 17
# Comment_Id           Ugy-POgN6G2oy89Nn094AaABAg
# Video_Id                            XTAUZ2ZVr4A
# Comment_Text                 G<br><br>Ffd🎉😂😢😮😅😊
# Comment_Author                        @Sasi__1M
# Comment_Published          2024-02-07T13:09:16Z
# Name: 17, dtype: object
# comments are already inserted
# 18
# Comment_Id           Ugz-JNtka9bff_V4cBl4AaABAg
# Video_Id                            YiigD4KHRjE
# Comment_Text                   anna comes super
# Comment_Author                 @user-ev6rx4eb7m
# Comment_Published          2024-02-15T16:33:45Z
# Name: 18, dtype: object
# comments are already inserted
# 19
# Comment_Id             UgzCzgo8b0VkDXNqqrh4AaABAg
# Video_Id                              YiigD4KHRjE
# Comment_Text         super Sandhya akka vice nice
# Comment_Author                   @user-ev6rx4eb7m
# Comment_Published            2024-02-15T16:28:14Z
# Name: 19, dtype: object
# comments are already inserted
# 20
# Comment_Id           Ugw-AIPqkK6x6FpXVzJ4AaABAg
# Video_Id                            YiigD4KHRjE
# Comment_Text                                 😂😂
# Comment_Author                 @user-sh6mj8gn8t
# Comment_Published          2024-02-13T18:13:23Z
# Name: 20, dtype: object
# comments are already inserted
# 21
# Comment_Id           UgwWyePVxSmiIxzjf7B4AaABAg
# Video_Id                            YiigD4KHRjE
# Comment_Text                     Very nice ❤❤😊😊
# Comment_Author                 @user-od9xr7je1n
# Comment_Published          2024-02-10T15:26:48Z
# Name: 21, dtype: object
# comments are already inserted
# 22
# Comment_Id           UgxLmrR_GOYHhPXxual4AaABAg
# Video_Id                            YiigD4KHRjE
# Comment_Text                Edhu Nalla iruku 😂😅
# Comment_Author                @sathissathis9942
# Comment_Published          2024-02-06T19:30:03Z
# Name: 22, dtype: object
# comments are already inserted
# 23
# Comment_Id                                UgwApETVT-UUKZAUlkl4AaABAg
# Video_Id                                                 GGIZV-YKml4
# Comment_Text         Aandha mind voice correct ahh sync aagudhukaa😂😂
# Comment_Author                                          @saipavi8883
# Comment_Published                               2024-02-03T06:03:00Z
# Name: 23, dtype: object
# comments are already inserted
# 24
# Comment_Id                                  UgzO4wM3KdkRiXWd1Hh4AaABAg
# Video_Id                                                   GGIZV-YKml4
# Comment_Text         Good video good message thanks for giving us.....
# Comment_Author                                            @saipavi8883
# Comment_Published                                 2024-02-03T06:01:41Z
# Name: 24, dtype: object
# comments are already inserted
# 25
# Comment_Id                                  UgxHyy5RuaeSAn3qqdJ4AaABAg
# Video_Id                                                   GGIZV-YKml4
# Comment_Text         Good morning😊 kaa more useful video for me in ...
# Comment_Author                                       @sathissathis9942
# Comment_Published                                 2024-02-03T05:06:34Z
# Name: 25, dtype: object
# comments are already inserted
# 26
# Comment_Id                                  UgzkKl1QsrnpARGX6sV4AaABAg
# Video_Id                                                   mfrTbuvTQMM
# Comment_Text         Neenga enna solerupinha nu pakka nan wait pand...
# Comment_Author                                       @sathissathis9942
# Comment_Published                                 2024-02-03T05:10:19Z
# Name: 26, dtype: object
# comments are already inserted
# 27
# Comment_Id           Ugx_1U-llQ9DnKJuErx4AaABAg
# Video_Id                            L4wZneq9w1c
# Comment_Text                     ❤ Happy family
# Comment_Author                @sathissathis9942
# Comment_Published          2024-02-03T05:09:44Z
# Name: 27, dtype: object
# comments are already inserted
# 28
# Comment_Id           UgxHrWcMoMy358NDK1h4AaABAg
# Video_Id                            -vxzehTd9gQ
# Comment_Text                                🎉❤😊
# Comment_Author                @sathissathis9942
# Comment_Published          2024-02-03T05:08:59Z
# Name: 28, dtype: object
# comments are already inserted
# 29
# Comment_Id           UgzOgZ6Bfd4GyUUDMtF4AaABAg
# Video_Id                            -vxzehTd9gQ
# Comment_Text                                 😅😅
# Comment_Author                    @parthisusi10
# Comment_Published          2024-01-31T16:18:01Z
# Name: 29, dtype: object
# comments are already inserted
# 30
# Comment_Id                 Ugz3IymDaLTLCkClHtZ4AaABAg
# Video_Id                                  -vxzehTd9gQ
# Comment_Text         Ayyo paavam avare marathuttaru..
# Comment_Author                           @vjavadi8102
# Comment_Published                2024-01-31T12:40:20Z
# Name: 30, dtype: object
# comments are already inserted
# 31
# Comment_Id           Ugz_UlabcI3ABcNDLJd4AaABAg
# Video_Id                            dJzXgW3ZDy4
# Comment_Text               11/10...😅 Awesome 💯🎉
# Comment_Author                @sathissathis9942
# Comment_Published          2024-01-24T12:22:42Z
# Name: 31, dtype: object
# comments are already inserted
# 32
# Comment_Id           UgyXAIjh8_rI2nQ19G14AaABAg
# Video_Id                            GM0aiRHfpsw
# Comment_Text               Edhu Nalla eruku..❤😊
# Comment_Author                @sathissathis9942
# Comment_Published          2024-01-24T12:23:29Z
# Name: 32, dtype: object
# comments are already inserted
# 33
# Comment_Id           UgwNgj350UyvDnAjF_V4AaABAg
# Video_Id                            GM0aiRHfpsw
# Comment_Text               Edhu Nalla eruku..❤😊
# Comment_Author                @sathissathis9942
# Comment_Published          2024-01-24T12:23:29Z
# Name: 33, dtype: object
# comments are already inserted
# 34
# Comment_Id                       UgzbzAVMggjvZUtu_DN4AaABAg
# Video_Id                                        ChHgDtcD03M
# Comment_Text         Papa naraya expression kudukuranga...😊
# Comment_Author                            @sathissathis9942
# Comment_Published                      2024-01-24T12:24:31Z
# Name: 34, dtype: object
# comments are already inserted
# 35
# Comment_Id           Ugysxx0OP17g1K6IEVl4AaABAg
# Video_Id                            azP8YG892Xs
# Comment_Text                  Happy Birthday 🎂😁
# Comment_Author                @sathissathis9942
# Comment_Published          2024-02-03T05:11:06Z
# Name: 35, dtype: object
# comments are already inserted
# 36
# Comment_Id                                  UgziFREmevu2DA6xt-94AaABAg
# Video_Id                                                   QuRVX60P_6I
# Comment_Text         You tube la<br>Grt silver purchase vlog <br>VV...
# Comment_Author                                         @venkateshs6081
# Comment_Published                                 2024-01-18T04:15:19Z
# Name: 36, dtype: object
# comments are already inserted
# 37
# Comment_Id           Ugw1_TtPdjrdV24KAOB4AaABAg
# Video_Id                            QuRVX60P_6I
# Comment_Text               வீடியோ சூப்பர் அக்கா
# Comment_Author                  @venkateshs6081
# Comment_Published          2024-01-12T12:35:02Z
# Name: 37, dtype: object
# comments are already inserted
# 38
# Comment_Id                                  UgzQbDF6I7DxHTKt1ch4AaABAg
# Video_Id                                                   QuRVX60P_6I
# Comment_Text         You tube la <br>KS Kiladis pedicure இந்த வீடிய...
# Comment_Author                                         @venkateshs6081
# Comment_Published                                 2024-01-12T12:34:27Z
# Name: 38, dtype: object
# comments are already inserted
# 39
# Comment_Id           UgyIsmLapFBh2WnKwL94AaABAg
# Video_Id                            NQuKTGQ0LLE
# Comment_Text               வீடியோ சூப்பர் அக்கா
# Comment_Author                  @venkateshs6081
# Comment_Published          2024-01-12T12:36:17Z
# Name: 39, dtype: object
# comments are already inserted
# 40
# Comment_Id                                  UgzcVUnIBmnGKtJ0s1F4AaABAg
# Video_Id                                                   NQuKTGQ0LLE
# Comment_Text         You tube la <br>KS Kiladis pedicure இந்த வீடிய...
# Comment_Author                                         @venkateshs6081
# Comment_Published                                 2024-01-12T12:35:22Z
# Name: 40, dtype: object
# comments are already inserted
# 41
# Comment_Id                          UgxrQ75cAybwfvLPpP14AaABAg
# Video_Id                                           NQuKTGQ0LLE
# Comment_Text         My current weight 76tarcet weight lose 60
# Comment_Author                                  @ManiRam-td4dn
# Comment_Published                         2023-12-22T16:21:51Z
# Name: 41, dtype: object
# comments are already inserted
# 42
# Comment_Id           UgxmYyJacdqvGr4zCWZ4AaABAg
# Video_Id                            NQuKTGQ0LLE
# Comment_Text            Sari sari manichiten d😂
# Comment_Author               @sunmathikumar4992
# Comment_Published          2023-12-22T13:32:41Z
# Name: 42, dtype: object
# comments are already inserted
# 43
# Comment_Id                            UgwPtnZj6XCEgGwsWvZ4AaABAg
# Video_Id                                             auoZjFAWOik
# Comment_Text         Neenga daily exercise walking Panna vengala
# Comment_Author                                        @lakshan23
# Comment_Published                           2023-12-19T07:30:21Z
# Name: 43, dtype: object
# comments are already inserted
# 44
# Comment_Id            UgzRmED7EBAiaTdyJ6F4AaABAg
# Video_Id                             auoZjFAWOik
# Comment_Text         Hi my weight 66.6 target 57
# Comment_Author               @subburajsanjay7202
# Comment_Published           2023-12-15T06:10:34Z
# Name: 44, dtype: object
# comments are already inserted
# 45
# Comment_Id           UgzVMXpYnCrNWwalCiJ4AaABAg
# Video_Id                            auoZjFAWOik
# Comment_Text                              Super
# Comment_Author              @AbirajeshLifestyle
# Comment_Published          2023-12-15T05:50:00Z
# Name: 45, dtype: object
# comments are already inserted
# 46
# Comment_Id           UgyO3FohYoNhBoZPCAl4AaABAg
# Video_Id                            RmCbx0Q2QTU
# Comment_Text                    Cutieepie ...❤🎉
# Comment_Author                @sathissathis9942
# Comment_Published          2024-01-24T12:25:07Z
# Name: 46, dtype: object
# comments are already inserted
# 47
# Comment_Id           UgxqiDrj-QZyvoZ08Mh4AaABAg
# Video_Id                            RmCbx0Q2QTU
# Comment_Text              Your son is so cute🎉❤
# Comment_Author                @valueofthought01
# Comment_Published          2023-12-15T14:08:50Z
# Name: 47, dtype: object
# comments are already inserted
# 48
# Comment_Id           UgwwAAQobZWfCa5xtQx4AaABAg
# Video_Id                            U7ezXMkNRlY
# Comment_Text                                Pls
# Comment_Author                   @Maniabi-xj2qg
# Comment_Published          2023-12-13T08:55:44Z
# Name: 48, dtype: object
# comments are already inserted
# 49
# Comment_Id                              UgzWBoFXT00NfdgrcER4AaABAg
# Video_Id                                               U7ezXMkNRlY
# Comment_Text         Sister ennku romba wight loss pannunum sister
# Comment_Author                                      @Maniabi-xj2qg
# Comment_Published                             2023-12-13T08:55:31Z
# Name: 49, dtype: object
# comments are already inserted
# 50
# Comment_Id           UgwRYICAeEAZuFTJhOx4AaABAg
# Video_Id                            U7ezXMkNRlY
# Comment_Text                              Super
# Comment_Author              @AbirajeshLifestyle
# Comment_Published          2023-12-13T08:45:22Z
# Name: 50, dtype: object
# comments are already inserted
# 51
# Comment_Id           UgxgBlr0s3A48zp5jYd4AaABAg
# Video_Id                            Aeq5fnQPiZs
# Comment_Text                 Super all the best
# Comment_Author              @AbirajeshLifestyle
# Comment_Published          2023-12-12T11:00:49Z
# Name: 51, dtype: object
# comments are already inserted
# 52
# Comment_Id                    Ugytar2V5pza_HTULct4AaABAg
# Video_Id                                     Aeq5fnQPiZs
# Comment_Text         Yes we want what  u r cooking😊.....
# Comment_Author                    @srinivasansandhya8672
# Comment_Published                   2023-12-11T08:16:01Z
# Name: 52, dtype: object
# comments are already inserted
# 53
# Comment_Id                                  UgxpnLHWVSqpIaqqtKR4AaABAg
# Video_Id                                                   Aeq5fnQPiZs
# Comment_Text         Plz put how to make Kali receipe video.and whi...
# Comment_Author                                               @j7fun100
# Comment_Published                                 2023-12-11T07:59:14Z
# Name: 53, dtype: object
# comments are already inserted
# 54
# Comment_Id            UgxM7Ur_A6xIA-1YOKl4AaABAg
# Video_Id                             K86jyqFTBS4
# Comment_Text         Your voice is not audioable
# Comment_Author                 @SreeEnergyCorner
# Comment_Published           2023-12-08T10:54:23Z
# Name: 54, dtype: object
# comments are already inserted
# 55
# Comment_Id                                  UgxjigaICRIsbS9htaF4AaABAg
# Video_Id                                                   K86jyqFTBS4
# Comment_Text         Sis en height 155 weight 55 evlo weight erukan...
# Comment_Author                                     @preethapreetha4372
# Comment_Published                                 2023-12-07T05:25:39Z
# Name: 55, dtype: object
# comments are already inserted
# 56
# Comment_Id           Ugx41tXxsUvf16vGW2t4AaABAg
# Video_Id                            3kmAb2jQIyE
# Comment_Text                  Congratulations❤🎉
# Comment_Author                @SnehaVeljo-hy6xm
# Comment_Published          2023-12-04T14:35:29Z
# Name: 56, dtype: object
# comments are already inserted
# 57
# Comment_Id           UgxgEnvb5BgArT7xtZR4AaABAg
# Video_Id                            _Cp8ub1LsJQ
# Comment_Text              Athu enna kudikeringa
# Comment_Author                @m.sudharsan2b220
# Comment_Published          2023-12-16T05:05:16Z
# Name: 57, dtype: object
# comments are already inserted
# 58
# Comment_Id                                  Ugx-BrHMlwTK4kB-GuZ4AaABAg
# Video_Id                                                   _Cp8ub1LsJQ
# Comment_Text         Hi sister. Actually I have one doubt. Engalukk...
# Comment_Author                                       @thanikasalam4008
# Comment_Published                                 2023-12-05T05:05:50Z
# Name: 58, dtype: object
# comments are already inserted
# 59
# Comment_Id                      UgztHYa5MAsDYX392ZJ4AaABAg
# Video_Id                                       _Cp8ub1LsJQ
# Comment_Text         Akka my current weight 52 achieved 42
# Comment_Author                                    @Usrimam
# Comment_Published                     2023-12-04T06:48:39Z
# Name: 59, dtype: object
# comments are already inserted
# 60
# Comment_Id                 Ugzo5kycr84Kv-odKKp4AaABAg
# Video_Id                                  _Cp8ub1LsJQ
# Comment_Text         Your weight please sister please
# Comment_Author                       @user-zp6yp4gg6b
# Comment_Published                2023-12-04T02:09:10Z
# Name: 60, dtype: object
# comments are already inserted
# 61
# Comment_Id                            UgwUJesu9TmpjnlgCqd4AaABAg
# Video_Id                                             _Cp8ub1LsJQ
# Comment_Text         Start pannumpodhu neenga enna weight sister
# Comment_Author                                     @shansasi9501
# Comment_Published                           2023-12-03T06:52:23Z
# Name: 61, dtype: object
# comments are already inserted
# 62
# Comment_Id                                  Ugx_d0jjCDSyXgnfxNF4AaABAg
# Video_Id                                                   _Cp8ub1LsJQ
# Comment_Text         Which is U r current weight ?and  which is ur ...
# Comment_Author                                               @j7fun100
# Comment_Published                                 2023-12-03T05:55:14Z
# Name: 62, dtype: object
# comments are already inserted
# 63
# Comment_Id           Ugwal6lA6YFLOs7ZaG54AaABAg
# Video_Id                            8EfkCARVe88
# Comment_Text          Akka glass tumbler super❤
# Comment_Author                    @pavithra4888
# Comment_Published          2023-12-03T16:13:39Z
# Name: 63, dtype: object
# comments are already inserted
# 64
# Comment_Id           UgyfmxoFiqGsgDAvrXB4AaABAg
# Video_Id                            8EfkCARVe88
# Comment_Text                         Hii sister
# Comment_Author                  @ramchandru5731
# Comment_Published          2023-12-01T03:07:44Z
# Name: 64, dtype: object
# comments are already inserted
# 65
# Comment_Id                                  UgwDZRG67KdGjloQbnN4AaABAg
# Video_Id                                                   3SmE0OUrJBI
# Comment_Text         Correct sis yenna eptiyellam sonnaga 20 kg wei...
# Comment_Author                                    @sharmilifestyle2984
# Comment_Published                                 2023-11-30T07:24:51Z
# Name: 65, dtype: object
# comments are already inserted
# 66
# Comment_Id                                  UgzPqUAmfnpe-KQ9zNV4AaABAg
# Video_Id                                                   3SmE0OUrJBI
# Comment_Text         I love your channel keep up the good work.. Al...
# Comment_Author                                         @cook_withpooja
# Comment_Published                                 2023-11-30T07:24:31Z
# Name: 66, dtype: object
# comments are already inserted
# 67
# Comment_Id           UgyLbVTWocR6omHxeVZ4AaABAg
# Video_Id                            3SmE0OUrJBI
# Comment_Text                 Sis drink link sis
# Comment_Author               @madhandharani2713
# Comment_Published          2023-11-30T05:56:50Z
# Name: 67, dtype: object
# comments are already inserted
# 68
# Comment_Id                                  UgyI6Gfg7HghSG7_dmF4AaABAg
# Video_Id                                                   lMmxivsmtTc
# Comment_Text         Nonstick,aluminum vessels use panathinga healt...
# Comment_Author                                         @priyakumar8475
# Comment_Published                                 2024-01-02T12:37:35Z
# Name: 68, dtype: object
# comments are already inserted
# 69
# Comment_Id           Ugz3iiuCAAqWj_HmrAJ4AaABAg
# Video_Id                            ooLKyCivmjg
# Comment_Text                     Current weight
# Comment_Author                 @user-gg1ei6bs5x
# Comment_Published          2023-11-27T12:08:38Z
# Name: 69, dtype: object
# comments are already inserted
# 70
# Comment_Id                          Ugy0GydnbfUYqzYkC3N4AaABAg
# Video_Id                                           ooLKyCivmjg
# Comment_Text         Neega onnum antha alavukku weight illayea
# Comment_Author                            @sharmilifestyle2984
# Comment_Published                         2023-11-27T05:21:56Z
# Name: 70, dtype: object
# comments are already inserted
# 71
# Comment_Id                        Ugw2PImtU2zKGkXy7Lp4AaABAg
# Video_Id                                         WivZTUyOoyc
# Comment_Text         Last konjo video la voice kekla mam 🙄🙄😅
# Comment_Author                           @jothisvarshavj2728
# Comment_Published                       2023-11-30T09:25:57Z
# Name: 71, dtype: object
# comments are already inserted
# 72
# Comment_Id                              Ugwe4uWgnt8NcFr8lY14AaABAg
# Video_Id                                               WivZTUyOoyc
# Comment_Text         Neraya consistency word use pandringa mam😂😂😂😂
# Comment_Author                                 @jothisvarshavj2728
# Comment_Published                             2023-11-30T09:25:25Z
# Name: 72, dtype: object
# comments are already inserted
# 73
# Comment_Id                                  UgyN-nEdoj3i0eUK_ZJ4AaABAg
# Video_Id                                                   WivZTUyOoyc
# Comment_Text         😊content pathu videokula vandhaavnga😂 sarbaga ...
# Comment_Author                                    @RajkumarKumar-cn1oi
# Comment_Published                                 2023-11-26T20:55:27Z
# Name: 73, dtype: object
# comments are already inserted
# 74
# Comment_Id           Ugz5mUpfNx4BRGODXDt4AaABAg
# Video_Id                            WivZTUyOoyc
# Comment_Text                          Super sis
# Comment_Author                    @sivamani5303
# Comment_Published          2023-11-25T09:43:19Z
# Name: 74, dtype: object
# comments are already inserted
# 75
# Comment_Id                                UgwN9IdPeFB1qkd_cft4AaABAg
# Video_Id                                                 aGjR7kZkYWQ
# Comment_Text         Super akka u posting a good information to us 🎉
# Comment_Author                                  @RajkumarKumar-cn1oi
# Comment_Published                               2023-11-25T22:30:26Z
# Name: 75, dtype: object
# comments are already inserted
# 76
# Comment_Id           UgwrHrpF51uGPgmWe294AaABAg
# Video_Id                            RNaPwnjJlr4
# Comment_Text                              ❤nice
# Comment_Author                    @parthisusi10
# Comment_Published          2024-01-28T12:40:29Z
# Name: 76, dtype: object
# comments are already inserted
# 77
# Comment_Id           UgyNrd7jiAY-hwXWraR4AaABAg
# Video_Id                            H63jpLOySCc
# Comment_Text                 Super all the best
# Comment_Author              @AbirajeshLifestyle
# Comment_Published          2023-12-12T10:59:51Z
# Name: 77, dtype: object
# comments are already inserted
# 78
# Comment_Id           UgwJwBuDx-MrhkjHtw14AaABAg
# Video_Id                            H63jpLOySCc
# Comment_Text         Last ha ena water sis Adhu
# Comment_Author               @Priyashakthivlogs
# Comment_Published          2023-11-26T15:34:42Z
# Name: 78, dtype: object
# comments are already inserted
# 79
# Comment_Id                                  Ugz5jHKmK74P7AYjklx4AaABAg
# Video_Id                                                   aYuCM7hHPAQ
# Comment_Text         Hai bro how are you ? your way of explanation ...
# Comment_Author                                @renugadevichakkarai6111
# Comment_Published                                 2024-02-09T09:03:48Z
# Name: 79, dtype: object
# comments are already inserted
# 80
# Comment_Id           UgxEQtw9lQ5HNAIladV4AaABAg
# Video_Id                            aYuCM7hHPAQ
# Comment_Text                              Ayyaa
# Comment_Author             @dineeshvarshanc1576
# Comment_Published          2023-09-08T15:02:31Z
# Name: 80, dtype: object
# comments are already inserted
# 81
# Comment_Id                   UgxWCAzRbu7XnkS6DD94AaABAg
# Video_Id                                    aYuCM7hHPAQ
# Comment_Text         Waiting for your videos big boss 🎉
# Comment_Author                          @PraveenN-fp5jy
# Comment_Published                  2023-09-04T18:59:03Z
# Name: 81, dtype: object
# comments are already inserted
# 82
# Comment_Id           Ugx_McuXDnVPw4PS-Ix4AaABAg
# Video_Id                            aYuCM7hHPAQ
# Comment_Text                         Congrats 👏
# Comment_Author                @thineshkumar5068
# Comment_Published          2023-08-31T06:15:49Z
# Name: 82, dtype: object
# comments are already inserted
# 83
# Comment_Id                          UgyxKbaURKGmmbZoYMB4AaABAg
# Video_Id                                           aYuCM7hHPAQ
# Comment_Text         Congratulations Shabari,we are waiting...
# Comment_Author                                @cinemashots3903
# Comment_Published                         2023-08-29T07:45:54Z
# Name: 83, dtype: object
# comments are already inserted
# 84
# Comment_Id           UgxWRFKMs5mGY10tESB4AaABAg
# Video_Id                            aYuCM7hHPAQ
# Comment_Text                  waiting sir......
# Comment_Author                    @NGStudio1997
# Comment_Published          2023-08-29T06:22:54Z
# Name: 84, dtype: object
# comments are already inserted
# 85
# Comment_Id                                  UgwQLnOsfJCIpAI45sh4AaABAg
# Video_Id                                                   aYuCM7hHPAQ
# Comment_Text         Congratulations 🎉<br>Eagerly waiting for yours...
# Comment_Author                                                 @Uk-zen
# Comment_Published                                 2023-08-29T06:13:31Z
# Name: 85, dtype: object
# comments are already inserted
# 86
# Comment_Id                 UgybIC5X4aNoPVBMBKt4AaABAg
# Video_Id                                  aYuCM7hHPAQ
# Comment_Text         Waiting for yours sessions sir 😊
# Comment_Author                           @rabinanto07
# Comment_Published                2023-08-28T18:42:59Z
# Name: 86, dtype: object
# comments are already inserted
# 87
# Comment_Id                                  UgxMT8PuAPl_cPOf0O94AaABAg
# Video_Id                                                   aYuCM7hHPAQ
# Comment_Text         That&#39;s really a good initiative shabari, c...
# Comment_Author                                            @iampraveens
# Comment_Published                                 2023-08-28T18:38:32Z
# Name: 87, dtype: object
# comments are already inserted
# 88
# Comment_Id                                  UgxhjKjKXpnYKtXZH_14AaABAg
# Video_Id                                                   aYuCM7hHPAQ
# Comment_Text         Hi sir, santhiya(DT1) waiting for ur videos......
# Comment_Author                                             @NidhisVlog
# Comment_Published                                 2023-08-28T16:42:24Z
# Name: 88, dtype: object
# comments are already inserted
# 89
# Comment_Id           UgzC3Yv-ZT40K9gGnVh4AaABAg
# Video_Id                            Yndu_cdyDng
# Comment_Text                                  ✌
# Comment_Author          @tamilfreefirememes6579
# Comment_Published          2024-02-20T16:52:12Z
# Name: 89, dtype: object
# comments are already inserted
# 90
# Comment_Id           UgwHoX5qPDu6TEA3YVh4AaABAg
# Video_Id                            X45N3h7b_5I
# Comment_Text              sir how to contact yu
# Comment_Author                   @nikhilesh3683
# Comment_Published          2022-02-24T15:34:42Z
# Name: 90, dtype: object
# comments are already inserted
# 91
# Comment_Id                                  UgyVXmqjddv-uzMFhiV4AaABAg
# Video_Id                                                   X45N3h7b_5I
# Comment_Text         hats-off to your effort to make everyone to un...
# Comment_Author                                     @santhoshnagaraj344
# Comment_Published                                 2021-09-05T15:28:38Z
# Name: 91, dtype: object
# comments are already inserted
# 92
# Comment_Id           UgwkIoV-Idj85tk7fQJ4AaABAg
# Video_Id                            X45N3h7b_5I
# Comment_Text                  Nice try Shabari.
# Comment_Author                      @jshari2002
# Comment_Published          2021-05-25T11:15:32Z
# Name: 92, dtype: object
# comments are already inserted
# 93
# Comment_Id                Ugw2Y1bNZ3JKOaUJSzt4AaABAg
# Video_Id                                 X45N3h7b_5I
# Comment_Text         Informative speech....superb...
# Comment_Author                   @gowrishankaris9169
# Comment_Published               2021-05-22T12:41:07Z
# Name: 93, dtype: object
# comments are already inserted
# 94
# Comment_Id           Ugx3lp9tlIY9bKLiZN54AaABAg
# Video_Id                            X45N3h7b_5I
# Comment_Text          Waiting for coding part 🔥
# Comment_Author                      @outplays_3
# Comment_Published          2021-05-02T11:57:37Z
# Name: 94, dtype: object
# comments are already inserted
# 95
# Comment_Id                                  UgxHyoFPleWtRruxE2x4AaABAg
# Video_Id                                                   CPO7xgstK0Q
# Comment_Text         Can we drive the autonomous car and make it to...
# Comment_Author                                     @santhoshnagaraj344
# Comment_Published                                 2021-09-05T15:14:44Z
# Name: 95, dtype: object
# comments are already inserted
# 96
# Comment_Id           UgxZnRojiA2YEKbjGLh4AaABAg
# Video_Id                            CPO7xgstK0Q
# Comment_Text           Good attempt. Keep it up
# Comment_Author                    @jaggujayanth
# Comment_Published          2021-04-28T10:17:46Z
# Name: 96, dtype: object
# comments are already inserted
# 97
# Comment_Id                                  UgyYcUf7GbE5iVpLU5R4AaABAg
# Video_Id                                                   CPO7xgstK0Q
# Comment_Text         Hello sir iam having an doubt on ardunio and n...
# Comment_Author                                             @outplays_3
# Comment_Published                                 2021-04-24T04:54:24Z
# Name: 97, dtype: object
# comments are already inserted
# 98
# Comment_Id           UgxEFbsnvv607CVmGLR4AaABAg
# Video_Id                            DGbSMC8AoH4
# Comment_Text            Awesome explanation sir
# Comment_Author                 @madhanmohan1634
# Comment_Published          2023-02-17T19:08:23Z
# Name: 98, dtype: object
# comments are already inserted
# 99
# Comment_Id                                  UgzfHnE7I-iMDqE9OSZ4AaABAg
# Video_Id                                                   DGbSMC8AoH4
# Comment_Text         sir, is there is all the algorithms to be trai...
# Comment_Author                                     @santhoshnagaraj344
# Comment_Published                                 2021-09-05T14:51:25Z
# Name: 99, dtype: object
# comments are already inserted
# 100
# Comment_Id                                  Ugz0ISPai5Io9pVOof54AaABAg
# Video_Id                                                   rdRAdvsESKA
# Comment_Text         Already one Mr.Magesh of RESPRO Capital manage...
# Comment_Author                                               @Greenome
# Comment_Published                                 2023-12-11T05:40:09Z
# Name: 100, dtype: object
# comments are already inserted
# 101
# Comment_Id                                  UgzX-83ZjuBaVLSK5-d4AaABAg
# Video_Id                                                   rdRAdvsESKA
# Comment_Text         A criminal case on money scam has been filed a...
# Comment_Author                                               @Greenome
# Comment_Published                                 2023-12-11T05:39:07Z
# Name: 101, dtype: object
# comments are already inserted
# 102
# Comment_Id                                  UgyDv_s5aGKfgUZxzqx4AaABAg
# Video_Id                                                   rdRAdvsESKA
# Comment_Text         Fraud to the core he is... he runs a company c...
# Comment_Author                                               @Greenome
# Comment_Published                                 2023-12-11T05:37:34Z
# Name: 102, dtype: object
# comments are already inserted
# 103
# Comment_Id                                  UgwIEMkpFfV09f2FtKV4AaABAg
# Video_Id                                                   rdRAdvsESKA
# Comment_Text         its awesome to learn AI in native language(Tam...
# Comment_Author                                     @santhoshnagaraj344
# Comment_Published                                 2021-09-05T14:36:30Z
# Name: 103, dtype: object
# comments are already inserted
# 104
# Comment_Id                UgzKOhlF0OfyQaB6TSx4AaABAg
# Video_Id                                 rdRAdvsESKA
# Comment_Text         Great to learn in tamil..<br>👌😎
# Comment_Author                   @shanmugapriya.v430
# Comment_Published               2021-04-16T17:16:27Z
# Name: 104, dtype: object
# comments are already inserted
# 105
# Comment_Id                                  UgxUdQOXlO6Vq_Wr2A54AaABAg
# Video_Id                                                   rdRAdvsESKA
# Comment_Text         Super Sir.. Explanation and examples given for...
# Comment_Author                                         @giridharanr135
# Comment_Published                                 2021-04-16T14:08:34Z
# Name: 105, dtype: object
# comments are already inserted
# 106
# Comment_Id                              UgwL0rGruAmMcd1zwjx4AaABAg
# Video_Id                                               mvEaWBYmFqI
# Comment_Text         Hi sir unga kitta online class padika mudiuma
# Comment_Author                                  @lakshmilakshmi550
# Comment_Published                             2024-02-16T07:53:29Z
# Name: 106, dtype: object
# comments are already inserted
# 107
# Comment_Id           UgxLT85vFnDRI88eFNd4AaABAg
# Video_Id                            mvEaWBYmFqI
# Comment_Text                                  🔥
# Comment_Author                        @ranch_03
# Comment_Published          2023-02-28T14:25:57Z
# Name: 107, dtype: object
# comments are already inserted
# 108
# Comment_Id           UgzUplBxDTHLXMYOScV4AaABAg
# Video_Id                            mvEaWBYmFqI
# Comment_Text                                  🔥
# Comment_Author                      @outplays_3
# Comment_Published          2021-04-15T05:06:57Z
# Name: 108, dtype: object
# comments are already inserted
# 109
# Comment_Id                      Ugy4osqlQNY4Fo77hFR4AaABAg
# Video_Id                                       mvEaWBYmFqI
# Comment_Text         Good effort Shabari Sir. Keep going 👍
# Comment_Author                             @diwakarang1316
# Comment_Published                     2021-04-15T04:02:38Z
# Name: 109, dtype: object
# comments are already inserted
# 110
# Comment_Id           UgzuLCQjpISHF4Z-C_14AaABAg
# Video_Id                            hfi-m-l4DmA
# Comment_Text          Unka video use panikalama
# Comment_Author                       @bwsquadyt
# Comment_Published          2023-11-13T09:07:53Z
# Name: 110, dtype: object
# comments are already inserted
# 111
# Comment_Id           UgxcwJDiS8hhqPTJBMx4AaABAg
# Video_Id                            hfi-m-l4DmA
# Comment_Text                               👏💯 ✨
# Comment_Author                @thamaraikodi6088
# Comment_Published          2023-11-09T11:11:39Z
# Name: 111, dtype: object
# comments are already inserted
# 112
# Comment_Id           UgzkCwLF5O-WdliJQvt4AaABAg
# Video_Id                            L66ZEPeuPmM
# Comment_Text                              Money
# Comment_Author                 @user-xm2eg6ic7f
# Comment_Published          2023-11-08T08:00:29Z
# Name: 112, dtype: object
# comments are already inserted
# 113
# Comment_Id                        UgzbmR3erc_Kg1lGvZh4AaABAg
# Video_Id                                         jkjgZCKlzBU
# Comment_Text         Super d❤<br>tqs for motivating me daliy
# Comment_Author                             @sandhiyayuvanesh
# Comment_Published                       2023-11-07T17:23:30Z
# Name: 113, dtype: object
# comments are already inserted
# 114
# Comment_Id           UgzThiZwwCx5hx5aSx94AaABAg
# Video_Id                            -K5N-xl05HI
# Comment_Text                   <b>Promosm</b> 🍀
# Comment_Author              @fernandonorton2833
# Comment_Published          2023-11-15T00:19:03Z
# Name: 114, dtype: object
# comments are already inserted
# 115
# Comment_Id                                  UgxC57SCW9YbZBXo-s14AaABAg
# Video_Id                                                   88dRDU_8sWg
# Comment_Text         Yes failure is first step of success.. really ...
# Comment_Author                                       @sandhiyayuvanesh
# Comment_Published                                 2023-11-03T08:50:49Z
# Name: 115, dtype: object
# comments are already inserted
# 116
# Comment_Id           UgwTEa09sf-cy5H5__V4AaABAg
# Video_Id                            gYEScEDhsTo
# Comment_Text            Super motivated jeevi 🎉
# Comment_Author                      @mrekha8141
# Comment_Published          2023-11-03T04:04:36Z
# Name: 116, dtype: object
# comments are already inserted
# 117
# Comment_Id           UgwvzD-EpxF_JGFG3CZ4AaABAg
# Video_Id                            gYEScEDhsTo
# Comment_Text                            Super 😊
# Comment_Author              @nagarajnaveena2771
# Comment_Published          2023-11-02T14:03:38Z
# Name: 117, dtype: object
# comments are already inserted
# 118
# Comment_Id                                  UgwYk0tZhjcZzTNuVWN4AaABAg
# Video_Id                                                   gYEScEDhsTo
# Comment_Text         I&#39;m really motivated with your words ... 🎉...
# Comment_Author                                       @sandhiyayuvanesh
# Comment_Published                                 2023-11-02T09:43:30Z
# Name: 118, dtype: object
# comments are already inserted
# 119
# Comment_Id            Ugz0qBO1BqbuEUImiZd4AaABAg
# Video_Id                             awXLekUIbRs
# Comment_Text         Super jeevi congratulation🎉
# Comment_Author                       @mrekha8141
# Comment_Published           2023-11-02T06:50:21Z
# Name: 119, dtype: object
# comments are already inserted
# 120
# Comment_Id           UgxczgY-5Tu9SCMhZNl4AaABAg
# Video_Id                            awXLekUIbRs
# Comment_Text                  வாழ்த்துக்கள்  MP
# Comment_Author              @sankargsankarg3410
# Comment_Published          2023-11-02T04:24:53Z
# Name: 120, dtype: object
# comments are already inserted
# 121
# Comment_Id                             UgxQmovt0W03DFsoSD94AaABAg
# Video_Id                                              awXLekUIbRs
# Comment_Text         Congratulations for your success start di 🥳🥳
# Comment_Author                              @charumathirajesh4982
# Comment_Published                            2023-11-02T01:20:37Z
# Name: 121, dtype: object
# comments are already inserted
# 122
# Comment_Id           Ugz4snjGnbUiNcSzGgF4AaABAg
# Video_Id                            awXLekUIbRs
# Comment_Text                     Super da Machi
# Comment_Author               @SivaparvathiRSiva
# Comment_Published          2023-11-01T13:29:10Z
# Name: 122, dtype: object
# comments are already inserted
# 123
# Comment_Id           Ugy1LC-B9AYG0W8kwmt4AaABAg
# Video_Id                            awXLekUIbRs
# Comment_Text                           super ❤️
# Comment_Author                 @user-oo8uc9oe5r
# Comment_Published          2023-11-01T12:22:30Z
# Name: 123, dtype: object
# comments are already inserted
# 124
# Comment_Id           UgzQbtPEsanX0BP-ACR4AaABAg
# Video_Id                            awXLekUIbRs
# Comment_Text                              Tq de
# Comment_Author                @valueofthought01
# Comment_Published          2023-11-01T12:08:56Z
# Name: 124, dtype: object
# comments are already inserted
# 125
# Comment_Id           UgwL2yimf5H6NadIdoF4AaABAg
# Video_Id                            awXLekUIbRs
# Comment_Text               Congratulations de🎉🎉
# Comment_Author                @twinklecheek7367
# Comment_Published          2023-11-01T11:36:17Z
# Name: 125, dtype: object
# comments are already inserted
# 126
# Comment_Id                          UgzBTuscOnPFTuA4E914AaABAg
# Video_Id                                           awXLekUIbRs
# Comment_Text         Nice🎉..... Waiting for your introduction😊
# Comment_Author                                      @babym7735
# Comment_Published                         2023-11-01T10:05:47Z
# Name: 126, dtype: object
# comments are already inserted
# 127
# Comment_Id           UgzcQp9jWUsM7Gnf-st4AaABAg
# Video_Id                            awXLekUIbRs
# Comment_Text               Epo update varum...!
# Comment_Author             @madhanvelpolice5321
# Comment_Published          2023-11-01T09:18:28Z
# Name: 127, dtype: object
# comments are already inserted
# 128
# Comment_Id           Ugw3aOvGrtMnrqmEjoV4AaABAg
# Video_Id                            DJXDRnK7m1k
# Comment_Text                    <b>Promo sm</b>
# Comment_Author                       @frankr919
# Comment_Published          2023-10-01T18:49:04Z
# Name: 128, dtype: object
# comments are already inserted
# 129
# Comment_Id               Ugxg56vAFWTsMK-F9Fh4AaABAg
# Video_Id                                bVxPrMPlAYE
# Comment_Text         reversable compooooooooooooter
# Comment_Author                   @josephvanname3377
# Comment_Published              2023-04-20T01:47:40Z
# Name: 129, dtype: object
# comments are already inserted
# 130
# Comment_Id                                  Ugx5cO7yBaeL6jNJA-t4AaABAg
# Video_Id                                                   initRjGxVnY
# Comment_Text         how&#39;s it called the type of person you are...
# Comment_Author                                            @PragandSens
# Comment_Published                                 2023-05-11T22:13:11Z
# Name: 130, dtype: object
# comments are already inserted
# 131
# Comment_Id                    UgwKZ0_7PEJX5I0IRgp4AaABAg
# Video_Id                                     bAQMUXMrAl8
# Comment_Text         do it! happy cry if you need to man
# Comment_Author                           @TheDRAGONFLITE
# Comment_Published                   2022-07-22T07:57:01Z
# Name: 131, dtype: object
# comments are already inserted
# 132
# Comment_Id           UgwOtb9oFniNdclVwbB4AaABAg
# Video_Id                            9zzasY6JCb8
# Comment_Text                                  😂
# Comment_Author               @justfortimepass94
# Comment_Published          2023-03-07T16:17:27Z
# Name: 132, dtype: object
# comments are already inserted
# 133
# Comment_Id           UgwOPBI8LeEpzcWjWbF4AaABAg
# Video_Id                            vtL3AzzP2lY
# Comment_Text                                  🥰
# Comment_Author               @justfortimepass94
# Comment_Published          2023-03-05T04:57:18Z
# Name: 133, dtype: object
# comments are already inserted
# 134
# Comment_Id           UgzjK99Qf0IGNz_-ZVp4AaABAg
# Video_Id                            Mq_6TqffcgY
# Comment_Text                              Mass💥
# Comment_Author                   @saranyatk9593
# Comment_Published          2023-03-04T16:02:27Z
# Name: 134, dtype: object
# comments are already inserted
# 135
# Comment_Id                                  UgyyDpyog_opIDvUN6F4AaABAg
# Video_Id                                                   Mq_6TqffcgY
# Comment_Text         Engineering padikueadhu thapu illai extra cour...
# Comment_Author                                          @vijitimes1570
# Comment_Published                                 2023-03-04T15:55:55Z
# Name: 135, dtype: object
# comments are already inserted
# 136
# Comment_Id                   Ugx-Tbt_AyOgkyRX6_p4AaABAg
# Video_Id                                    YubvIbOfY0w
# Comment_Text         En machanuku ena korachal sister 🤪
# Comment_Author                       @ganeshkumar-gq7ui
# Comment_Published                  2023-03-04T13:58:57Z
# Name: 136, dtype: object
# comments are already inserted
# 137
# Comment_Id           UgwBPjOo_WYCLM3rt_54AaABAg
# Video_Id                            q0m3LTMgSSs
# Comment_Text                                 😂😂
# Comment_Author                       @optionser
# Comment_Published          2023-03-04T15:54:25Z
# Name: 137, dtype: object
# comments are already inserted
# 138
# Comment_Id           Ugzj3gbNgCnJub1UcoR4AaABAg
# Video_Id                            q0m3LTMgSSs
# Comment_Text                                😂😂😂
# Comment_Author                       @ramvj5552
# Comment_Published          2023-03-03T14:15:39Z
# Name: 138, dtype: object
# comments are already inserted
# 139
# Comment_Id           UgxbCIx2QbfL375zbBp4AaABAg
# Video_Id                            q0m3LTMgSSs
# Comment_Text                                  😆
# Comment_Author                   @saranyatk9593
# Comment_Published          2023-03-03T11:48:49Z
# Name: 139, dtype: object
# comments are already inserted
# 140
# Comment_Id           Ugxkcywq6LwRgCMTTaN4AaABAg
# ...
# Name: 3049, dtype: object
# comments are already inserted
# 3050
# Comment_Id                                  UgzXJX3vEDwhaEEu92N4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         கண்ட கருமாந்திரத்தை எல்லாம் தின்னால் அப்படித்த...
# Comment_Author                                          @rammithra7341
# Comment_Published                                 2023-09-15T10:19:24Z
# Name: 3050, dtype: object
# comments are already inserted
# 3051
# Comment_Id           UgwWGIe7t5LVFvYjMGl4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text           Super 😂😂😂🤒🤕🥺🇱🇰👈💐💐💐🥰🌹😘😘👸👈
# Comment_Author              @fathimaraseeka1197
# Comment_Published          2023-08-30T09:06:29Z
# Name: 3051, dtype: object
# comments are already inserted
# 3052
# Comment_Id                  UgwWmB5iu3JAB7BXRaF4AaABAg
# Video_Id                                   UJhaK-7WE1c
# Comment_Text         Kandatha sapta appadi dha agum 😂🤣
# Comment_Author                              @sara31003
# Comment_Published                 2023-08-22T18:25:59Z
# Name: 3052, dtype: object
# comments are already inserted
# 3053
# Comment_Id                 UgxV4Y8dLfjTGawwq_R4AaABAg
# Video_Id                                  UJhaK-7WE1c
# Comment_Text         Pandian stores trolls her badly😅
# Comment_Author                            @120_ticket
# Comment_Published                2023-05-10T03:38:16Z
# Name: 3053, dtype: object
# comments are already inserted
# 3054
# Comment_Id                                  UgzfIy7F1YJLA3i2QgJ4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         is dysentery , food poisoning or a diahorrea a...
# Comment_Author                                                @SS24480
# Comment_Published                                 2023-04-12T08:51:34Z
# Name: 3054, dtype: object
# comments are already inserted
# 3055
# Comment_Id                           Ugx5AA-xY7YXuG9DU6Z4AaABAg
# Video_Id                                            UJhaK-7WE1c
# Comment_Text         Akka ungalukku onnum pannathu akka 🥰🥰🥰🥰🥰🥳🎉
# Comment_Author                                @suthansuthan2404
# Comment_Published                          2023-03-01T03:21:53Z
# Name: 3055, dtype: object
# comments are already inserted
# 3056
# Comment_Id           UgxG_Xl87GTuXMDGA_54AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                               👸🙏🕉️
# Comment_Author        @saraswathysaraswathy9184
# Comment_Published          2022-12-19T05:53:36Z
# Name: 3056, dtype: object
# comments are already inserted
# 3057
# Comment_Id                                  UgySXkDaRe0T-09KTUZ4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         பொது நிகழ்ச்சியில் darsha விற்கு pedi என கிண்ட...
# Comment_Author                                            @sridhar4490
# Comment_Published                                 2022-11-18T05:58:59Z
# Name: 3057, dtype: object
# comments are already inserted
# 3058
# Comment_Id                                  Ugymlfcdtlug7EXwmpJ4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         ஒரு பேதிக்கு நீ பெரிய ஹாஸ்பிடல் போயி அட்மிட் ஆ...
# Comment_Author                                               @ArjunC22
# Comment_Published                                 2022-07-27T13:37:45Z
# Name: 3058, dtype: object
# comments are already inserted
# 3059
# Comment_Id                                  UgyJeH9T_bJdxxq2qMN4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Priyanka, pls don&#39;t joke about your weight...
# Comment_Author                                              @bluestrue
# Comment_Published                                 2022-06-08T18:45:56Z
# Name: 3059, dtype: object
# comments are already inserted
# 3060
# Comment_Id           UgwIkLx0R4O7eL8wYQJ4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                 Akka you look like
# Comment_Author                  @sriranjani7297
# Comment_Published          2022-06-07T15:47:42Z
# Name: 3060, dtype: object
# comments are already inserted
# 3061
# Comment_Id                   UgxnlnselNtMI12Kt3x4AaABAg
# Video_Id                                    UJhaK-7WE1c
# Comment_Text         Akka u soooo sweet 😍😌🤗 Akka 😘😘😘😘😘😘
# Comment_Author                          @s.rabeckal6692
# Comment_Published                  2022-05-23T11:39:19Z
# Name: 3061, dtype: object
# comments are already inserted
# 3062
# Comment_Id                        Ugx4DkJYIi7pYsI4h754AaABAg
# Video_Id                                         UJhaK-7WE1c
# Comment_Text         Please make vlog with English subtitles
# Comment_Author                         @durgeshwaridhage3118
# Comment_Published                       2022-05-22T02:31:24Z
# Name: 3062, dtype: object
# comments are already inserted
# 3063
# Comment_Id                             Ugy0UlxQIyCPR-M-My94AaABAg
# Video_Id                                              UJhaK-7WE1c
# Comment_Text         Priyanka I feel very sad to see u like this.
# Comment_Author                                 @peninalpersis4324
# Comment_Published                            2022-04-26T19:57:03Z
# Name: 3063, dtype: object
# comments are already inserted
# 3064
# Comment_Id           UgyPodhQ8CMDgPcq3kV4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                             So sad
# Comment_Author                 @shazminshan6319
# Comment_Published          2022-04-25T21:37:03Z
# Name: 3064, dtype: object
# comments are already inserted
# 3065
# Comment_Id                          UgzUNDYdwLc0LiHZix94AaABAg
# Video_Id                                           UJhaK-7WE1c
# Comment_Text         One symptom is dyeriya for covid takecare
# Comment_Author                                 @bhuvanaveda182
# Comment_Published                         2022-04-21T10:03:45Z
# Name: 3065, dtype: object
# comments are already inserted
# 3066
# Comment_Id                                  UgzgErgTB2i0hz2zibZ4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Akka enna analum sapadula mattum correct ah ir...
# Comment_Author                                     @saransaravanan5925
# Comment_Published                                 2022-04-16T08:01:11Z
# Name: 3066, dtype: object
# comments are already inserted
# 3067
# Comment_Id           UgwLJPGd2gF-iXW3dId4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                            Hi akka
# Comment_Author               @sathishswetha9539
# Comment_Published          2022-04-08T07:31:12Z
# Name: 3067, dtype: object
# comments are already inserted
# 3068
# Comment_Id                                  Ugw68UPJwMbYxeHr-_V4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Get wel <a href="http://soon.my/">soon.my</a> ...
# Comment_Author                                           @fathimaz4300
# Comment_Published                                 2022-03-26T01:45:01Z
# Name: 3068, dtype: object
# comments are already inserted
# 3069
# Comment_Id                                  Ugzn6lP1gvhCVb6lHPV4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Ne polacha enna sethuuuu ponna ennna losuuu sa...
# Comment_Author                                                 @u11209
# Comment_Published                                 2022-03-04T13:58:09Z
# Name: 3069, dtype: object
# comments are already inserted
# 3070
# Comment_Id                                  Ugy3XVtO6QsdWLmWgON4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Inime ipdi achna.. nenga veetla tea tikation l...
# Comment_Author                                         @lunavenkat5297
# Comment_Published                                 2022-02-25T07:33:40Z
# Name: 3070, dtype: object
# comments are already inserted
# 3071
# Comment_Id                                  UgzgebglzufLhIHNgZ94AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Don&#39;t worry ungalku onum agathu nenga inth...
# Comment_Author                                         @lunavenkat5297
# Comment_Published                                 2022-02-25T07:29:36Z
# Name: 3071, dtype: object
# comments are already inserted
# 3072
# Comment_Id                                  UgyfIxC0D9O9sc-Ojrl4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Namaku<br>Namaku<br>Sorudan <br>Sorudan <br>Mu...
# Comment_Author                                         @lunavenkat5297
# Comment_Published                                 2022-02-25T07:27:45Z
# Name: 3072, dtype: object
# comments are already inserted
# 3073
# Comment_Id           Ugx9v8CHnBDy4CUjeJB4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                           தங்கமே 😍
# Comment_Author                @safrasnazeem8224
# Comment_Published          2022-02-02T17:07:08Z
# Name: 3073, dtype: object
# comments are already inserted
# 3074
# Comment_Id           UgygdGc6Lja-NPtfwL94AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                           Hai akka
# Comment_Author                     @rajanmk4390
# Comment_Published          2022-01-31T04:31:40Z
# Name: 3074, dtype: object
# comments are already inserted
# 3075
# Comment_Id           UgyIMK8NryE4uiXSqKh4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                           Hai akka
# Comment_Author                     @rajanmk4390
# Comment_Published          2022-01-31T04:31:34Z
# Name: 3075, dtype: object
# comments are already inserted
# 3076
# Comment_Id                UgzBYeZPP7g3UQG7k7N4AaABAg
# Video_Id                                 UJhaK-7WE1c
# Comment_Text         I love you piriyanka akka❤️❤️❤️
# Comment_Author                    @nanthinidurga6563
# Comment_Published               2022-01-28T14:34:22Z
# Name: 3076, dtype: object
# comments are already inserted
# 3077
# Comment_Id           UgxoLq66beJ2fj-1J9B4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                     ❤️❤️❤️❤️❤️❤️❤️
# Comment_Author                   @ashavijay1922
# Comment_Published          2022-01-27T10:18:43Z
# Name: 3077, dtype: object
# comments are already inserted
# 3078
# Comment_Id                                 UgxrodC3JF9O272kdSp4AaABAg
# Video_Id                                                  UJhaK-7WE1c
# Comment_Text         Ungaluku onnumakathu akka. Na saamiketa veantuna
# Comment_Author                                   @monamohanapriya7728
# Comment_Published                                2022-01-26T10:25:07Z
# Name: 3078, dtype: object
# comments are already inserted
# 3079
# Comment_Id                                  UgxqDo_jre4g209luF94AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Priyanka akka you&#39;re a strong woman neeka ...
# Comment_Author                                       @RishiKumar-pw2ug
# Comment_Published                                 2022-01-26T08:09:26Z
# Name: 3079, dtype: object
# comments are already inserted
# 3080
# Comment_Id                        UgwGIKIxJnvTQ4WgUtN4AaABAg
# Video_Id                                         UJhaK-7WE1c
# Comment_Text         Akka nanga veg aa non veg akka veg akka
# Comment_Author                              @deepasuresh2362
# Comment_Published                       2022-01-25T07:51:09Z
# Name: 3080, dtype: object
# comments are already inserted
# 3081
# Comment_Id                                  Ugy43waDDMRYuI6GeWx4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         akka ungale ipidi pathapoo yenake sad ach akka...
# Comment_Author                                            @anjanaj4806
# Comment_Published                                 2022-01-22T16:30:17Z
# Name: 3081, dtype: object
# comments are already inserted
# 3082
# Comment_Id                                  UgyJBEh8uGacrFYBTeV4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Akka ungalukku idhu alla setu aagadhu .always ...
# Comment_Author                                        @jayaseelans1743
# Comment_Published                                 2022-01-21T14:03:49Z
# Name: 3082, dtype: object
# comments are already inserted
# 3083
# Comment_Id           Ugzfloy6PtVbKIxsvix4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                        akka🤣🤣🤣🤣😂😂😂
# Comment_Author                 @ranjiniskrt9426
# Comment_Published          2022-01-21T07:53:13Z
# Name: 3083, dtype: object
# comments are already inserted
# 3084
# Comment_Id           UgwCZ7BFBq2OA65cALh4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                                  😘
# Comment_Author        @meenakumarisaravanan2569
# Comment_Published          2022-01-20T09:58:42Z
# Name: 3084, dtype: object
# comments are already inserted
# 3085
# Comment_Id                                  Ugy4_5pNRESjxY7WYDV4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Aspetaluku evalo panam selavashu. Moondru orud...
# Comment_Author                                @kalaiselviappadurai5387
# Comment_Published                                 2022-01-19T17:30:47Z
# Name: 3085, dtype: object
# comments are already inserted
# 3086
# Comment_Id           UgwCo_MvxRT4Fpocg5R4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                 After biggboss 😂😂🤣
# Comment_Author                     @yogeshb7908
# Comment_Published          2022-01-19T06:35:08Z
# Name: 3086, dtype: object
# comments are already inserted
# 3087
# Comment_Id                                  Ugw2b37Hm4-VAkKvtw54AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Seekeeram vandhu fun banunga priyanka all the ...
# Comment_Author                                      @priyaiyyappan6857
# Comment_Published                                 2022-01-19T06:13:32Z
# Name: 3087, dtype: object
# comments are already inserted
# 3088
# Comment_Id           UgyGJ_lUv3inGHL6Nd54AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                 Theeni pandaram...
# Comment_Author                     @rajivindira
# Comment_Published          2022-01-18T04:40:20Z
# Name: 3088, dtype: object
# comments are already inserted
# 3089
# Comment_Id             Ugz4IA66IbQDvmTHZ3F4AaABAg
# Video_Id                              UJhaK-7WE1c
# Comment_Text         Thinnipandaaram kundu psycho
# Comment_Author                   @vinchenzo011111
# Comment_Published            2022-01-17T15:33:55Z
# Name: 3089, dtype: object
# comments are already inserted
# 3090
# Comment_Id                                  UgzJY6PCgkacvUYzBHd4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Vaera level video priyanka, singapenney, bigg ...
# Comment_Author                                        @muthukumars7413
# Comment_Published                                 2022-01-17T06:48:03Z
# Name: 3090, dtype: object
# comments are already inserted
# 3091
# Comment_Id                      UgzOupC3hC1qpV_dVw94AaABAg
# Video_Id                                       UJhaK-7WE1c
# Comment_Text         Akka don&#39;t worry get will soon 🤩🤩
# Comment_Author                            @elamurugans2054
# Comment_Published                     2022-01-17T06:16:02Z
# Name: 3091, dtype: object
# comments are already inserted
# 3092
# Comment_Id           UgymtA0CnneDVDcGIaZ4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text         Get well soon akka❤️❤️❤️❤️
# Comment_Author                  @UshaRani-jg3yu
# Comment_Published          2022-01-17T04:58:44Z
# Name: 3092, dtype: object
# comments are already inserted
# 3093
# Comment_Id                       UgzB38aDADp3k0Q7WXx4AaABAg
# Video_Id                                        UJhaK-7WE1c
# Comment_Text         hi ka be happy😊 ka speedy recovery 😘😘😘
# Comment_Author                            @sharonsmitha9596
# Comment_Published                      2022-01-16T07:39:00Z
# Name: 3093, dtype: object
# comments are already inserted

# %%
#############def table

def tables():
    channels_table()
    playlist_table()
    videos_table()
    comments_details()

    return "tables created successfully"

# %%
table=tables()

# %%
def show_comments_details():
    com_list=[]
    db=client["youtube_data"]
    collection1=db["youtube_data"]
    for com_data in collection1.find({},{"_id":0,"comment_information":1}):
        for i in range (len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])
    df=st.dataframe(com_list)
    return df

# %%
df
# Out:
# DeltaGenerator()

# %%
for index,row in df.iterrows():
    insert_query=''' insert into playlists(Playlist_Id ,
                                           Title,
                                           Channel_Id,
                                           Channel_Name,
                                           PublishedAt,
                                           Video_Count
                                           )
                                           
                                           
                                           values(%s,%s,%s,%s,%s,%s)'''


    values=(row['playlist_Id'],
            row['Title'],
            row['Channel_Id'],
            row['Channel_Name'],
            row['PublishedAt'],
            row['Video_Count'])

   
    cursor.execute(insert_query,values)
    mydb.commit()

# %%
###cgannel
ch_list=[]
db=client["youtube_data"]
collection1=db["youtube_data"]
for ch_data in collection1.find({},{"_id":0,"channel_information":1}):
    ch_list.append(ch_data["channel_information"])
df=pd.DataFrame(ch_list)


df

# %%
for index,row in df.iterrows():
         insert_query=''' insert into channels(Channel_Name,
                                                channel_Id,
                                                Video_Id,
                                                Title,
                                                Tags,
                                                Thumbnail,
                                                Description,
                                                Published_Date,
                                                Duration,
                                                Views,
                                                Likes,
                                                Comments,
                                                Favorite_Count,
                                                Definition,
                                                Caption_Status
                                                )"""
                                        values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''

values=(
        row['Channel_Name'],
        row['channel_Id'],
        row['Video_Id'],
        row['Title'],
        row['Tags'],
        row['Thumbnail'],
        row['Description'],
        row['Published_Date'],
        row['Duration'],
        row['Views'],
        row['Likes'],
        row['Comments'],
        row['Favorite_Count'],
        row['Definition'],
        row['Caption_Status'])

try:
    cursor.execute(insert_query,values)
    mydb.commit()
except:
    print('channels values are already inserted')

# %%
drop_query='''drop table if exists channels'''
cursor.execute(drop_query)
mydb.commit()

# %%
######## channel



mydb=psycopg2.connect(host="localhost",user="postgres",password="root",
                    database="testing",port="5432")
cursor=mydb.cursor()


create_query="""create table channels(channel_name varchar(100) ,
                                                    channel_id varchar(80) primary key,
                                                    subscribers bigint,
                                                    views bigint,
                                                    total_videos int,
                                                    channel_description text,
                                                    playlist_id varchar(80)
                                                    )"""
cursor.execute(create_query)
mydb.commit()

# %%
##playlist
mydb=psycopg2.connect(host="localhost",user="postgres",password="root",
                    database="testing",port="5432")
cursor=mydb.cursor()

create_query="""create table if not exists playlists(Playlist_Id varchar(100)primary key ,
                                                                        Title varchar(80) ,
                                                                        Channel_Id varchar(100),
                                                                        Channel_Name varchar(100),
                                                                        PublishedAt timestamp,
                                                                        Video_Count int
                                                                        )"""
cursor.execute(create_query)
mydb.commit()

# %%
####videos

mydb=psycopg2.connect(host="localhost",user="postgres",password="root",
                    database="youtube_details",port="5432")
cursor=mydb.cursor()
drop_query='''drop table if exists videos'''
cursor.execute(drop_query)
mydb.commit()

create_query="""create table if not exists videos(Channel_Name varchar(100),
                                                                channel_Id varchar(100),
                                                                Video_Id varchar(30),
                                                                Title varchar(150),
                                                                Tags text,
                                                                Thumbnail varchar(150),
                                                                Description text,
                                                                Published_Date timestamp,
                                                                Duration interval,
                                                                Views bigint,
                                                                Likes bigint,
                                                                Comments int,
                                                                Favorite_Count int,
                                                                Definition varchar(30),
                                                                Caption_Status varchar(50)
                                                                )"""
cursor.execute(create_query)
mydb.commit()

# %%
vi_list=[]
db=client["youtube_data"]
collection1=db["youtube_data"]
for vi_data in collection1.find({},{"_id":0,"video_information":1}):
        for i in range (len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][0])
df=pd.DataFrame(vi_list)
df

# %%
###comments
mydb=psycopg2.connect(host="localhost",user="postgres",password="root",
                    database="youtube_details",port="5432")

cursor=mydb.cursor()
drop_query='''drop table if exists comments'''
cursor.execute(drop_query)
mydb.commit()

create_query="""create table if not exists comments(Comment_Id varchar(100) primary key,
                                                        Video_Id varchar(50),
                                                        Comment_Text text,
                                                        Comment_Author varchar(150),
                                                        Comment_Published timestamp
                                                        )"""
cursor.execute(create_query)
mydb.commit()

# %%
com_list=[]
db=client["youtube_data"]
collection1=db["youtube_data"]
for com_data in collection1.find({},{"_id":0,"comment_information":1}):
  for i in range (len(com_data["comment_information"])):
      com_list.append(com_data["comment_information"][0])
df3=pd.DataFrame(com_list)
df3

# %%
print(com_list)

# %%
df3.columns

# %%
for index,row in df3.iterrows():
    insert_query=''' insert into comments(Comment_Id ,
                                            Video_Id ,
                                            Comment_Text ,
                                            Comment_Author,
                                            Comment_Published
                                         )
                                           
                                           
                                           values(%s,%s,%s,%s,%s)'''


    values=(row['Comment_Id'],
            row['Video_Id'],
            row['Comment_Text'],
            row['Comment_Author'],
            row['Comment_Published']
           )


try:
    cursor.execute(insert_query,values)
    mydb.commit()
except:
    print('channels values are already inserted')

# %%
#############def table

def tables():
    channels_table()
    playlist_table()
    videos_table()
    comments_details()

    return "tables created successfully"

# %%
table=tables()
# Out:
# channels table already created
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# [{'Playlist_Id': 'PLErROxUrBdIS0c1sN9tJCm5PpiICiGIG-', 'Title': '#minivlogs  #daliyvlog #diteplan #cooking #shortsfeed  #viral #daliyvlog', 'Channel_Id': 'UCEziudKWmyBhkW8nYleaW8A', 'Channel_Name': '2k Healthy lifestyle ', 'PublishedAt': '2023-11-09T16:59:26Z', 'Video_Count': 1}, {'Playlist_Id': 'PLErROxUrBdIQW4flJ2ShFMbyA-c0vIfP2', 'Title': 'My weight lose 7 days challenge', 'Channel_Id': 'UCEziudKWmyBhkW8nYleaW8A', 'Channel_Name': '2k Healthy lifestyle ', 'PublishedAt': '2023-11-07T04:32:40Z', 'Video_Count': 6}, {'Playlist_Id': 'PLa-q1hozZo6qe3dnQ50IdV9DmPrLnA31p', 'Title': 'Basic Ideas about Machine Learning', 'Channel_Id': 'UCQqmjKQBKQkRbWbSntYJX0Q', 'Channel_Name': 'Shabarinath Premlal', 'PublishedAt': '2021-04-30T15:13:04Z', 'Video_Count': 11}, {'Playlist_Id': 'PLYRKF-MmRFI7_AIVJ2UZle6ZdMVj4zoSh', 'Title': 'Fitness Videos', 'Channel_Id': 'UCottV9-6Q4ze0kg0AiCS_gA', 'Channel_Name': 'Interactive Fitness', 'PublishedAt': '2024-02-20T13:07:50Z', 'Video_Count': 7}, {'Playlist_Id': 'PLYRKF-MmRFI5oSBv1EsZ9j9Kqfxd2iSHl', 'Title': 'Your Ultimate Fitness Journey Handbook', 'Channel_Id': 'UCottV9-6Q4ze0kg0AiCS_gA', 'Channel_Name': 'Interactive Fitness', 'PublishedAt': '2024-02-04T16:28:43Z', 'Video_Count': 1}, {'Playlist_Id': 'PLYRKF-MmRFI6vc6F5XDepbCSXDCJjxyFm', 'Title': 'Best Foods to Eat In Your Fitness Journey', 'Channel_Id': 'UCottV9-6Q4ze0kg0AiCS_gA', 'Channel_Name': 'Interactive Fitness', 'PublishedAt': '2024-02-02T06:22:13Z', 'Video_Count': 3}, {'Playlist_Id': 'PLYRKF-MmRFI6RWg1YYcgcsmIPCOjvC5Kk', 'Title': 'Follow Along Workouts', 'Channel_Id': 'UCottV9-6Q4ze0kg0AiCS_gA', 'Channel_Name': 'Interactive Fitness', 'PublishedAt': '2024-01-29T14:53:26Z', 'Video_Count': 12}, {'Playlist_Id': 'PLuo9105K6NLRozcPvyXG4fx3z2-cvXG3G', 'Title': 'PhonePe Pulse Data Visualization and Exploration', 'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ', 'Channel_Name': 'Data Science Tamil', 'PublishedAt': '2023-11-16T02:20:12Z', 'Video_Count': 29}, {'Playlist_Id': 'PLuo9105K6NLRe85dP13b0i57AkgyLWOFj', 'Title': 'YouTube Data Harvesting and Warehousing', 'Channel_Id': 'UCuI5XcJYynHa5k_lqDzAgwQ', 'Channel_Name': 'Data Science Tamil', 'PublishedAt': '2023-10-17T20:13:20Z', 'Video_Count': 16}, {'Playlist_Id': 'PLsPanwi_PYe2JEX2pAov_I-WaPQFF7lY9', 'Title': '2020', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2021-01-18T14:14:26Z', 'Video_Count': 1}, {'Playlist_Id': 'PLsPanwi_PYe1GcATCMl1z-66vLbD2zNIb', 'Title': 'Diwali 2020', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-11-15T12:35:55Z', 'Video_Count': 3}, {'Playlist_Id': 'PLsPanwi_PYe2LsMbfO9F9remvPUviGaMY', 'Title': 'Handbag', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-09-29T12:21:23Z', 'Video_Count': 2}, {'Playlist_Id': 'PLsPanwi_PYe0HAOt0wPnr1QIJ91wAoox4', 'Title': 'Beauty', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-09-03T13:31:08Z', 'Video_Count': 3}, {'Playlist_Id': 'PLsPanwi_PYe1HBSS-ovi2hDOyrehR7Ea0', 'Title': 'Namakku Soru Dhaan Mukkiyam', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-09-03T13:30:29Z', 'Video_Count': 6}, {'Playlist_Id': 'PLsPanwi_PYe1XcZku7eEKp9yDlebyNyaj', 'Title': 'Vlog', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-07-27T02:34:23Z', 'Video_Count': 64}, {'Playlist_Id': 'PLsPanwi_PYe1xOzpOTzfSOcpQeY_wab29', 'Title': 'Kelunga Kelunga', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-06-06T17:32:46Z', 'Video_Count': 5}, {'Playlist_Id': 'PLsPanwi_PYe0TRv0U7oRv-9zsVrc8MC3i', 'Title': 'Lockdown Series', 'Channel_Id': 'UCNrlHfYLo7s2eoeKEJiJi3Q', 'Channel_Name': 'Priyanka Deshpande', 'PublishedAt': '2020-06-05T20:27:00Z', 'Video_Count': 1}]
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# channels values are already inserted
# [{'Channel_Name': '2k Healthy lifestyle ', 'channel_Id': 'UCEziudKWmyBhkW8nYleaW8A', 'Video_Id': 'H7mCOzC2wGo', 'Title': '😋ladiesfinger dryfry  #villagestylefood#ytshortsfeed#shorts#villagecooking#villagestylefood #shorts', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/H7mCOzC2wGo/default.jpg', 'Description': '#cookingchannel #cooking #food #foodnetwork #foodie #foodporn #cookingathome #youtube #cookingvideo #chef #cookingwithlove #cook #cookingtips #youtuber #foodblogger #cookingtime #yummy #cookingclass #cookingshow #instafood #goodeats #recipes #instachef #foodphotography #cookingvideos #personalchef #yummyfood #celebritychef #cheflife #cookingram#homecooking #goodfood #foodstagram #youtubechannel #cookinglife #instagood #love #cookingisfun #cookinglight #delicious #foodlover #kitchenlife #indianfood #cookingwithkids #cookinglove #cookingmama #cookingschool #like #dinner #downhome #catering #cookingclasses #homemade #cookingismypassion #recipe #eater #foodies #cookingdemo #cookingfromscratch #kitchenchronicles#cookingchannel #delicious #foodstagram #youtube #foodphotography #foodblogger #cooking #chef #youtuber #goodfood #cheflife #homecooking #cook #catering #nomnomnom #yummyfood #recipes #goodeats #igfood #culinary #youtubechannel#villagefood #food #foodie #foodphotography #villagelife #indianfood #kerala #foodblogger #village #foodporn #m #mallutraveller #tech #karthiksurya #arjyou #mallu #foodlover #foodstagram #malayalam #malayali #kochi #instafood #comedy #meme #trolls #karikkfresh #karikku #thiruvananthapuram #lulu #funnymalayalam#malayalamtrolls #crazymalayalam #jokes #tc #troll #mention #techtraveleat #trollcompanyofficial #streetfood #foodiesofinstagram #healthyfood #desifood #trollcompany #homemade #february #yummy #fish #valantinesday #nature #traditionalfood #villagefoodfactory #foodlovers #india #chicken #tastyfood #chennaifoodie #photography #delicious #foodpics #southindianfood#villagefood #meme #india #delicious #homemade #healthyfood #foodstagram #foodphotography #comedy #foodgasm #foodblogger #foodlover #kerala #foodpics #fish #foodies #youtuber #jokes #mallu #malayalam #kochi#villagefood #indianfood #february #troll #tastyfood #trolls #assam #lulu #villagelife #desifood #traditionalfood #southindianfood ##villagefood #chennaifoodie #mention #thiruvananthapuram #mallutraveller #malayalamtrolls #karikku #valantinesday #crazymalayalam #villagefood #trollcompany #techtraveleat #karthiksurya #funnymalayalam #villagefoodfactory #', 'Published_Date': '2024-02-20T12:45:01Z', 'Duration': 'PT1M', 'Views': '265', 'Likes': '19', 'Comments': '3', 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}, {'Channel_Name': 'Shabarinath Premlal', 'channel_Id': 'UCQqmjKQBKQkRbWbSntYJX0Q', 'Video_Id': 'aYuCM7hHPAQ', 'Title': 'Turn every setback into a comeback video', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/aYuCM7hHPAQ/default.jpg', 'Description': 'we ll have regular technical updates\n#comeback  #setback', 'Published_Date': '2023-08-28T16:37:46Z', 'Duration': 'PT55S', 'Views': '285', 'Likes': '32', 'Comments': '13', 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}, {'Channel_Name': 'Cutest Channel', 'channel_Id': 'UCfIVF3nUnQJvR9Xcmg4wEDQ', 'Video_Id': 'cBPj0nEjL24', 'Title': '#ninjahattori#ninjahattoriintamil#ninja#hattori#hattoriintamil', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/cBPj0nEjL24/default.jpg', 'Description': '#ninjahattori\n#ninjahattoriintamil\n#ninja\n#hattori\n#hattoriintamil', 'Published_Date': '2022-10-04T05:39:32Z', 'Duration': 'PT12M', 'Views': '451', 'Likes': '8', 'Comments': '0', 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}, {'Channel_Name': 'power of mindset ', 'channel_Id': 'UCZcyXrwn0Zri6eAhG215AMw', 'Video_Id': 'x5vI-U0OunY', 'Title': '#viral #increaseyourvalue#timemanagement #motivational #youtubeshortsvideo  #motivationalspeaker', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/x5vI-U0OunY/default.jpg', 'Des ...
# step 1
# Step 1
# 0
# Comment_Id                                  UgxiNYj8ZU9-Flsqf2t4AaABAg
# Video_Id                                                   H7mCOzC2wGo
# Comment_Text         Endha vendakai poriyal different ah iruku nanu...
# Comment_Author                                            @saipavi8883
# Comment_Published                                 2024-02-21T02:57:24Z
# Name: 0, dtype: object
# comments are already inserted
# 1
# Comment_Id                                  UgwwIFyDkvmiN7Q2TLh4AaABAg
# Video_Id                                                   H7mCOzC2wGo
# Comment_Text         Panni puri panrapo oru vlog podunge with my br...
# Comment_Author                                  @srinivasansandhya8672
# Comment_Published                                 2024-02-20T14:11:31Z
# Name: 1, dtype: object
# comments are already inserted
# 2
# Comment_Id           UgxipngjG1tHXsPLGUZ4AaABAg
# Video_Id                            bwJnb5ds8Ec
# Comment_Text              Donne biriyani super😇
# Comment_Author                     @saipavi8883
# Comment_Published          2024-02-21T02:58:26Z
# Name: 2, dtype: object
# comments are already inserted
# 3
# Comment_Id                                  UgwbtqvdTCPgZC2LGzd4AaABAg
# Video_Id                                                   bwJnb5ds8Ec
# Comment_Text         Paakum bodhea theariyudhu edhu nalla irukum nu...
# Comment_Author                                            @saipavi8883
# Comment_Published                                 2024-02-21T02:58:07Z
# Name: 3, dtype: object
# comments are already inserted
# 4
# Comment_Id               UgwtsKYSE_M6k4ESOCx4AaABAg
# Video_Id                                bwJnb5ds8Ec
# Comment_Text         Akka donne biriyani super 😁❤️🎉
# Comment_Author                    @sathissathis9942
# Comment_Published              2024-02-21T02:52:35Z
# Name: 4, dtype: object
# comments are already inserted
# 5
# Comment_Id                    UgwUI1eH6UPvLIcw1y14AaABAg
# Video_Id                                     bwJnb5ds8Ec
# Comment_Text         Akka different ahh tea try pannunga
# Comment_Author                             @Ammukutty031
# Comment_Published                   2024-02-19T00:10:49Z
# Name: 5, dtype: object
# comments are already inserted
# 6
# Comment_Id               UgyXrEg4vz47vQEb50l4AaABAg
# Video_Id                                NUPJS1ei3FE
# Comment_Text         Akka easy cake recipes podunga
# Comment_Author                        @IndhuMathi00
# Comment_Published              2024-02-19T00:06:50Z
# Name: 6, dtype: object
# comments are already inserted
# 7
# Comment_Id                                  UgyKaiVEPAy5kyJmyyx4AaABAg
# Video_Id                                                   K6S0sWwwH04
# Comment_Text         Valakai bajji valakai dhan romba chinna chinna...
# Comment_Author                                            @saipavi8883
# Comment_Published                                 2024-02-21T02:59:51Z
# Name: 7, dtype: object
# comments are already inserted
# 8
# Comment_Id                                  Ugxa36TSJSE_Tu_1b7N4AaABAg
# Video_Id                                                   K6S0sWwwH04
# Comment_Text         Sister ladies finger vechi edhachi different r...
# Comment_Author                                           @Ammukutty031
# Comment_Published                                 2024-02-20T08:09:59Z
# Name: 8, dtype: object
# comments are already inserted
# 9
# Comment_Id           UgzJtqyHYusj_-d2Kct4AaABAg
# Video_Id                            K6S0sWwwH04
# Comment_Text          Sandhya akka super banana
# Comment_Author                 @user-ev6rx4eb7m
# Comment_Published          2024-02-15T16:32:20Z
# Name: 9, dtype: object
# comments are already inserted
# 10
# Comment_Id             UgzuPBemVIku72KcGuR4AaABAg
# Video_Id                              K6S0sWwwH04
# Comment_Text         Sweet recipes podunga akka 🤤
# Comment_Author                      @Priya_pretty
# Comment_Published            2024-02-13T18:02:11Z
# Name: 10, dtype: object
# comments are already inserted
# 11
# Comment_Id           Ugxw1NXFO4GA9buq1T54AaABAg
# Video_Id                            K6S0sWwwH04
# Comment_Text                       Akka super 🤤
# Comment_Author                    @Priya_pretty
# Comment_Published          2024-02-13T17:59:33Z
# Name: 11, dtype: object
# comments are already inserted
# 12
# Comment_Id           UgxiE4HzpWlUXnk7kHx4AaABAg
# Video_Id                            f--VmIHj23A
# Comment_Text                         Nalla illa
# Comment_Author            @SanthiyaSankar-lx4tt
# Comment_Published          2024-02-08T12:16:59Z
# Name: 12, dtype: object
# comments are already inserted
# 13
# Comment_Id                                 Ugz4SVW_tvzqzniCvUl4AaABAg
# Video_Id                                                  3wWjFt44pE0
# Comment_Text         Iyoooo correct ah nadikiraney😆😆😆😆😆😆😆😆😆😆😆😆😆😆😆😆😆😆😃
# Comment_Author                                 @srinivasansandhya8672
# Comment_Published                                2024-02-08T05:02:49Z
# Name: 13, dtype: object
# comments are already inserted
# 14
# Comment_Id                                  Ugx74dMxLbdKG2X_I8t4AaABAg
# Video_Id                                                   3wWjFt44pE0
# Comment_Text         Edha recipe nanum v2la try pandrean sis nalla ...
# Comment_Author                                       @sathissathis9942
# Comment_Published                                 2024-02-07T17:44:40Z
# Name: 14, dtype: object
# comments are already inserted
# 15
# Comment_Id                                  Ugxnd9-lVmf1-NprlJd4AaABAg
# Video_Id                                                   3wWjFt44pE0
# Comment_Text         Sunday special super and Tamila Tamila episode...
# Comment_Author                                       @sathissathis9942
# Comment_Published                                 2024-02-07T17:31:00Z
# Name: 15, dtype: object
# comments are already inserted
# 16
# Comment_Id           UgzXjzeGb-V64VW-9_h4AaABAg
# Video_Id                            XTAUZ2ZVr4A
# Comment_Text                                 In
# Comment_Author             @prasannaeswar-kk9iq
# Comment_Published          2024-02-07T14:18:45Z
# Name: 16, dtype: object
# comments are already inserted
# 17
# Comment_Id           Ugy-POgN6G2oy89Nn094AaABAg
# Video_Id                            XTAUZ2ZVr4A
# Comment_Text                 G<br><br>Ffd🎉😂😢😮😅😊
# Comment_Author                        @Sasi__1M
# Comment_Published          2024-02-07T13:09:16Z
# Name: 17, dtype: object
# comments are already inserted
# 18
# Comment_Id           Ugz-JNtka9bff_V4cBl4AaABAg
# Video_Id                            YiigD4KHRjE
# Comment_Text                   anna comes super
# Comment_Author                 @user-ev6rx4eb7m
# Comment_Published          2024-02-15T16:33:45Z
# Name: 18, dtype: object
# comments are already inserted
# 19
# Comment_Id             UgzCzgo8b0VkDXNqqrh4AaABAg
# Video_Id                              YiigD4KHRjE
# Comment_Text         super Sandhya akka vice nice
# Comment_Author                   @user-ev6rx4eb7m
# Comment_Published            2024-02-15T16:28:14Z
# Name: 19, dtype: object
# comments are already inserted
# 20
# Comment_Id           Ugw-AIPqkK6x6FpXVzJ4AaABAg
# Video_Id                            YiigD4KHRjE
# Comment_Text                                 😂😂
# Comment_Author                 @user-sh6mj8gn8t
# Comment_Published          2024-02-13T18:13:23Z
# Name: 20, dtype: object
# comments are already inserted
# 21
# Comment_Id           UgwWyePVxSmiIxzjf7B4AaABAg
# Video_Id                            YiigD4KHRjE
# Comment_Text                     Very nice ❤❤😊😊
# Comment_Author                 @user-od9xr7je1n
# Comment_Published          2024-02-10T15:26:48Z
# Name: 21, dtype: object
# comments are already inserted
# 22
# Comment_Id           UgxLmrR_GOYHhPXxual4AaABAg
# Video_Id                            YiigD4KHRjE
# Comment_Text                Edhu Nalla iruku 😂😅
# Comment_Author                @sathissathis9942
# Comment_Published          2024-02-06T19:30:03Z
# Name: 22, dtype: object
# comments are already inserted
# 23
# Comment_Id                                UgwApETVT-UUKZAUlkl4AaABAg
# Video_Id                                                 GGIZV-YKml4
# Comment_Text         Aandha mind voice correct ahh sync aagudhukaa😂😂
# Comment_Author                                          @saipavi8883
# Comment_Published                               2024-02-03T06:03:00Z
# Name: 23, dtype: object
# comments are already inserted
# 24
# Comment_Id                                  UgzO4wM3KdkRiXWd1Hh4AaABAg
# Video_Id                                                   GGIZV-YKml4
# Comment_Text         Good video good message thanks for giving us.....
# Comment_Author                                            @saipavi8883
# Comment_Published                                 2024-02-03T06:01:41Z
# Name: 24, dtype: object
# comments are already inserted
# 25
# Comment_Id                                  UgxHyy5RuaeSAn3qqdJ4AaABAg
# Video_Id                                                   GGIZV-YKml4
# Comment_Text         Good morning😊 kaa more useful video for me in ...
# Comment_Author                                       @sathissathis9942
# Comment_Published                                 2024-02-03T05:06:34Z
# Name: 25, dtype: object
# comments are already inserted
# 26
# Comment_Id                                  UgzkKl1QsrnpARGX6sV4AaABAg
# Video_Id                                                   mfrTbuvTQMM
# Comment_Text         Neenga enna solerupinha nu pakka nan wait pand...
# Comment_Author                                       @sathissathis9942
# Comment_Published                                 2024-02-03T05:10:19Z
# Name: 26, dtype: object
# comments are already inserted
# 27
# Comment_Id           Ugx_1U-llQ9DnKJuErx4AaABAg
# Video_Id                            L4wZneq9w1c
# Comment_Text                     ❤ Happy family
# Comment_Author                @sathissathis9942
# Comment_Published          2024-02-03T05:09:44Z
# Name: 27, dtype: object
# comments are already inserted
# 28
# Comment_Id           UgxHrWcMoMy358NDK1h4AaABAg
# Video_Id                            -vxzehTd9gQ
# Comment_Text                                🎉❤😊
# Comment_Author                @sathissathis9942
# Comment_Published          2024-02-03T05:08:59Z
# Name: 28, dtype: object
# comments are already inserted
# 29
# Comment_Id           UgzOgZ6Bfd4GyUUDMtF4AaABAg
# Video_Id                            -vxzehTd9gQ
# Comment_Text                                 😅😅
# Comment_Author                    @parthisusi10
# Comment_Published          2024-01-31T16:18:01Z
# Name: 29, dtype: object
# comments are already inserted
# 30
# Comment_Id                 Ugz3IymDaLTLCkClHtZ4AaABAg
# Video_Id                                  -vxzehTd9gQ
# Comment_Text         Ayyo paavam avare marathuttaru..
# Comment_Author                           @vjavadi8102
# Comment_Published                2024-01-31T12:40:20Z
# Name: 30, dtype: object
# comments are already inserted
# 31
# Comment_Id           Ugz_UlabcI3ABcNDLJd4AaABAg
# Video_Id                            dJzXgW3ZDy4
# Comment_Text               11/10...😅 Awesome 💯🎉
# Comment_Author                @sathissathis9942
# Comment_Published          2024-01-24T12:22:42Z
# Name: 31, dtype: object
# comments are already inserted
# 32
# Comment_Id           UgyXAIjh8_rI2nQ19G14AaABAg
# Video_Id                            GM0aiRHfpsw
# Comment_Text               Edhu Nalla eruku..❤😊
# Comment_Author                @sathissathis9942
# Comment_Published          2024-01-24T12:23:29Z
# Name: 32, dtype: object
# comments are already inserted
# 33
# Comment_Id           UgwNgj350UyvDnAjF_V4AaABAg
# Video_Id                            GM0aiRHfpsw
# Comment_Text               Edhu Nalla eruku..❤😊
# Comment_Author                @sathissathis9942
# Comment_Published          2024-01-24T12:23:29Z
# Name: 33, dtype: object
# comments are already inserted
# 34
# Comment_Id                       UgzbzAVMggjvZUtu_DN4AaABAg
# Video_Id                                        ChHgDtcD03M
# Comment_Text         Papa naraya expression kudukuranga...😊
# Comment_Author                            @sathissathis9942
# Comment_Published                      2024-01-24T12:24:31Z
# Name: 34, dtype: object
# comments are already inserted
# 35
# Comment_Id           Ugysxx0OP17g1K6IEVl4AaABAg
# Video_Id                            azP8YG892Xs
# Comment_Text                  Happy Birthday 🎂😁
# Comment_Author                @sathissathis9942
# Comment_Published          2024-02-03T05:11:06Z
# Name: 35, dtype: object
# comments are already inserted
# 36
# Comment_Id                                  UgziFREmevu2DA6xt-94AaABAg
# Video_Id                                                   QuRVX60P_6I
# Comment_Text         You tube la<br>Grt silver purchase vlog <br>VV...
# Comment_Author                                         @venkateshs6081
# Comment_Published                                 2024-01-18T04:15:19Z
# Name: 36, dtype: object
# comments are already inserted
# 37
# Comment_Id           Ugw1_TtPdjrdV24KAOB4AaABAg
# Video_Id                            QuRVX60P_6I
# Comment_Text               வீடியோ சூப்பர் அக்கா
# Comment_Author                  @venkateshs6081
# Comment_Published          2024-01-12T12:35:02Z
# Name: 37, dtype: object
# comments are already inserted
# 38
# Comment_Id                                  UgzQbDF6I7DxHTKt1ch4AaABAg
# Video_Id                                                   QuRVX60P_6I
# Comment_Text         You tube la <br>KS Kiladis pedicure இந்த வீடிய...
# Comment_Author                                         @venkateshs6081
# Comment_Published                                 2024-01-12T12:34:27Z
# Name: 38, dtype: object
# comments are already inserted
# 39
# Comment_Id           UgyIsmLapFBh2WnKwL94AaABAg
# Video_Id                            NQuKTGQ0LLE
# Comment_Text               வீடியோ சூப்பர் அக்கா
# Comment_Author                  @venkateshs6081
# Comment_Published          2024-01-12T12:36:17Z
# Name: 39, dtype: object
# comments are already inserted
# 40
# Comment_Id                                  UgzcVUnIBmnGKtJ0s1F4AaABAg
# Video_Id                                                   NQuKTGQ0LLE
# Comment_Text         You tube la <br>KS Kiladis pedicure இந்த வீடிய...
# Comment_Author                                         @venkateshs6081
# Comment_Published                                 2024-01-12T12:35:22Z
# Name: 40, dtype: object
# comments are already inserted
# 41
# Comment_Id                          UgxrQ75cAybwfvLPpP14AaABAg
# Video_Id                                           NQuKTGQ0LLE
# Comment_Text         My current weight 76tarcet weight lose 60
# Comment_Author                                  @ManiRam-td4dn
# Comment_Published                         2023-12-22T16:21:51Z
# Name: 41, dtype: object
# comments are already inserted
# 42
# Comment_Id           UgxmYyJacdqvGr4zCWZ4AaABAg
# Video_Id                            NQuKTGQ0LLE
# Comment_Text            Sari sari manichiten d😂
# Comment_Author               @sunmathikumar4992
# Comment_Published          2023-12-22T13:32:41Z
# Name: 42, dtype: object
# comments are already inserted
# 43
# Comment_Id                            UgwPtnZj6XCEgGwsWvZ4AaABAg
# Video_Id                                             auoZjFAWOik
# Comment_Text         Neenga daily exercise walking Panna vengala
# Comment_Author                                        @lakshan23
# Comment_Published                           2023-12-19T07:30:21Z
# Name: 43, dtype: object
# comments are already inserted
# 44
# Comment_Id            UgzRmED7EBAiaTdyJ6F4AaABAg
# Video_Id                             auoZjFAWOik
# Comment_Text         Hi my weight 66.6 target 57
# Comment_Author               @subburajsanjay7202
# Comment_Published           2023-12-15T06:10:34Z
# Name: 44, dtype: object
# comments are already inserted
# 45
# Comment_Id           UgzVMXpYnCrNWwalCiJ4AaABAg
# Video_Id                            auoZjFAWOik
# Comment_Text                              Super
# Comment_Author              @AbirajeshLifestyle
# Comment_Published          2023-12-15T05:50:00Z
# Name: 45, dtype: object
# comments are already inserted
# 46
# Comment_Id           UgyO3FohYoNhBoZPCAl4AaABAg
# Video_Id                            RmCbx0Q2QTU
# Comment_Text                    Cutieepie ...❤🎉
# Comment_Author                @sathissathis9942
# Comment_Published          2024-01-24T12:25:07Z
# Name: 46, dtype: object
# comments are already inserted
# 47
# Comment_Id           UgxqiDrj-QZyvoZ08Mh4AaABAg
# Video_Id                            RmCbx0Q2QTU
# Comment_Text              Your son is so cute🎉❤
# Comment_Author                @valueofthought01
# Comment_Published          2023-12-15T14:08:50Z
# Name: 47, dtype: object
# comments are already inserted
# 48
# Comment_Id           UgwwAAQobZWfCa5xtQx4AaABAg
# Video_Id                            U7ezXMkNRlY
# Comment_Text                                Pls
# Comment_Author                   @Maniabi-xj2qg
# Comment_Published          2023-12-13T08:55:44Z
# Name: 48, dtype: object
# comments are already inserted
# 49
# Comment_Id                              UgzWBoFXT00NfdgrcER4AaABAg
# Video_Id                                               U7ezXMkNRlY
# Comment_Text         Sister ennku romba wight loss pannunum sister
# Comment_Author                                      @Maniabi-xj2qg
# Comment_Published                             2023-12-13T08:55:31Z
# Name: 49, dtype: object
# comments are already inserted
# 50
# Comment_Id           UgwRYICAeEAZuFTJhOx4AaABAg
# Video_Id                            U7ezXMkNRlY
# Comment_Text                              Super
# Comment_Author              @AbirajeshLifestyle
# Comment_Published          2023-12-13T08:45:22Z
# Name: 50, dtype: object
# comments are already inserted
# 51
# Comment_Id           UgxgBlr0s3A48zp5jYd4AaABAg
# Video_Id                            Aeq5fnQPiZs
# Comment_Text                 Super all the best
# Comment_Author              @AbirajeshLifestyle
# Comment_Published          2023-12-12T11:00:49Z
# Name: 51, dtype: object
# comments are already inserted
# 52
# Comment_Id                    Ugytar2V5pza_HTULct4AaABAg
# Video_Id                                     Aeq5fnQPiZs
# Comment_Text         Yes we want what  u r cooking😊.....
# Comment_Author                    @srinivasansandhya8672
# Comment_Published                   2023-12-11T08:16:01Z
# Name: 52, dtype: object
# comments are already inserted
# 53
# Comment_Id                                  UgxpnLHWVSqpIaqqtKR4AaABAg
# Video_Id                                                   Aeq5fnQPiZs
# Comment_Text         Plz put how to make Kali receipe video.and whi...
# Comment_Author                                               @j7fun100
# Comment_Published                                 2023-12-11T07:59:14Z
# Name: 53, dtype: object
# comments are already inserted
# 54
# Comment_Id            UgxM7Ur_A6xIA-1YOKl4AaABAg
# Video_Id                             K86jyqFTBS4
# Comment_Text         Your voice is not audioable
# Comment_Author                 @SreeEnergyCorner
# Comment_Published           2023-12-08T10:54:23Z
# Name: 54, dtype: object
# comments are already inserted
# 55
# Comment_Id                                  UgxjigaICRIsbS9htaF4AaABAg
# Video_Id                                                   K86jyqFTBS4
# Comment_Text         Sis en height 155 weight 55 evlo weight erukan...
# Comment_Author                                     @preethapreetha4372
# Comment_Published                                 2023-12-07T05:25:39Z
# Name: 55, dtype: object
# comments are already inserted
# 56
# Comment_Id           Ugx41tXxsUvf16vGW2t4AaABAg
# Video_Id                            3kmAb2jQIyE
# Comment_Text                  Congratulations❤🎉
# Comment_Author                @SnehaVeljo-hy6xm
# Comment_Published          2023-12-04T14:35:29Z
# Name: 56, dtype: object
# comments are already inserted
# 57
# Comment_Id           UgxgEnvb5BgArT7xtZR4AaABAg
# Video_Id                            _Cp8ub1LsJQ
# Comment_Text              Athu enna kudikeringa
# Comment_Author                @m.sudharsan2b220
# Comment_Published          2023-12-16T05:05:16Z
# Name: 57, dtype: object
# comments are already inserted
# 58
# Comment_Id                                  Ugx-BrHMlwTK4kB-GuZ4AaABAg
# Video_Id                                                   _Cp8ub1LsJQ
# Comment_Text         Hi sister. Actually I have one doubt. Engalukk...
# Comment_Author                                       @thanikasalam4008
# Comment_Published                                 2023-12-05T05:05:50Z
# Name: 58, dtype: object
# comments are already inserted
# 59
# Comment_Id                      UgztHYa5MAsDYX392ZJ4AaABAg
# Video_Id                                       _Cp8ub1LsJQ
# Comment_Text         Akka my current weight 52 achieved 42
# Comment_Author                                    @Usrimam
# Comment_Published                     2023-12-04T06:48:39Z
# Name: 59, dtype: object
# comments are already inserted
# 60
# Comment_Id                 Ugzo5kycr84Kv-odKKp4AaABAg
# Video_Id                                  _Cp8ub1LsJQ
# Comment_Text         Your weight please sister please
# Comment_Author                       @user-zp6yp4gg6b
# Comment_Published                2023-12-04T02:09:10Z
# Name: 60, dtype: object
# comments are already inserted
# 61
# Comment_Id                            UgwUJesu9TmpjnlgCqd4AaABAg
# Video_Id                                             _Cp8ub1LsJQ
# Comment_Text         Start pannumpodhu neenga enna weight sister
# Comment_Author                                     @shansasi9501
# Comment_Published                           2023-12-03T06:52:23Z
# Name: 61, dtype: object
# comments are already inserted
# 62
# Comment_Id                                  Ugx_d0jjCDSyXgnfxNF4AaABAg
# Video_Id                                                   _Cp8ub1LsJQ
# Comment_Text         Which is U r current weight ?and  which is ur ...
# Comment_Author                                               @j7fun100
# Comment_Published                                 2023-12-03T05:55:14Z
# Name: 62, dtype: object
# comments are already inserted
# 63
# Comment_Id           Ugwal6lA6YFLOs7ZaG54AaABAg
# Video_Id                            8EfkCARVe88
# Comment_Text          Akka glass tumbler super❤
# Comment_Author                    @pavithra4888
# Comment_Published          2023-12-03T16:13:39Z
# Name: 63, dtype: object
# comments are already inserted
# 64
# Comment_Id           UgyfmxoFiqGsgDAvrXB4AaABAg
# Video_Id                            8EfkCARVe88
# Comment_Text                         Hii sister
# Comment_Author                  @ramchandru5731
# Comment_Published          2023-12-01T03:07:44Z
# Name: 64, dtype: object
# comments are already inserted
# 65
# Comment_Id                                  UgwDZRG67KdGjloQbnN4AaABAg
# Video_Id                                                   3SmE0OUrJBI
# Comment_Text         Correct sis yenna eptiyellam sonnaga 20 kg wei...
# Comment_Author                                    @sharmilifestyle2984
# Comment_Published                                 2023-11-30T07:24:51Z
# Name: 65, dtype: object
# comments are already inserted
# 66
# Comment_Id                                  UgzPqUAmfnpe-KQ9zNV4AaABAg
# Video_Id                                                   3SmE0OUrJBI
# Comment_Text         I love your channel keep up the good work.. Al...
# Comment_Author                                         @cook_withpooja
# Comment_Published                                 2023-11-30T07:24:31Z
# Name: 66, dtype: object
# comments are already inserted
# 67
# Comment_Id           UgyLbVTWocR6omHxeVZ4AaABAg
# Video_Id                            3SmE0OUrJBI
# Comment_Text                 Sis drink link sis
# Comment_Author               @madhandharani2713
# Comment_Published          2023-11-30T05:56:50Z
# Name: 67, dtype: object
# comments are already inserted
# 68
# Comment_Id                                  UgyI6Gfg7HghSG7_dmF4AaABAg
# Video_Id                                                   lMmxivsmtTc
# Comment_Text         Nonstick,aluminum vessels use panathinga healt...
# Comment_Author                                         @priyakumar8475
# Comment_Published                                 2024-01-02T12:37:35Z
# Name: 68, dtype: object
# comments are already inserted
# 69
# Comment_Id           Ugz3iiuCAAqWj_HmrAJ4AaABAg
# Video_Id                            ooLKyCivmjg
# Comment_Text                     Current weight
# Comment_Author                 @user-gg1ei6bs5x
# Comment_Published          2023-11-27T12:08:38Z
# Name: 69, dtype: object
# comments are already inserted
# 70
# Comment_Id                          Ugy0GydnbfUYqzYkC3N4AaABAg
# Video_Id                                           ooLKyCivmjg
# Comment_Text         Neega onnum antha alavukku weight illayea
# Comment_Author                            @sharmilifestyle2984
# Comment_Published                         2023-11-27T05:21:56Z
# Name: 70, dtype: object
# comments are already inserted
# 71
# Comment_Id                        Ugw2PImtU2zKGkXy7Lp4AaABAg
# Video_Id                                         WivZTUyOoyc
# Comment_Text         Last konjo video la voice kekla mam 🙄🙄😅
# Comment_Author                           @jothisvarshavj2728
# Comment_Published                       2023-11-30T09:25:57Z
# Name: 71, dtype: object
# comments are already inserted
# 72
# Comment_Id                              Ugwe4uWgnt8NcFr8lY14AaABAg
# Video_Id                                               WivZTUyOoyc
# Comment_Text         Neraya consistency word use pandringa mam😂😂😂😂
# Comment_Author                                 @jothisvarshavj2728
# Comment_Published                             2023-11-30T09:25:25Z
# Name: 72, dtype: object
# comments are already inserted
# 73
# Comment_Id                                  UgyN-nEdoj3i0eUK_ZJ4AaABAg
# Video_Id                                                   WivZTUyOoyc
# Comment_Text         😊content pathu videokula vandhaavnga😂 sarbaga ...
# Comment_Author                                    @RajkumarKumar-cn1oi
# Comment_Published                                 2023-11-26T20:55:27Z
# Name: 73, dtype: object
# comments are already inserted
# 74
# Comment_Id           Ugz5mUpfNx4BRGODXDt4AaABAg
# Video_Id                            WivZTUyOoyc
# Comment_Text                          Super sis
# Comment_Author                    @sivamani5303
# Comment_Published          2023-11-25T09:43:19Z
# Name: 74, dtype: object
# comments are already inserted
# 75
# Comment_Id                                UgwN9IdPeFB1qkd_cft4AaABAg
# Video_Id                                                 aGjR7kZkYWQ
# Comment_Text         Super akka u posting a good information to us 🎉
# Comment_Author                                  @RajkumarKumar-cn1oi
# Comment_Published                               2023-11-25T22:30:26Z
# Name: 75, dtype: object
# comments are already inserted
# 76
# Comment_Id           UgwrHrpF51uGPgmWe294AaABAg
# Video_Id                            RNaPwnjJlr4
# Comment_Text                              ❤nice
# Comment_Author                    @parthisusi10
# Comment_Published          2024-01-28T12:40:29Z
# Name: 76, dtype: object
# comments are already inserted
# 77
# Comment_Id           UgyNrd7jiAY-hwXWraR4AaABAg
# Video_Id                            H63jpLOySCc
# Comment_Text                 Super all the best
# Comment_Author              @AbirajeshLifestyle
# Comment_Published          2023-12-12T10:59:51Z
# Name: 77, dtype: object
# comments are already inserted
# 78
# Comment_Id           UgwJwBuDx-MrhkjHtw14AaABAg
# Video_Id                            H63jpLOySCc
# Comment_Text         Last ha ena water sis Adhu
# Comment_Author               @Priyashakthivlogs
# Comment_Published          2023-11-26T15:34:42Z
# Name: 78, dtype: object
# comments are already inserted
# 79
# Comment_Id                                  Ugz5jHKmK74P7AYjklx4AaABAg
# Video_Id                                                   aYuCM7hHPAQ
# Comment_Text         Hai bro how are you ? your way of explanation ...
# Comment_Author                                @renugadevichakkarai6111
# Comment_Published                                 2024-02-09T09:03:48Z
# Name: 79, dtype: object
# comments are already inserted
# 80
# Comment_Id           UgxEQtw9lQ5HNAIladV4AaABAg
# Video_Id                            aYuCM7hHPAQ
# Comment_Text                              Ayyaa
# Comment_Author             @dineeshvarshanc1576
# Comment_Published          2023-09-08T15:02:31Z
# Name: 80, dtype: object
# comments are already inserted
# 81
# Comment_Id                   UgxWCAzRbu7XnkS6DD94AaABAg
# Video_Id                                    aYuCM7hHPAQ
# Comment_Text         Waiting for your videos big boss 🎉
# Comment_Author                          @PraveenN-fp5jy
# Comment_Published                  2023-09-04T18:59:03Z
# Name: 81, dtype: object
# comments are already inserted
# 82
# Comment_Id           Ugx_McuXDnVPw4PS-Ix4AaABAg
# Video_Id                            aYuCM7hHPAQ
# Comment_Text                         Congrats 👏
# Comment_Author                @thineshkumar5068
# Comment_Published          2023-08-31T06:15:49Z
# Name: 82, dtype: object
# comments are already inserted
# 83
# Comment_Id                          UgyxKbaURKGmmbZoYMB4AaABAg
# Video_Id                                           aYuCM7hHPAQ
# Comment_Text         Congratulations Shabari,we are waiting...
# Comment_Author                                @cinemashots3903
# Comment_Published                         2023-08-29T07:45:54Z
# Name: 83, dtype: object
# comments are already inserted
# 84
# Comment_Id           UgxWRFKMs5mGY10tESB4AaABAg
# Video_Id                            aYuCM7hHPAQ
# Comment_Text                  waiting sir......
# Comment_Author                    @NGStudio1997
# Comment_Published          2023-08-29T06:22:54Z
# Name: 84, dtype: object
# comments are already inserted
# 85
# Comment_Id                                  UgwQLnOsfJCIpAI45sh4AaABAg
# Video_Id                                                   aYuCM7hHPAQ
# Comment_Text         Congratulations 🎉<br>Eagerly waiting for yours...
# Comment_Author                                                 @Uk-zen
# Comment_Published                                 2023-08-29T06:13:31Z
# Name: 85, dtype: object
# comments are already inserted
# 86
# Comment_Id                 UgybIC5X4aNoPVBMBKt4AaABAg
# Video_Id                                  aYuCM7hHPAQ
# Comment_Text         Waiting for yours sessions sir 😊
# Comment_Author                           @rabinanto07
# Comment_Published                2023-08-28T18:42:59Z
# Name: 86, dtype: object
# comments are already inserted
# 87
# Comment_Id                                  UgxMT8PuAPl_cPOf0O94AaABAg
# Video_Id                                                   aYuCM7hHPAQ
# Comment_Text         That&#39;s really a good initiative shabari, c...
# Comment_Author                                            @iampraveens
# Comment_Published                                 2023-08-28T18:38:32Z
# Name: 87, dtype: object
# comments are already inserted
# 88
# Comment_Id                                  UgxhjKjKXpnYKtXZH_14AaABAg
# Video_Id                                                   aYuCM7hHPAQ
# Comment_Text         Hi sir, santhiya(DT1) waiting for ur videos......
# Comment_Author                                             @NidhisVlog
# Comment_Published                                 2023-08-28T16:42:24Z
# Name: 88, dtype: object
# comments are already inserted
# 89
# Comment_Id           UgzC3Yv-ZT40K9gGnVh4AaABAg
# Video_Id                            Yndu_cdyDng
# Comment_Text                                  ✌
# Comment_Author          @tamilfreefirememes6579
# Comment_Published          2024-02-20T16:52:12Z
# Name: 89, dtype: object
# comments are already inserted
# 90
# Comment_Id           UgwHoX5qPDu6TEA3YVh4AaABAg
# Video_Id                            X45N3h7b_5I
# Comment_Text              sir how to contact yu
# Comment_Author                   @nikhilesh3683
# Comment_Published          2022-02-24T15:34:42Z
# Name: 90, dtype: object
# comments are already inserted
# 91
# Comment_Id                                  UgyVXmqjddv-uzMFhiV4AaABAg
# Video_Id                                                   X45N3h7b_5I
# Comment_Text         hats-off to your effort to make everyone to un...
# Comment_Author                                     @santhoshnagaraj344
# Comment_Published                                 2021-09-05T15:28:38Z
# Name: 91, dtype: object
# comments are already inserted
# 92
# Comment_Id           UgwkIoV-Idj85tk7fQJ4AaABAg
# Video_Id                            X45N3h7b_5I
# Comment_Text                  Nice try Shabari.
# Comment_Author                      @jshari2002
# Comment_Published          2021-05-25T11:15:32Z
# Name: 92, dtype: object
# comments are already inserted
# 93
# Comment_Id                Ugw2Y1bNZ3JKOaUJSzt4AaABAg
# Video_Id                                 X45N3h7b_5I
# Comment_Text         Informative speech....superb...
# Comment_Author                   @gowrishankaris9169
# Comment_Published               2021-05-22T12:41:07Z
# Name: 93, dtype: object
# comments are already inserted
# 94
# Comment_Id           Ugx3lp9tlIY9bKLiZN54AaABAg
# Video_Id                            X45N3h7b_5I
# Comment_Text          Waiting for coding part 🔥
# Comment_Author                      @outplays_3
# Comment_Published          2021-05-02T11:57:37Z
# Name: 94, dtype: object
# comments are already inserted
# 95
# Comment_Id                                  UgxHyoFPleWtRruxE2x4AaABAg
# Video_Id                                                   CPO7xgstK0Q
# Comment_Text         Can we drive the autonomous car and make it to...
# Comment_Author                                     @santhoshnagaraj344
# Comment_Published                                 2021-09-05T15:14:44Z
# Name: 95, dtype: object
# comments are already inserted
# 96
# Comment_Id           UgxZnRojiA2YEKbjGLh4AaABAg
# Video_Id                            CPO7xgstK0Q
# Comment_Text           Good attempt. Keep it up
# Comment_Author                    @jaggujayanth
# Comment_Published          2021-04-28T10:17:46Z
# Name: 96, dtype: object
# comments are already inserted
# 97
# Comment_Id                                  UgyYcUf7GbE5iVpLU5R4AaABAg
# Video_Id                                                   CPO7xgstK0Q
# Comment_Text         Hello sir iam having an doubt on ardunio and n...
# Comment_Author                                             @outplays_3
# Comment_Published                                 2021-04-24T04:54:24Z
# Name: 97, dtype: object
# comments are already inserted
# 98
# Comment_Id           UgxEFbsnvv607CVmGLR4AaABAg
# Video_Id                            DGbSMC8AoH4
# Comment_Text            Awesome explanation sir
# Comment_Author                 @madhanmohan1634
# Comment_Published          2023-02-17T19:08:23Z
# Name: 98, dtype: object
# comments are already inserted
# 99
# Comment_Id                                  UgzfHnE7I-iMDqE9OSZ4AaABAg
# Video_Id                                                   DGbSMC8AoH4
# Comment_Text         sir, is there is all the algorithms to be trai...
# Comment_Author                                     @santhoshnagaraj344
# Comment_Published                                 2021-09-05T14:51:25Z
# Name: 99, dtype: object
# comments are already inserted
# 100
# Comment_Id                                  Ugz0ISPai5Io9pVOof54AaABAg
# Video_Id                                                   rdRAdvsESKA
# Comment_Text         Already one Mr.Magesh of RESPRO Capital manage...
# Comment_Author                                               @Greenome
# Comment_Published                                 2023-12-11T05:40:09Z
# Name: 100, dtype: object
# comments are already inserted
# 101
# Comment_Id                                  UgzX-83ZjuBaVLSK5-d4AaABAg
# Video_Id                                                   rdRAdvsESKA
# Comment_Text         A criminal case on money scam has been filed a...
# Comment_Author                                               @Greenome
# Comment_Published                                 2023-12-11T05:39:07Z
# Name: 101, dtype: object
# comments are already inserted
# 102
# Comment_Id                                  UgyDv_s5aGKfgUZxzqx4AaABAg
# Video_Id                                                   rdRAdvsESKA
# Comment_Text         Fraud to the core he is... he runs a company c...
# Comment_Author                                               @Greenome
# Comment_Published                                 2023-12-11T05:37:34Z
# Name: 102, dtype: object
# comments are already inserted
# 103
# Comment_Id                                  UgwIEMkpFfV09f2FtKV4AaABAg
# Video_Id                                                   rdRAdvsESKA
# Comment_Text         its awesome to learn AI in native language(Tam...
# Comment_Author                                     @santhoshnagaraj344
# Comment_Published                                 2021-09-05T14:36:30Z
# Name: 103, dtype: object
# comments are already inserted
# 104
# Comment_Id                UgzKOhlF0OfyQaB6TSx4AaABAg
# Video_Id                                 rdRAdvsESKA
# Comment_Text         Great to learn in tamil..<br>👌😎
# Comment_Author                   @shanmugapriya.v430
# Comment_Published               2021-04-16T17:16:27Z
# Name: 104, dtype: object
# comments are already inserted
# 105
# Comment_Id                                  UgxUdQOXlO6Vq_Wr2A54AaABAg
# Video_Id                                                   rdRAdvsESKA
# Comment_Text         Super Sir.. Explanation and examples given for...
# Comment_Author                                         @giridharanr135
# Comment_Published                                 2021-04-16T14:08:34Z
# Name: 105, dtype: object
# comments are already inserted
# 106
# Comment_Id                              UgwL0rGruAmMcd1zwjx4AaABAg
# Video_Id                                               mvEaWBYmFqI
# Comment_Text         Hi sir unga kitta online class padika mudiuma
# Comment_Author                                  @lakshmilakshmi550
# Comment_Published                             2024-02-16T07:53:29Z
# Name: 106, dtype: object
# comments are already inserted
# 107
# Comment_Id           UgxLT85vFnDRI88eFNd4AaABAg
# Video_Id                            mvEaWBYmFqI
# Comment_Text                                  🔥
# Comment_Author                        @ranch_03
# Comment_Published          2023-02-28T14:25:57Z
# Name: 107, dtype: object
# comments are already inserted
# 108
# Comment_Id           UgzUplBxDTHLXMYOScV4AaABAg
# Video_Id                            mvEaWBYmFqI
# Comment_Text                                  🔥
# Comment_Author                      @outplays_3
# Comment_Published          2021-04-15T05:06:57Z
# Name: 108, dtype: object
# comments are already inserted
# 109
# Comment_Id                      Ugy4osqlQNY4Fo77hFR4AaABAg
# Video_Id                                       mvEaWBYmFqI
# Comment_Text         Good effort Shabari Sir. Keep going 👍
# Comment_Author                             @diwakarang1316
# Comment_Published                     2021-04-15T04:02:38Z
# Name: 109, dtype: object
# comments are already inserted
# 110
# Comment_Id           UgzuLCQjpISHF4Z-C_14AaABAg
# Video_Id                            hfi-m-l4DmA
# Comment_Text          Unka video use panikalama
# Comment_Author                       @bwsquadyt
# Comment_Published          2023-11-13T09:07:53Z
# Name: 110, dtype: object
# comments are already inserted
# 111
# Comment_Id           UgxcwJDiS8hhqPTJBMx4AaABAg
# Video_Id                            hfi-m-l4DmA
# Comment_Text                               👏💯 ✨
# Comment_Author                @thamaraikodi6088
# Comment_Published          2023-11-09T11:11:39Z
# Name: 111, dtype: object
# comments are already inserted
# 112
# Comment_Id           UgzkCwLF5O-WdliJQvt4AaABAg
# Video_Id                            L66ZEPeuPmM
# Comment_Text                              Money
# Comment_Author                 @user-xm2eg6ic7f
# Comment_Published          2023-11-08T08:00:29Z
# Name: 112, dtype: object
# ...
# Name: 3049, dtype: object
# comments are already inserted
# 3050
# Comment_Id                                  UgzXJX3vEDwhaEEu92N4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         கண்ட கருமாந்திரத்தை எல்லாம் தின்னால் அப்படித்த...
# Comment_Author                                          @rammithra7341
# Comment_Published                                 2023-09-15T10:19:24Z
# Name: 3050, dtype: object
# comments are already inserted
# 3051
# Comment_Id           UgwWGIe7t5LVFvYjMGl4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text           Super 😂😂😂🤒🤕🥺🇱🇰👈💐💐💐🥰🌹😘😘👸👈
# Comment_Author              @fathimaraseeka1197
# Comment_Published          2023-08-30T09:06:29Z
# Name: 3051, dtype: object
# comments are already inserted
# 3052
# Comment_Id                  UgwWmB5iu3JAB7BXRaF4AaABAg
# Video_Id                                   UJhaK-7WE1c
# Comment_Text         Kandatha sapta appadi dha agum 😂🤣
# Comment_Author                              @sara31003
# Comment_Published                 2023-08-22T18:25:59Z
# Name: 3052, dtype: object
# comments are already inserted
# 3053
# Comment_Id                 UgxV4Y8dLfjTGawwq_R4AaABAg
# Video_Id                                  UJhaK-7WE1c
# Comment_Text         Pandian stores trolls her badly😅
# Comment_Author                            @120_ticket
# Comment_Published                2023-05-10T03:38:16Z
# Name: 3053, dtype: object
# comments are already inserted
# 3054
# Comment_Id                                  UgzfIy7F1YJLA3i2QgJ4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         is dysentery , food poisoning or a diahorrea a...
# Comment_Author                                                @SS24480
# Comment_Published                                 2023-04-12T08:51:34Z
# Name: 3054, dtype: object
# comments are already inserted
# 3055
# Comment_Id                           Ugx5AA-xY7YXuG9DU6Z4AaABAg
# Video_Id                                            UJhaK-7WE1c
# Comment_Text         Akka ungalukku onnum pannathu akka 🥰🥰🥰🥰🥰🥳🎉
# Comment_Author                                @suthansuthan2404
# Comment_Published                          2023-03-01T03:21:53Z
# Name: 3055, dtype: object
# comments are already inserted
# 3056
# Comment_Id           UgxG_Xl87GTuXMDGA_54AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                               👸🙏🕉️
# Comment_Author        @saraswathysaraswathy9184
# Comment_Published          2022-12-19T05:53:36Z
# Name: 3056, dtype: object
# comments are already inserted
# 3057
# Comment_Id                                  UgySXkDaRe0T-09KTUZ4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         பொது நிகழ்ச்சியில் darsha விற்கு pedi என கிண்ட...
# Comment_Author                                            @sridhar4490
# Comment_Published                                 2022-11-18T05:58:59Z
# Name: 3057, dtype: object
# comments are already inserted
# 3058
# Comment_Id                                  Ugymlfcdtlug7EXwmpJ4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         ஒரு பேதிக்கு நீ பெரிய ஹாஸ்பிடல் போயி அட்மிட் ஆ...
# Comment_Author                                               @ArjunC22
# Comment_Published                                 2022-07-27T13:37:45Z
# Name: 3058, dtype: object
# comments are already inserted
# 3059
# Comment_Id                                  UgyJeH9T_bJdxxq2qMN4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Priyanka, pls don&#39;t joke about your weight...
# Comment_Author                                              @bluestrue
# Comment_Published                                 2022-06-08T18:45:56Z
# Name: 3059, dtype: object
# comments are already inserted
# 3060
# Comment_Id           UgwIkLx0R4O7eL8wYQJ4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                 Akka you look like
# Comment_Author                  @sriranjani7297
# Comment_Published          2022-06-07T15:47:42Z
# Name: 3060, dtype: object
# comments are already inserted
# 3061
# Comment_Id                   UgxnlnselNtMI12Kt3x4AaABAg
# Video_Id                                    UJhaK-7WE1c
# Comment_Text         Akka u soooo sweet 😍😌🤗 Akka 😘😘😘😘😘😘
# Comment_Author                          @s.rabeckal6692
# Comment_Published                  2022-05-23T11:39:19Z
# Name: 3061, dtype: object
# comments are already inserted
# 3062
# Comment_Id                        Ugx4DkJYIi7pYsI4h754AaABAg
# Video_Id                                         UJhaK-7WE1c
# Comment_Text         Please make vlog with English subtitles
# Comment_Author                         @durgeshwaridhage3118
# Comment_Published                       2022-05-22T02:31:24Z
# Name: 3062, dtype: object
# comments are already inserted
# 3063
# Comment_Id                             Ugy0UlxQIyCPR-M-My94AaABAg
# Video_Id                                              UJhaK-7WE1c
# Comment_Text         Priyanka I feel very sad to see u like this.
# Comment_Author                                 @peninalpersis4324
# Comment_Published                            2022-04-26T19:57:03Z
# Name: 3063, dtype: object
# comments are already inserted
# 3064
# Comment_Id           UgyPodhQ8CMDgPcq3kV4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                             So sad
# Comment_Author                 @shazminshan6319
# Comment_Published          2022-04-25T21:37:03Z
# Name: 3064, dtype: object
# comments are already inserted
# 3065
# Comment_Id                          UgzUNDYdwLc0LiHZix94AaABAg
# Video_Id                                           UJhaK-7WE1c
# Comment_Text         One symptom is dyeriya for covid takecare
# Comment_Author                                 @bhuvanaveda182
# Comment_Published                         2022-04-21T10:03:45Z
# Name: 3065, dtype: object
# comments are already inserted
# 3066
# Comment_Id                                  UgzgErgTB2i0hz2zibZ4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Akka enna analum sapadula mattum correct ah ir...
# Comment_Author                                     @saransaravanan5925
# Comment_Published                                 2022-04-16T08:01:11Z
# Name: 3066, dtype: object
# comments are already inserted
# 3067
# Comment_Id           UgwLJPGd2gF-iXW3dId4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                            Hi akka
# Comment_Author               @sathishswetha9539
# Comment_Published          2022-04-08T07:31:12Z
# Name: 3067, dtype: object
# comments are already inserted
# 3068
# Comment_Id                                  Ugw68UPJwMbYxeHr-_V4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Get wel <a href="http://soon.my/">soon.my</a> ...
# Comment_Author                                           @fathimaz4300
# Comment_Published                                 2022-03-26T01:45:01Z
# Name: 3068, dtype: object
# comments are already inserted
# 3069
# Comment_Id                                  Ugzn6lP1gvhCVb6lHPV4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Ne polacha enna sethuuuu ponna ennna losuuu sa...
# Comment_Author                                                 @u11209
# Comment_Published                                 2022-03-04T13:58:09Z
# Name: 3069, dtype: object
# comments are already inserted
# 3070
# Comment_Id                                  Ugy3XVtO6QsdWLmWgON4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Inime ipdi achna.. nenga veetla tea tikation l...
# Comment_Author                                         @lunavenkat5297
# Comment_Published                                 2022-02-25T07:33:40Z
# Name: 3070, dtype: object
# comments are already inserted
# 3071
# Comment_Id                                  UgzgebglzufLhIHNgZ94AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Don&#39;t worry ungalku onum agathu nenga inth...
# Comment_Author                                         @lunavenkat5297
# Comment_Published                                 2022-02-25T07:29:36Z
# Name: 3071, dtype: object
# comments are already inserted
# 3072
# Comment_Id                                  UgyfIxC0D9O9sc-Ojrl4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Namaku<br>Namaku<br>Sorudan <br>Sorudan <br>Mu...
# Comment_Author                                         @lunavenkat5297
# Comment_Published                                 2022-02-25T07:27:45Z
# Name: 3072, dtype: object
# comments are already inserted
# 3073
# Comment_Id           Ugx9v8CHnBDy4CUjeJB4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                           தங்கமே 😍
# Comment_Author                @safrasnazeem8224
# Comment_Published          2022-02-02T17:07:08Z
# Name: 3073, dtype: object
# comments are already inserted
# 3074
# Comment_Id           UgygdGc6Lja-NPtfwL94AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                           Hai akka
# Comment_Author                     @rajanmk4390
# Comment_Published          2022-01-31T04:31:40Z
# Name: 3074, dtype: object
# comments are already inserted
# 3075
# Comment_Id           UgyIMK8NryE4uiXSqKh4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                           Hai akka
# Comment_Author                     @rajanmk4390
# Comment_Published          2022-01-31T04:31:34Z
# Name: 3075, dtype: object
# comments are already inserted
# 3076
# Comment_Id                UgzBYeZPP7g3UQG7k7N4AaABAg
# Video_Id                                 UJhaK-7WE1c
# Comment_Text         I love you piriyanka akka❤️❤️❤️
# Comment_Author                    @nanthinidurga6563
# Comment_Published               2022-01-28T14:34:22Z
# Name: 3076, dtype: object
# comments are already inserted
# 3077
# Comment_Id           UgxoLq66beJ2fj-1J9B4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                     ❤️❤️❤️❤️❤️❤️❤️
# Comment_Author                   @ashavijay1922
# Comment_Published          2022-01-27T10:18:43Z
# Name: 3077, dtype: object
# comments are already inserted
# 3078
# Comment_Id                                 UgxrodC3JF9O272kdSp4AaABAg
# Video_Id                                                  UJhaK-7WE1c
# Comment_Text         Ungaluku onnumakathu akka. Na saamiketa veantuna
# Comment_Author                                   @monamohanapriya7728
# Comment_Published                                2022-01-26T10:25:07Z
# Name: 3078, dtype: object
# comments are already inserted
# 3079
# Comment_Id                                  UgxqDo_jre4g209luF94AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Priyanka akka you&#39;re a strong woman neeka ...
# Comment_Author                                       @RishiKumar-pw2ug
# Comment_Published                                 2022-01-26T08:09:26Z
# Name: 3079, dtype: object
# comments are already inserted
# 3080
# Comment_Id                        UgwGIKIxJnvTQ4WgUtN4AaABAg
# Video_Id                                         UJhaK-7WE1c
# Comment_Text         Akka nanga veg aa non veg akka veg akka
# Comment_Author                              @deepasuresh2362
# Comment_Published                       2022-01-25T07:51:09Z
# Name: 3080, dtype: object
# comments are already inserted
# 3081
# Comment_Id                                  Ugy43waDDMRYuI6GeWx4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         akka ungale ipidi pathapoo yenake sad ach akka...
# Comment_Author                                            @anjanaj4806
# Comment_Published                                 2022-01-22T16:30:17Z
# Name: 3081, dtype: object
# comments are already inserted
# 3082
# Comment_Id                                  UgyJBEh8uGacrFYBTeV4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Akka ungalukku idhu alla setu aagadhu .always ...
# Comment_Author                                        @jayaseelans1743
# Comment_Published                                 2022-01-21T14:03:49Z
# Name: 3082, dtype: object
# comments are already inserted
# 3083
# Comment_Id           Ugzfloy6PtVbKIxsvix4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                        akka🤣🤣🤣🤣😂😂😂
# Comment_Author                 @ranjiniskrt9426
# Comment_Published          2022-01-21T07:53:13Z
# Name: 3083, dtype: object
# comments are already inserted
# 3084
# Comment_Id           UgwCZ7BFBq2OA65cALh4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                                  😘
# Comment_Author        @meenakumarisaravanan2569
# Comment_Published          2022-01-20T09:58:42Z
# Name: 3084, dtype: object
# comments are already inserted
# 3085
# Comment_Id                                  Ugy4_5pNRESjxY7WYDV4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Aspetaluku evalo panam selavashu. Moondru orud...
# Comment_Author                                @kalaiselviappadurai5387
# Comment_Published                                 2022-01-19T17:30:47Z
# Name: 3085, dtype: object
# comments are already inserted
# 3086
# Comment_Id           UgwCo_MvxRT4Fpocg5R4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                 After biggboss 😂😂🤣
# Comment_Author                     @yogeshb7908
# Comment_Published          2022-01-19T06:35:08Z
# Name: 3086, dtype: object
# comments are already inserted
# 3087
# Comment_Id                                  Ugw2b37Hm4-VAkKvtw54AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Seekeeram vandhu fun banunga priyanka all the ...
# Comment_Author                                      @priyaiyyappan6857
# Comment_Published                                 2022-01-19T06:13:32Z
# Name: 3087, dtype: object
# comments are already inserted
# 3088
# Comment_Id           UgyGJ_lUv3inGHL6Nd54AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text                 Theeni pandaram...
# Comment_Author                     @rajivindira
# Comment_Published          2022-01-18T04:40:20Z
# Name: 3088, dtype: object
# comments are already inserted
# 3089
# Comment_Id             Ugz4IA66IbQDvmTHZ3F4AaABAg
# Video_Id                              UJhaK-7WE1c
# Comment_Text         Thinnipandaaram kundu psycho
# Comment_Author                   @vinchenzo011111
# Comment_Published            2022-01-17T15:33:55Z
# Name: 3089, dtype: object
# comments are already inserted
# 3090
# Comment_Id                                  UgzJY6PCgkacvUYzBHd4AaABAg
# Video_Id                                                   UJhaK-7WE1c
# Comment_Text         Vaera level video priyanka, singapenney, bigg ...
# Comment_Author                                        @muthukumars7413
# Comment_Published                                 2022-01-17T06:48:03Z
# Name: 3090, dtype: object
# comments are already inserted
# 3091
# Comment_Id                      UgzOupC3hC1qpV_dVw94AaABAg
# Video_Id                                       UJhaK-7WE1c
# Comment_Text         Akka don&#39;t worry get will soon 🤩🤩
# Comment_Author                            @elamurugans2054
# Comment_Published                     2022-01-17T06:16:02Z
# Name: 3091, dtype: object
# comments are already inserted
# 3092
# Comment_Id           UgymtA0CnneDVDcGIaZ4AaABAg
# Video_Id                            UJhaK-7WE1c
# Comment_Text         Get well soon akka❤️❤️❤️❤️
# Comment_Author                  @UshaRani-jg3yu
# Comment_Published          2022-01-17T04:58:44Z
# Name: 3092, dtype: object
# comments are already inserted
# 3093
# Comment_Id                       UgzB38aDADp3k0Q7WXx4AaABAg
# Video_Id                                        UJhaK-7WE1c
# Comment_Text         hi ka be happy😊 ka speedy recovery 😘😘😘
# Comment_Author                            @sharonsmitha9596
# Comment_Published                      2022-01-16T07:39:00Z
# Name: 3093, dtype: object
# comments are already inserted

# %%
####STREAMLIT PART

with st.sidebar:
    st.title(":orange[YOUTUBE HAVERSTING AND WAREHOUSING]")
    st.header("skills")
    st.caption("Python")
    st.caption("Data Collection")
    st.caption("MongoDB")
    st.caption("API Integration")
    st.caption("Data Management Using MongoDB and SQL")

channel_id=st.text_input("Enter and store data")

if st.button("collect and store data"):
    ch_ids=[]
    db=client["Youtube_data"]
    coll1=db["Youtube_data"]
    for ch_data in collection1.find({},{"_id:0","channel_information"}):
        print(ch_data["channel_information"]["channel_id"])
        ch_ids.append(ch_data["channel_information"]["channel_id"])

    if channel_id in ch_ids:
         st.success("Channel Details of the given channel id already exists")
    else:
        insert=channel_details(channel_id)
        st.success(insert) 

if st.button("Migrate to sql"):
    table=tables()
    st.success(table)
show_table=st.radio("SELECT THE TABLE FOR VIEW",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS"))

if show_table=="CHANNELS":
    show_channels_table()

elif show_table=="PLAYLISTS":
    show_playlist_table()

elif show_table=="VIDEOS":
    show_videos_table()

elif show_table=="COMMENTS":
    show_comments_details()

# %%
####sql connection

mydb=psycopg2.connect(host="localhost",user="postgres",password="root",
                    database="youtube_details",port="5432")
cursor=mydb.cursor()

question=st.selectbox("select your 1 question",
                      ("1.What are the names of all the videos and their corresponding channels?",
                                               "2.Which channels have the most number of videos and how many videos do they have?",
                                               "3.What are the top 10 most viewed videos and their respective channels?",
                                               "4.How many comments were made on each video, and what are their corresponding video names?",
                                               "5.Which videos have the highest number of likes, and what are their corresponding channel names?",
                                               "6.What is the total number of likes and dislikes for each video, and what are their corresponding video names?",
                                               "7.What is the total number of views for each channel, and what are their corresponding channel names?",
                                               "8.What are the names of all the channels that have published videos in the year 2022?",
                                               "9.What is the average duration of all videos in each channel, and what are their corresponding channel names?",
                                               "10.Which videos have the highest number of comments, and what are their corresponding channel names?"),
                                                index=None,
                                                placeholder="Select contact method...",
                                               )

if question=="1.What are the names of all the videos and their corresponding channels?":

    query1='''select title as videos,channel_name as channelname from videos'''
    cursor.execute(query1)
    mydb.commit()
    q1=cursor.fetchall()
    df=pd.DataFrame(q1,columns=["video title","channel name"])
    st.write(df)


elif question== "2.Which channels have the most number of videos and how many videos do they have?":

    query2='''select channel_name  as channelname,total_videos as no_videos from channels
            order by total_videos desc'''
    cursor.execute(query2)
    mydb.commit()
    q2=cursor.fetchall()
    df2=pd.DataFrame(q2,columns=["channel name","No of videos"])
    st.write(df2)


elif question=="3.What are the top 10 most viewed videos and their respective channels?":
   query3='''select views as views ,channel_name as channelname,title as videotitle 
           from videos where views is not null order by views desc limit 10'''
   cursor.execute(query3)
   mydb.commit()
   q3=cursor.fetchall()
   df3=pd.DataFrame(q3,columns=[" views","channel name","videotitle"])
   st.write(df3)

elif question== "4.How many comments were made on each video, and what are their corresponding video names?":
        query4='''select comments as no_comments,title as videotitle from videos where comments is not null'''
        cursor.execute(query4)
        mydb.commit()
        q4=cursor.fetchall()
        df4=pd.DataFrame(q4,columns=["no of comments","videotitle"])
        st.write(df4)

elif question=="5.Which videos have the highest number of likes, and what are their corresponding channel names?" :
        query5='''select title as videotitle,channel_name as channelname,likes as likecount from
                videos where likes is not null order by likes  desc '''
        cursor.execute(query5)
        mydb.commit()
        q5=cursor.fetchall()
        df5=pd.DataFrame(q5,columns=["videotitle","channelname","likecount"])
        st.write(df5)

elif question=="6.What is the total number of likes and dislikes for each video, and what are their corresponding video names?":
        query6='''select likes as likecount, title as videotitle from videos'''
        cursor.execute(query6)
        mydb.commit()
        q6=cursor.fetchall()
        df6=pd.DataFrame(q6,columns=["likecount","videotitle"])
        st.write(df6)

elif question=="7.What is the total number of views for each channel, and what are their corresponding channel names?":
        query7='''select channel_name as channelname,views as totalviews from channels '''
        cursor.execute(query7)
        mydb.commit()
        q7=cursor.fetchall()
        df7=pd.DataFrame(q7,columns=["channel name","totalviews"])
        st.write(df7)

elif question=="8.What are the names of all the channels that have published videos in the year 2022?":
        query8='''select title as video_title,published_date as videorelease,channel_name as channelname from videos
                        where extract (year from published_date) =2022'''
        cursor.execute(query8)
        mydb.commit()
        q8=cursor.fetchall()
        df8=pd.DataFrame(q8,columns=["videotitle","published_date","channelname"])
        st.write(df8)

elif question=="9.What is the average duration of all videos in each channel, and what are their corresponding channel names?":
        query9='''select channel_name as channelname,AVG(duration) as averageduration from videos group by channel_name'''
        cursor.execute(query9)
        mydb.commit()
        q9=cursor.fetchall()
        df9=pd.DataFrame(q9,columns=["channelname",("avergeduration")])
        df9
        
        q9=[]
        for index,row  in df9.iterrows():
                channel_title=row["channelname"]
                average_duration=row["avergeduration"]
                average_duration_str=str(average_duration)
                q9.append(dict(channeltitle=channel_title,averageduration=average_duration_str))
        df1=pd.DataFrame
        st.write(df1)

elif question=="10.Which videos have the highest number of comments, and what are their corresponding channel names?":
    query10='''select title as videotitle,channel_name as channelname,comments as comments from videos where comments is not null order by comments desc'''
    cursor.execute(query10)
    mydb.commit()
    q10=cursor.fetchall()
    df10=pd.DataFrame(q10,columns=["video title","channel name","comments"])
    st.write(df10)

# %%
ch_ids=[]
db=client["Youtube_data"]
coll1=db["Youtube_data"]
for ch_data in collection1.find({},{"_id:0","channel_information"}):
    ch_ids.append(ch_data["channel_information"]["channel_id"])

# %%
mydb=psycopg2.connect(host="localhost",user="postgres",password="root",
                    database="youtube_details",port="5432")
cursor=mydb.cursor()

# "4.How many comments were made on each video, and what are their corresponding video names?",
#                                                "5.Which videos have the highest number of likes, and what are their corresponding channel names?",
#                                                "6.What is the total number of likes and dislikes for each video, and what are their corresponding video names?",
#                                                "7.What is the total number of views for each channel, and what are their corresponding channel names?",
#                                                "8.What are the names of all the channels that have published videos in the year 2022?",
#                                                "9.What is the average duration of all videos in each channel, and what are their corresponding channel names?",
#                                                "10.Which videos have the highest number of comments, and what are their corresponding channel names?"

if question=="9.What is the average duration of all videos in each channel, and what are their corresponding channel names?":
        query9='''select channel_name as channelname,AVG(duration) as averageduration from videos group by channel_name'''
        cursor.execute(query9)
        mydb.commit()
        q9=cursor.fetchall()
        df9=pd.DataFrame(q9,columns=["channelname",("avergeduration")])
        st.write(df9)
        
        q9=[]
        for index,row  in df9.iterrows():
                channel_title=row["channelname"]
                average_duration=row["avergeduration"]
                average_duration_str=str(average_duration)
                q9.append(dict(channeltitle=channel_title,averageduration=average_duration_str))
                df1=pd.DataFrame
        st.write(df1)

elif question=="10.Which videos have the highest number of comments, and what are their corresponding channel names?":
    query10='''select title as videotitle,channel_name as channelname,comments as comments from videos where comments is not null order by comments desc'''
    cursor.execute(query10)
    mydb.commit()
    q10=cursor.fetchall()
    df10=pd.DataFrame(q10,columns=["video title","channel name","comments"])
    df10

# %%
df9
# Out:
#              channelname  avergeduration
# 0     Data Science Tamil 0 days 00:16:25
# 1    Interactive Fitness 0 days 00:00:24
# 2         Life of Shmoji 0 days 00:08:46
# 3         Inspire Me Now 0 days 00:00:39
# 4         Cutest Channel 0 days 00:12:00
# 5           Life's View💞 0 days 00:00:18
# 6  2k Healthy lifestyle  0 days 00:01:00
# 7     Priyanka Deshpande 0 days 00:09:11
# 8      power of mindset  0 days 00:01:00
# 9    Shabarinath Premlal 0 days 00:00:55

# %%
if question=="10.Which videos have the highest number of comments, and what are their corresponding channel names?":
    query10='''select title as videotitle,channel_name as channelname,comments as comments from videos where comments is not null order by comments desc'''
    cursor.execute(query10)
    mydb.commit()
    q10=cursor.fetchall()
    df10=pd.DataFrame(q10,columns=["video title","channel name","comments"])
    df10
# Out:
#                                           video title           channel name  \
# 0                         24 hours Cleaning Challenge     Priyanka Deshpande
# 1                         24 hours Cleaning Challenge     Priyanka Deshpande
# 2                         24 hours Cleaning Challenge     Priyanka Deshpande
# 3            Turn every setback into a comeback video    Shabarinath Premlal
# 4            Turn every setback into a comeback video    Shabarinath Premlal
# 5            Turn every setback into a comeback video    Shabarinath Premlal
# 6   😋ladiesfinger dryfry  #villagestylefood#ytshor...  2k Healthy lifestyle
# 7   😋ladiesfinger dryfry  #villagestylefood#ytshor...  2k Healthy lifestyle
# 8   😋ladiesfinger dryfry  #villagestylefood#ytshor...  2k Healthy lifestyle
# 9                    valkaiyee verupaa eruku machaa 🤣           Life's View💞
# 10                   valkaiyee verupaa eruku machaa 🤣           Life's View💞
# 11  PhonePe Pulse Data Visualization and Explorati...     Data Science Tamil
# 12  PhonePe Pulse Data Visualization and Explorati...     Data Science Tamil
# 13                   valkaiyee verupaa eruku machaa 🤣           Life's View💞
# 14  PhonePe Pulse Data Visualization and Explorati...     Data Science Tamil
# 15              जीवन की सच्चाई #youtubeshorts #shorts         Inspire Me Now
# 16  #ninjahattori#ninjahattoriintamil#ninja#hattor...         Cutest Channel
# 17  #viral #increaseyourvalue#timemanagement #moti...      power of mindset
# 18  #ninjahattori#ninjahattoriintamil#ninja#hattor...         Cutest Channel
# 19  #viral #increaseyourvalue#timemanagement #moti...      power of mindset
# 20  how to sleep (especially for people that strug...         Life of Shmoji
# 21              जीवन की सच्चाई #youtubeshorts #shorts         Inspire Me Now
# 22  Foods that can be bad for your brain health #s...    Interactive Fitness
# 23  Foods that can be bad for your brain health #s...    Interactive Fitness
# 24  how to sleep (especially for people that strug...         Life of Shmoji
# 25  #ninjahattori#ninjahattoriintamil#ninja#hattor...         Cutest Channel
# 26  #viral #increaseyourvalue#timemanagement #moti...      power of mindset
# 27  how to sleep (especially for people that strug...         Life of Shmoji
# 28              जीवन की सच्चाई #youtubeshorts #shorts         Inspire Me Now
# 29  Foods that can be bad for your brain health #s...    Interactive Fitness
#
#     comments
# 0        313
# 1        313
# 2        313
# 3         13
# 4         13
# 5         13
# 6          3
# 7          3
# 8          3
# 9          1
# 10         1
# 11         1
# 12         1
# 13         1
# 14         1
# 15         0
# 16         0
# 17         0
# 18         0
# 19         0
# 20         0
# 21         0
# 22         0
# 23         0
# 24         0
# 25         0
# 26         0
# 27         0
# 28         0
# 29         0

# %%
df10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[219], line 1
# ----> 1 df10
#
# NameError: name 'df10' is not defined

# %%
if question=="6.What is the total number of likes and dislikes for each video, and what are their corresponding video names?":
        query6='''select likes as likecount, title as videotitle from videos'''
        cursor.execute(query6)
        mydb.commit()
        q6=cursor.fetchall()
        df6=pd.DataFrame(q6,columns=["likecount","videotitle"])
        st.write(df6)

# %%
df6
# Out:
#     likecount                                         videotitle
# 0          19  😋ladiesfinger dryfry  #villagestylefood#ytshor...
# 1          32           Turn every setback into a comeback video
# 2           8  #ninjahattori#ninjahattoriintamil#ninja#hattor...
# 3          16  #viral #increaseyourvalue#timemanagement #moti...
# 4           1  how to sleep (especially for people that strug...
# 5          10                   valkaiyee verupaa eruku machaa 🤣
# 6           0              जीवन की सच्चाई #youtubeshorts #shorts
# 7           5  Foods that can be bad for your brain health #s...
# 8           4  PhonePe Pulse Data Visualization and Explorati...
# 9       13271                        24 hours Cleaning Challenge
# 10         19  😋ladiesfinger dryfry  #villagestylefood#ytshor...
# 11         32           Turn every setback into a comeback video
# 12          8  #ninjahattori#ninjahattoriintamil#ninja#hattor...
# 13         16  #viral #increaseyourvalue#timemanagement #moti...
# 14          1  how to sleep (especially for people that strug...
# 15         10                   valkaiyee verupaa eruku machaa 🤣
# 16          0              जीवन की सच्चाई #youtubeshorts #shorts
# 17          5  Foods that can be bad for your brain health #s...
# 18          4  PhonePe Pulse Data Visualization and Explorati...
# 19      13271                        24 hours Cleaning Challenge
# 20         19  😋ladiesfinger dryfry  #villagestylefood#ytshor...
# 21         32           Turn every setback into a comeback video
# 22          8  #ninjahattori#ninjahattoriintamil#ninja#hattor...
# 23         16  #viral #increaseyourvalue#timemanagement #moti...
# 24          1  how to sleep (especially for people that strug...
# 25         10                   valkaiyee verupaa eruku machaa 🤣
# 26          0              जीवन की सच्चाई #youtubeshorts #shorts
# 27          5  Foods that can be bad for your brain health #s...
# 28          4  PhonePe Pulse Data Visualization and Explorati...
# 29      13271                        24 hours Cleaning Challenge
